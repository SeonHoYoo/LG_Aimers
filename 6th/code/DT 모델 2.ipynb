# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import roc_auc_score
from sklearn.preprocessing import StandardScaler
from sklearn.pipeline import Pipeline
import joblib
import copy

# -------------------------------
# 1. 데이터 로드 및 전처리
# -------------------------------
data = pd.read_csv('train2.csv', encoding='cp949')
X = data.drop(columns=['ID', '시술 시기 코드', '시술 유형', '임신 성공 여부'])
y = data['임신 성공 여부']

# -------------------------------
# 2. Ensemble 학습을 위한 설정
# -------------------------------
n_iterations = 500   # 전체 데이터를 500번 사용
max_depth_start = 1
max_depth_end = 1000
patience = 1         # 연속 개선이 없으면 early stopping (여기서는 매우 짧게 설정)

ensemble_models = []        # 각 반복의 최적 모델 저장 리스트
ensemble_best_depths = []   # 각 모델의 최적 max_depth 저장
ensemble_train_auc = []     # 각 모델의 학습 ROC AUC 저장
ensemble_val_auc = []       # 각 모델의 검증 ROC AUC 저장

# -------------------------------
# 3. 여러 번의 무작위 데이터 분할 및 모델 학습
# -------------------------------
for i in range(n_iterations):
    print(f"\n=== Ensemble Model {i+1}/{n_iterations} ===")
    # 무작위 분할 (매번 다른 분할)
    X_train, X_val, y_train, y_val = train_test_split(
        X, y, test_size=0.2, stratify=y
    )
    
    # 파이프라인 구성: StandardScaler와 DecisionTreeClassifier
    pipeline = Pipeline([
        ('scaler', StandardScaler()),
        ('dt', DecisionTreeClassifier())
    ])
    
    patience_counter = 0   # early stopping 카운터 초기화
    best_score = -np.inf     # 검증 ROC AUC 최적값 초기화
    best_depth = None
    best_model = None
    
    # max_depth를 1부터 max_depth_end까지 증가시키며 모델 학습 및 평가
    for depth in range(max_depth_start, max_depth_end + 1):
        pipeline.set_params(dt__max_depth=depth)
        pipeline.fit(X_train, y_train)
        
        # 학습 및 검증 데이터 ROC AUC 계산
        y_train_prob = pipeline.predict_proba(X_train)[:, 1]
        train_score = roc_auc_score(y_train, y_train_prob)
        y_val_prob = pipeline.predict_proba(X_val)[:, 1]
        current_score = roc_auc_score(y_val, y_val_prob)
        
        # 각 depth 반복 시점의 결과 출력 (트래킹)
        print(f"Depth: {depth}, Train ROC AUC: {train_score:.4f}, Valid ROC AUC: {current_score:.4f}")
        
        # 검증 ROC AUC가 개선되면 갱신
        if current_score > best_score:
            best_score = current_score
            best_depth = depth
            best_model = copy.deepcopy(pipeline)
            patience_counter = 0  # 개선 시 카운터 리셋
        else:
            patience_counter += 1
        
        # 연속 개선이 없으면 조기 종료
        if patience_counter >= patience:
            print(f"Early stopping triggered at depth: {depth}")
            break

    # 해당 반복의 최종 학습 데이터 ROC AUC 재계산 (선택 사항)
    y_train_prob = best_model.predict_proba(X_train)[:, 1]
    final_train_score = roc_auc_score(y_train, y_train_prob)
    
    print(f"최적 Depth: {best_depth}, 최종 Train ROC AUC: {final_train_score:.4f}, 최종 Valid ROC AUC: {best_score:.4f}")
    
    ensemble_models.append(best_model)
    ensemble_best_depths.append(best_depth)
    ensemble_train_auc.append(final_train_score)
    ensemble_val_auc.append(best_score)

# -------------------------------
# 4. Ensemble 평가 (평균 성능 확인)
# -------------------------------
avg_train_auc = np.mean(ensemble_train_auc)
avg_val_auc = np.mean(ensemble_val_auc)
print("\nEnsemble 평균 성능:")
print(f"평균 Train ROC AUC: {avg_train_auc:.4f}")
print(f"평균 Valid ROC AUC: {avg_val_auc:.4f}")

# 전체 모델 저장 (나중에 재사용 가능)
joblib.dump(ensemble_models, "ensemble_deep_decision_trees.pkl")
print("\nEnsemble 모델이 'ensemble_deep_decision_trees.pkl'로 저장되었습니다.")

# -------------------------------
# 5. 상위 및 전체 모델 기반으로 테스트 데이터 예측
# -------------------------------
# validation ROC AUC를 기준으로 내림차순 정렬할 인덱스를 구합니다.
val_auc_array = np.array(ensemble_val_auc)
sorted_indices = np.argsort(val_auc_array)[::-1]  # 내림차순 (높은 성능순)

# 사용할 모델 개수별 인덱스 추출
top100_indices = sorted_indices[:100]
top200_indices = sorted_indices[:200]
top300_indices = sorted_indices[:300]
all_indices = np.arange(len(ensemble_models))  # 전체 500개 모델

# 테스트 데이터 로드 및 전처리
test_data = pd.read_csv('test2.csv', encoding='cp949')
X_test = test_data.drop(columns=['ID', '시술 시기 코드', '시술 유형', '임신 성공 여부'], errors='ignore')

def predict_with_ensemble(model_indices, models, X_test, threshold=0.5):
    probs_list = []
    for idx in model_indices:
        probs = models[idx].predict_proba(X_test)[:, 1]
        probs_list.append(probs)
    avg_probs = np.mean(probs_list, axis=0)
    preds = (avg_probs >= threshold).astype(int)
    return preds

# 각 앙상블 결과로 예측
top100_preds = predict_with_ensemble(top100_indices, ensemble_models, X_test)
top200_preds = predict_with_ensemble(top200_indices, ensemble_models, X_test)
top300_preds = predict_with_ensemble(top300_indices, ensemble_models, X_test)
all_preds    = predict_with_ensemble(all_indices,    ensemble_models, X_test)

# 예측 결과를 test_data에 추가
test_data['임신 성공 여부 예측_top100'] = top100_preds
test_data['임신 성공 여부 예측_top200'] = top200_preds
test_data['임신 성공 여부 예측_top300'] = top300_preds
test_data['임신 성공 여부 예측_all']     = all_preds

# 각각의 파일로 저장 (원하는 대로 컬럼 선택 가능)
test_data[['ID', '임신 성공 여부 예측_top100']].to_csv('ensemble_test_predictions_top100.csv', index=False, encoding='cp949')
test_data[['ID', '임신 성공 여부 예측_top200']].to_csv('ensemble_test_predictions_top200.csv', index=False, encoding='cp949')
test_data[['ID', '임신 성공 여부 예측_top300']].to_csv('ensemble_test_predictions_top300.csv', index=False, encoding='cp949')
test_data[['ID', '임신 성공 여부 예측_all']].to_csv('ensemble_test_predictions_all.csv', index=False, encoding='cp949')

print("테스트 데이터 예측 결과가 각각 'ensemble_test_predictions_top100.csv',")
print("'ensemble_test_predictions_top200.csv', 'ensemble_test_predictions_top300.csv',")
print("그리고 'ensemble_test_predictions_all.csv' 파일에 저장되었습니다.")
# Out:
# === Ensemble Model 1/500 ===
# Depth: 1, Train ROC AUC: 0.5978, Valid ROC AUC: 0.5978
# Depth: 2, Train ROC AUC: 0.6635, Valid ROC AUC: 0.6648
# Depth: 3, Train ROC AUC: 0.6909, Valid ROC AUC: 0.6920
# Depth: 4, Train ROC AUC: 0.7022, Valid ROC AUC: 0.7040
# Depth: 5, Train ROC AUC: 0.7103, Valid ROC AUC: 0.7117
# Depth: 6, Train ROC AUC: 0.7152, Valid ROC AUC: 0.7157
# Depth: 7, Train ROC AUC: 0.7187, Valid ROC AUC: 0.7183
# Depth: 8, Train ROC AUC: 0.7213, Valid ROC AUC: 0.7177
# Early stopping triggered at depth: 8
# 최적 Depth: 7, 최종 Train ROC AUC: 0.7187, 최종 Valid ROC AUC: 0.7183
#
# === Ensemble Model 2/500 ===
# Depth: 1, Train ROC AUC: 0.5975, Valid ROC AUC: 0.5990
# Depth: 2, Train ROC AUC: 0.6632, Valid ROC AUC: 0.6660
# Depth: 3, Train ROC AUC: 0.6908, Valid ROC AUC: 0.6924
# Depth: 4, Train ROC AUC: 0.7023, Valid ROC AUC: 0.7038
# Depth: 5, Train ROC AUC: 0.7104, Valid ROC AUC: 0.7117
# Depth: 6, Train ROC AUC: 0.7152, Valid ROC AUC: 0.7161
# Depth: 7, Train ROC AUC: 0.7189, Valid ROC AUC: 0.7177
# Depth: 8, Train ROC AUC: 0.7218, Valid ROC AUC: 0.7177
# Early stopping triggered at depth: 8
# 최적 Depth: 7, 최종 Train ROC AUC: 0.7189, 최종 Valid ROC AUC: 0.7177
#
# === Ensemble Model 3/500 ===
# Depth: 1, Train ROC AUC: 0.5976, Valid ROC AUC: 0.5986
# Depth: 2, Train ROC AUC: 0.6647, Valid ROC AUC: 0.6652
# Depth: 3, Train ROC AUC: 0.6902, Valid ROC AUC: 0.6928
# Depth: 4, Train ROC AUC: 0.7028, Valid ROC AUC: 0.7047
# Depth: 5, Train ROC AUC: 0.7099, Valid ROC AUC: 0.7097
# Depth: 6, Train ROC AUC: 0.7151, Valid ROC AUC: 0.7168
# Depth: 7, Train ROC AUC: 0.7185, Valid ROC AUC: 0.7180
# Depth: 8, Train ROC AUC: 0.7215, Valid ROC AUC: 0.7189
# Depth: 9, Train ROC AUC: 0.7248, Valid ROC AUC: 0.7178
# Early stopping triggered at depth: 9
# 최적 Depth: 8, 최종 Train ROC AUC: 0.7215, 최종 Valid ROC AUC: 0.7189
#
# === Ensemble Model 4/500 ===
# Depth: 1, Train ROC AUC: 0.5979, Valid ROC AUC: 0.5974
# Depth: 2, Train ROC AUC: 0.6658, Valid ROC AUC: 0.6609
# Depth: 3, Train ROC AUC: 0.6917, Valid ROC AUC: 0.6867
# Depth: 4, Train ROC AUC: 0.7044, Valid ROC AUC: 0.7006
# Depth: 5, Train ROC AUC: 0.7109, Valid ROC AUC: 0.7079
# Depth: 6, Train ROC AUC: 0.7157, Valid ROC AUC: 0.7131
# Depth: 7, Train ROC AUC: 0.7191, Valid ROC AUC: 0.7151
# Depth: 8, Train ROC AUC: 0.7219, Valid ROC AUC: 0.7155
# Depth: 9, Train ROC AUC: 0.7252, Valid ROC AUC: 0.7141
# Early stopping triggered at depth: 9
# 최적 Depth: 8, 최종 Train ROC AUC: 0.7219, 최종 Valid ROC AUC: 0.7155
#
# === Ensemble Model 5/500 ===
# Depth: 1, Train ROC AUC: 0.5978, Valid ROC AUC: 0.5978
# Depth: 2, Train ROC AUC: 0.6638, Valid ROC AUC: 0.6636
# Depth: 3, Train ROC AUC: 0.6911, Valid ROC AUC: 0.6915
# Depth: 4, Train ROC AUC: 0.7024, Valid ROC AUC: 0.7033
# Depth: 5, Train ROC AUC: 0.7104, Valid ROC AUC: 0.7104
# Depth: 6, Train ROC AUC: 0.7153, Valid ROC AUC: 0.7141
# Depth: 7, Train ROC AUC: 0.7189, Valid ROC AUC: 0.7167
# Depth: 8, Train ROC AUC: 0.7217, Valid ROC AUC: 0.7162
# Early stopping triggered at depth: 8
# 최적 Depth: 7, 최종 Train ROC AUC: 0.7189, 최종 Valid ROC AUC: 0.7167
#
# === Ensemble Model 6/500 ===
# Depth: 1, Train ROC AUC: 0.5984, Valid ROC AUC: 0.5955
# Depth: 2, Train ROC AUC: 0.6640, Valid ROC AUC: 0.6627
# Depth: 3, Train ROC AUC: 0.6916, Valid ROC AUC: 0.6895
# Depth: 4, Train ROC AUC: 0.7030, Valid ROC AUC: 0.7009
# Depth: 5, Train ROC AUC: 0.7111, Valid ROC AUC: 0.7086
# Depth: 6, Train ROC AUC: 0.7158, Valid ROC AUC: 0.7133
# Depth: 7, Train ROC AUC: 0.7190, Valid ROC AUC: 0.7159
# Depth: 8, Train ROC AUC: 0.7219, Valid ROC AUC: 0.7150
# Early stopping triggered at depth: 8
# 최적 Depth: 7, 최종 Train ROC AUC: 0.7190, 최종 Valid ROC AUC: 0.7159
#
# === Ensemble Model 7/500 ===
# Depth: 1, Train ROC AUC: 0.5974, Valid ROC AUC: 0.5994
# Depth: 2, Train ROC AUC: 0.6628, Valid ROC AUC: 0.6674
# Depth: 3, Train ROC AUC: 0.6901, Valid ROC AUC: 0.6955
# Depth: 4, Train ROC AUC: 0.7008, Valid ROC AUC: 0.7095
# Depth: 5, Train ROC AUC: 0.7088, Valid ROC AUC: 0.7178
# Depth: 6, Train ROC AUC: 0.7139, Valid ROC AUC: 0.7210
# Depth: 7, Train ROC AUC: 0.7175, Valid ROC AUC: 0.7225
# Depth: 8, Train ROC AUC: 0.7206, Valid ROC AUC: 0.7216
# Early stopping triggered at depth: 8
# 최적 Depth: 7, 최종 Train ROC AUC: 0.7175, 최종 Valid ROC AUC: 0.7225
#
# === Ensemble Model 8/500 ===
# Depth: 1, Train ROC AUC: 0.5978, Valid ROC AUC: 0.5975
# Depth: 2, Train ROC AUC: 0.6642, Valid ROC AUC: 0.6619
# Depth: 3, Train ROC AUC: 0.6918, Valid ROC AUC: 0.6887
# Depth: 4, Train ROC AUC: 0.7028, Valid ROC AUC: 0.7015
# Depth: 5, Train ROC AUC: 0.7108, Valid ROC AUC: 0.7099
# Depth: 6, Train ROC AUC: 0.7154, Valid ROC AUC: 0.7149
# Depth: 7, Train ROC AUC: 0.7189, Valid ROC AUC: 0.7174
# Depth: 8, Train ROC AUC: 0.7214, Valid ROC AUC: 0.7181
# Depth: 9, Train ROC AUC: 0.7246, Valid ROC AUC: 0.7174
# Early stopping triggered at depth: 9
# 최적 Depth: 8, 최종 Train ROC AUC: 0.7214, 최종 Valid ROC AUC: 0.7181
#
# === Ensemble Model 9/500 ===
# Depth: 1, Train ROC AUC: 0.5978, Valid ROC AUC: 0.5976
# Depth: 2, Train ROC AUC: 0.6634, Valid ROC AUC: 0.6652
# Depth: 3, Train ROC AUC: 0.6905, Valid ROC AUC: 0.6937
# Depth: 4, Train ROC AUC: 0.7018, Valid ROC AUC: 0.7057
# Depth: 5, Train ROC AUC: 0.7102, Valid ROC AUC: 0.7125
# Depth: 6, Train ROC AUC: 0.7151, Valid ROC AUC: 0.7164
# Depth: 7, Train ROC AUC: 0.7184, Valid ROC AUC: 0.7183
# Depth: 8, Train ROC AUC: 0.7215, Valid ROC AUC: 0.7180
# Early stopping triggered at depth: 8
# 최적 Depth: 7, 최종 Train ROC AUC: 0.7184, 최종 Valid ROC AUC: 0.7183
#
# === Ensemble Model 10/500 ===
# Depth: 1, Train ROC AUC: 0.5980, Valid ROC AUC: 0.5967
# Depth: 2, Train ROC AUC: 0.6643, Valid ROC AUC: 0.6613
# Depth: 3, Train ROC AUC: 0.6915, Valid ROC AUC: 0.6896
# Depth: 4, Train ROC AUC: 0.7026, Valid ROC AUC: 0.7025
# Depth: 5, Train ROC AUC: 0.7109, Valid ROC AUC: 0.7095
# Depth: 6, Train ROC AUC: 0.7159, Valid ROC AUC: 0.7124
# Depth: 7, Train ROC AUC: 0.7194, Valid ROC AUC: 0.7158
# Depth: 8, Train ROC AUC: 0.7223, Valid ROC AUC: 0.7144
# Early stopping triggered at depth: 8
# 최적 Depth: 7, 최종 Train ROC AUC: 0.7194, 최종 Valid ROC AUC: 0.7158
#
# === Ensemble Model 11/500 ===
# Depth: 1, Train ROC AUC: 0.5979, Valid ROC AUC: 0.5972
# Depth: 2, Train ROC AUC: 0.6655, Valid ROC AUC: 0.6621
# Depth: 3, Train ROC AUC: 0.6916, Valid ROC AUC: 0.6875
# Depth: 4, Train ROC AUC: 0.7045, Valid ROC AUC: 0.7014
# Depth: 5, Train ROC AUC: 0.7106, Valid ROC AUC: 0.7070
# Depth: 6, Train ROC AUC: 0.7157, Valid ROC AUC: 0.7125
# Depth: 7, Train ROC AUC: 0.7189, Valid ROC AUC: 0.7148
# Depth: 8, Train ROC AUC: 0.7221, Valid ROC AUC: 0.7157
# Depth: 9, Train ROC AUC: 0.7258, Valid ROC AUC: 0.7143
# Early stopping triggered at depth: 9
# 최적 Depth: 8, 최종 Train ROC AUC: 0.7221, 최종 Valid ROC AUC: 0.7157
#
# === Ensemble Model 12/500 ===
# Depth: 1, Train ROC AUC: 0.5978, Valid ROC AUC: 0.5979
# Depth: 2, Train ROC AUC: 0.6660, Valid ROC AUC: 0.6599
# Depth: 3, Train ROC AUC: 0.6920, Valid ROC AUC: 0.6854
# Depth: 4, Train ROC AUC: 0.7040, Valid ROC AUC: 0.6974
# Depth: 5, Train ROC AUC: 0.7121, Valid ROC AUC: 0.7059
# Depth: 6, Train ROC AUC: 0.7170, Valid ROC AUC: 0.7103
# Depth: 7, Train ROC AUC: 0.7202, Valid ROC AUC: 0.7123
# Depth: 8, Train ROC AUC: 0.7230, Valid ROC AUC: 0.7123
# Early stopping triggered at depth: 8
# 최적 Depth: 7, 최종 Train ROC AUC: 0.7202, 최종 Valid ROC AUC: 0.7123
#
# === Ensemble Model 13/500 ===
# Depth: 1, Train ROC AUC: 0.5978, Valid ROC AUC: 0.5978
# Depth: 2, Train ROC AUC: 0.6630, Valid ROC AUC: 0.6667
# Depth: 3, Train ROC AUC: 0.6904, Valid ROC AUC: 0.6940
# Depth: 4, Train ROC AUC: 0.7020, Valid ROC AUC: 0.7051
# Depth: 5, Train ROC AUC: 0.7099, Valid ROC AUC: 0.7135
# Depth: 6, Train ROC AUC: 0.7146, Valid ROC AUC: 0.7178
# Depth: 7, Train ROC AUC: 0.7179, Valid ROC AUC: 0.7207
# Depth: 8, Train ROC AUC: 0.7210, Valid ROC AUC: 0.7200
# Early stopping triggered at depth: 8
# 최적 Depth: 7, 최종 Train ROC AUC: 0.7179, 최종 Valid ROC AUC: 0.7207
#
# === Ensemble Model 14/500 ===
# Depth: 1, Train ROC AUC: 0.5976, Valid ROC AUC: 0.5987
# Depth: 2, Train ROC AUC: 0.6639, Valid ROC AUC: 0.6632
# Depth: 3, Train ROC AUC: 0.6912, Valid ROC AUC: 0.6911
# Depth: 4, Train ROC AUC: 0.7024, Valid ROC AUC: 0.7033
# Depth: 5, Train ROC AUC: 0.7104, Valid ROC AUC: 0.7115
# Depth: 6, Train ROC AUC: 0.7152, Valid ROC AUC: 0.7159
# Depth: 7, Train ROC AUC: 0.7186, Valid ROC AUC: 0.7188
# Depth: 8, Train ROC AUC: 0.7216, Valid ROC AUC: 0.7180
# Early stopping triggered at depth: 8
# 최적 Depth: 7, 최종 Train ROC AUC: 0.7186, 최종 Valid ROC AUC: 0.7188
#
# === Ensemble Model 15/500 ===
# Depth: 1, Train ROC AUC: 0.5979, Valid ROC AUC: 0.5972
# Depth: 2, Train ROC AUC: 0.6643, Valid ROC AUC: 0.6666
# Depth: 3, Train ROC AUC: 0.6900, Valid ROC AUC: 0.6938
# Depth: 4, Train ROC AUC: 0.7031, Valid ROC AUC: 0.7059
# Depth: 5, Train ROC AUC: 0.7102, Valid ROC AUC: 0.7114
# Depth: 6, Train ROC AUC: 0.7153, Valid ROC AUC: 0.7157
# Depth: 7, Train ROC AUC: 0.7185, Valid ROC AUC: 0.7171
# Depth: 8, Train ROC AUC: 0.7218, Valid ROC AUC: 0.7179
# Depth: 9, Train ROC AUC: 0.7248, Valid ROC AUC: 0.7169
# Early stopping triggered at depth: 9
# 최적 Depth: 8, 최종 Train ROC AUC: 0.7218, 최종 Valid ROC AUC: 0.7179
#
# === Ensemble Model 16/500 ===
# Depth: 1, Train ROC AUC: 0.5976, Valid ROC AUC: 0.5985
# Depth: 2, Train ROC AUC: 0.6639, Valid ROC AUC: 0.6632
# Depth: 3, Train ROC AUC: 0.6909, Valid ROC AUC: 0.6920
# Depth: 4, Train ROC AUC: 0.7022, Valid ROC AUC: 0.7042
# Depth: 5, Train ROC AUC: 0.7104, Valid ROC AUC: 0.7117
# Depth: 6, Train ROC AUC: 0.7154, Valid ROC AUC: 0.7146
# Depth: 7, Train ROC AUC: 0.7189, Valid ROC AUC: 0.7162
# Depth: 8, Train ROC AUC: 0.7217, Valid ROC AUC: 0.7168
# Depth: 9, Train ROC AUC: 0.7248, Valid ROC AUC: 0.7160
# Early stopping triggered at depth: 9
# 최적 Depth: 8, 최종 Train ROC AUC: 0.7217, 최종 Valid ROC AUC: 0.7168
#
# === Ensemble Model 17/500 ===
# Depth: 1, Train ROC AUC: 0.5978, Valid ROC AUC: 0.5976
# Depth: 2, Train ROC AUC: 0.6647, Valid ROC AUC: 0.6651
# Depth: 3, Train ROC AUC: 0.6910, Valid ROC AUC: 0.6897
# Depth: 4, Train ROC AUC: 0.7042, Valid ROC AUC: 0.7038
# Depth: 5, Train ROC AUC: 0.7109, Valid ROC AUC: 0.7097
# Depth: 6, Train ROC AUC: 0.7152, Valid ROC AUC: 0.7140
# Depth: 7, Train ROC AUC: 0.7185, Valid ROC AUC: 0.7167
# Depth: 8, Train ROC AUC: 0.7216, Valid ROC AUC: 0.7188
# Depth: 9, Train ROC AUC: 0.7249, Valid ROC AUC: 0.7174
# Early stopping triggered at depth: 9
# 최적 Depth: 8, 최종 Train ROC AUC: 0.7216, 최종 Valid ROC AUC: 0.7188
#
# === Ensemble Model 18/500 ===
# Depth: 1, Train ROC AUC: 0.5981, Valid ROC AUC: 0.5967
# Depth: 2, Train ROC AUC: 0.6647, Valid ROC AUC: 0.6598
# Depth: 3, Train ROC AUC: 0.6925, Valid ROC AUC: 0.6857
# Depth: 4, Train ROC AUC: 0.7036, Valid ROC AUC: 0.6983
# Depth: 5, Train ROC AUC: 0.7119, Valid ROC AUC: 0.7055
# Depth: 6, Train ROC AUC: 0.7166, Valid ROC AUC: 0.7099
# Depth: 7, Train ROC AUC: 0.7202, Valid ROC AUC: 0.7123
# Depth: 8, Train ROC AUC: 0.7231, Valid ROC AUC: 0.7115
# Early stopping triggered at depth: 8
# 최적 Depth: 7, 최종 Train ROC AUC: 0.7202, 최종 Valid ROC AUC: 0.7123
#
# === Ensemble Model 19/500 ===
# Depth: 1, Train ROC AUC: 0.5975, Valid ROC AUC: 0.5991
# Depth: 2, Train ROC AUC: 0.6649, Valid ROC AUC: 0.6642
# Depth: 3, Train ROC AUC: 0.6908, Valid ROC AUC: 0.6900
# Depth: 4, Train ROC AUC: 0.7035, Valid ROC AUC: 0.7042
# Depth: 5, Train ROC AUC: 0.7106, Valid ROC AUC: 0.7102
# Depth: 6, Train ROC AUC: 0.7156, Valid ROC AUC: 0.7139
# Depth: 7, Train ROC AUC: 0.7191, Valid ROC AUC: 0.7157
# Depth: 8, Train ROC AUC: 0.7223, Valid ROC AUC: 0.7157
# Early stopping triggered at depth: 8
# 최적 Depth: 7, 최종 Train ROC AUC: 0.7191, 최종 Valid ROC AUC: 0.7157
#
# === Ensemble Model 20/500 ===
# Depth: 1, Train ROC AUC: 0.5976, Valid ROC AUC: 0.5985
# Depth: 2, Train ROC AUC: 0.6634, Valid ROC AUC: 0.6649
# Depth: 3, Train ROC AUC: 0.6910, Valid ROC AUC: 0.6919
# Depth: 4, Train ROC AUC: 0.7023, Valid ROC AUC: 0.7037
# Depth: 5, Train ROC AUC: 0.7100, Valid ROC AUC: 0.7133
# Depth: 6, Train ROC AUC: 0.7144, Valid ROC AUC: 0.7181
# Depth: 7, Train ROC AUC: 0.7181, Valid ROC AUC: 0.7204
# Depth: 8, Train ROC AUC: 0.7208, Valid ROC AUC: 0.7204
# Depth: 9, Train ROC AUC: 0.7245, Valid ROC AUC: 0.7188
# Early stopping triggered at depth: 9
# 최적 Depth: 8, 최종 Train ROC AUC: 0.7208, 최종 Valid ROC AUC: 0.7204
#
# === Ensemble Model 21/500 ===
# Depth: 1, Train ROC AUC: 0.5978, Valid ROC AUC: 0.5975
# Depth: 2, Train ROC AUC: 0.6651, Valid ROC AUC: 0.6584
# Depth: 3, Train ROC AUC: 0.6923, Valid ROC AUC: 0.6866
# Depth: 4, Train ROC AUC: 0.7031, Valid ROC AUC: 0.6991
# Depth: 5, Train ROC AUC: 0.7111, Valid ROC AUC: 0.7082
# Depth: 6, Train ROC AUC: 0.7158, Valid ROC AUC: 0.7114
# Depth: 7, Train ROC AUC: 0.7193, Valid ROC AUC: 0.7146
# Depth: 8, Train ROC AUC: 0.7222, Valid ROC AUC: 0.7150
# Depth: 9, Train ROC AUC: 0.7254, Valid ROC AUC: 0.7144
# Early stopping triggered at depth: 9
# 최적 Depth: 8, 최종 Train ROC AUC: 0.7222, 최종 Valid ROC AUC: 0.7150
#
# === Ensemble Model 22/500 ===
# Depth: 1, Train ROC AUC: 0.5974, Valid ROC AUC: 0.5991
# Depth: 2, Train ROC AUC: 0.6640, Valid ROC AUC: 0.6626
# Depth: 3, Train ROC AUC: 0.6910, Valid ROC AUC: 0.6915
# Depth: 4, Train ROC AUC: 0.7017, Valid ROC AUC: 0.7012
# Depth: 5, Train ROC AUC: 0.7101, Valid ROC AUC: 0.7103
# Depth: 6, Train ROC AUC: 0.7152, Valid ROC AUC: 0.7142
# Depth: 7, Train ROC AUC: 0.7184, Valid ROC AUC: 0.7171
# Depth: 8, Train ROC AUC: 0.7212, Valid ROC AUC: 0.7176
# Depth: 9, Train ROC AUC: 0.7247, Valid ROC AUC: 0.7163
# Early stopping triggered at depth: 9
# 최적 Depth: 8, 최종 Train ROC AUC: 0.7212, 최종 Valid ROC AUC: 0.7176
#
# === Ensemble Model 23/500 ===
# Depth: 1, Train ROC AUC: 0.5976, Valid ROC AUC: 0.5986
# Depth: 2, Train ROC AUC: 0.6635, Valid ROC AUC: 0.6648
# Depth: 3, Train ROC AUC: 0.6911, Valid ROC AUC: 0.6913
# Depth: 4, Train ROC AUC: 0.7026, Valid ROC AUC: 0.7027
# Depth: 5, Train ROC AUC: 0.7108, Valid ROC AUC: 0.7100
# Depth: 6, Train ROC AUC: 0.7153, Valid ROC AUC: 0.7150
# Depth: 7, Train ROC AUC: 0.7188, Valid ROC AUC: 0.7164
# Depth: 8, Train ROC AUC: 0.7218, Valid ROC AUC: 0.7164
# Early stopping triggered at depth: 8
# 최적 Depth: 7, 최종 Train ROC AUC: 0.7188, 최종 Valid ROC AUC: 0.7164
#
# === Ensemble Model 24/500 ===
# Depth: 1, Train ROC AUC: 0.5976, Valid ROC AUC: 0.5985
# Depth: 2, Train ROC AUC: 0.6649, Valid ROC AUC: 0.6645
# Depth: 3, Train ROC AUC: 0.6906, Valid ROC AUC: 0.6911
# Depth: 4, Train ROC AUC: 0.7043, Valid ROC AUC: 0.7034
# Depth: 5, Train ROC AUC: 0.7108, Valid ROC AUC: 0.7102
# Depth: 6, Train ROC AUC: 0.7155, Valid ROC AUC: 0.7132
# Depth: 7, Train ROC AUC: 0.7192, Valid ROC AUC: 0.7151
# Depth: 8, Train ROC AUC: 0.7226, Valid ROC AUC: 0.7162
# Depth: 9, Train ROC AUC: 0.7259, Valid ROC AUC: 0.7153
# Early stopping triggered at depth: 9
# 최적 Depth: 8, 최종 Train ROC AUC: 0.7226, 최종 Valid ROC AUC: 0.7162
#
# === Ensemble Model 25/500 ===
# Depth: 1, Train ROC AUC: 0.5976, Valid ROC AUC: 0.5985
# Depth: 2, Train ROC AUC: 0.6653, Valid ROC AUC: 0.6626
# Depth: 3, Train ROC AUC: 0.6904, Valid ROC AUC: 0.6916
# Depth: 4, Train ROC AUC: 0.7038, Valid ROC AUC: 0.7054
# Depth: 5, Train ROC AUC: 0.7100, Valid ROC AUC: 0.7128
# Depth: 6, Train ROC AUC: 0.7147, Valid ROC AUC: 0.7170
# Depth: 7, Train ROC AUC: 0.7180, Valid ROC AUC: 0.7188
# Depth: 8, Train ROC AUC: 0.7211, Valid ROC AUC: 0.7191
# Depth: 9, Train ROC AUC: 0.7248, Valid ROC AUC: 0.7184
# Early stopping triggered at depth: 9
# 최적 Depth: 8, 최종 Train ROC AUC: 0.7211, 최종 Valid ROC AUC: 0.7191
#
# === Ensemble Model 26/500 ===
# Depth: 1, Train ROC AUC: 0.5976, Valid ROC AUC: 0.5986
# Depth: 2, Train ROC AUC: 0.6633, Valid ROC AUC: 0.6656
# Depth: 3, Train ROC AUC: 0.6907, Valid ROC AUC: 0.6930
# Depth: 4, Train ROC AUC: 0.7022, Valid ROC AUC: 0.7041
# Depth: 5, Train ROC AUC: 0.7103, Valid ROC AUC: 0.7123
# Depth: 6, Train ROC AUC: 0.7151, Valid ROC AUC: 0.7171
# Depth: 7, Train ROC AUC: 0.7186, Valid ROC AUC: 0.7180
# Depth: 8, Train ROC AUC: 0.7216, Valid ROC AUC: 0.7180
# Depth: 9, Train ROC AUC: 0.7249, Valid ROC AUC: 0.7174
# Early stopping triggered at depth: 9
# 최적 Depth: 8, 최종 Train ROC AUC: 0.7216, 최종 Valid ROC AUC: 0.7180
#
# === Ensemble Model 27/500 ===
# Depth: 1, Train ROC AUC: 0.5977, Valid ROC AUC: 0.5979
# Depth: 2, Train ROC AUC: 0.6639, Valid ROC AUC: 0.6633
# Depth: 3, Train ROC AUC: 0.6915, Valid ROC AUC: 0.6897
# Depth: 4, Train ROC AUC: 0.7031, Valid ROC AUC: 0.7005
# Depth: 5, Train ROC AUC: 0.7112, Valid ROC AUC: 0.7081
# Depth: 6, Train ROC AUC: 0.7158, Valid ROC AUC: 0.7118
# Depth: 7, Train ROC AUC: 0.7192, Valid ROC AUC: 0.7159
# Depth: 8, Train ROC AUC: 0.7220, Valid ROC AUC: 0.7157
# Early stopping triggered at depth: 8
# 최적 Depth: 7, 최종 Train ROC AUC: 0.7192, 최종 Valid ROC AUC: 0.7159
#
# === Ensemble Model 28/500 ===
# Depth: 1, Train ROC AUC: 0.5977, Valid ROC AUC: 0.5980
# Depth: 2, Train ROC AUC: 0.6640, Valid ROC AUC: 0.6628
# Depth: 3, Train ROC AUC: 0.6917, Valid ROC AUC: 0.6891
# Depth: 4, Train ROC AUC: 0.7028, Valid ROC AUC: 0.7017
# Depth: 5, Train ROC AUC: 0.7108, Valid ROC AUC: 0.7096
# Depth: 6, Train ROC AUC: 0.7159, Valid ROC AUC: 0.7125
# Depth: 7, Train ROC AUC: 0.7195, Valid ROC AUC: 0.7141
# Depth: 8, Train ROC AUC: 0.7223, Valid ROC AUC: 0.7138
# Early stopping triggered at depth: 8
# 최적 Depth: 7, 최종 Train ROC AUC: 0.7195, 최종 Valid ROC AUC: 0.7141
#
# === Ensemble Model 29/500 ===
# Depth: 1, Train ROC AUC: 0.5976, Valid ROC AUC: 0.5983
# Depth: 2, Train ROC AUC: 0.6643, Valid ROC AUC: 0.6666
# Depth: 3, Train ROC AUC: 0.6903, Valid ROC AUC: 0.6928
# Depth: 4, Train ROC AUC: 0.7019, Valid ROC AUC: 0.7055
# Depth: 5, Train ROC AUC: 0.7102, Valid ROC AUC: 0.7114
# Depth: 6, Train ROC AUC: 0.7150, Valid ROC AUC: 0.7155
# Depth: 7, Train ROC AUC: 0.7183, Valid ROC AUC: 0.7185
# Depth: 8, Train ROC AUC: 0.7212, Valid ROC AUC: 0.7194
# Depth: 9, Train ROC AUC: 0.7244, Valid ROC AUC: 0.7175
# Early stopping triggered at depth: 9
# 최적 Depth: 8, 최종 Train ROC AUC: 0.7212, 최종 Valid ROC AUC: 0.7194
#
# === Ensemble Model 30/500 ===
# Depth: 1, Train ROC AUC: 0.5982, Valid ROC AUC: 0.5963
# Depth: 2, Train ROC AUC: 0.6649, Valid ROC AUC: 0.6645
# Depth: 3, Train ROC AUC: 0.6901, Valid ROC AUC: 0.6932
# Depth: 4, Train ROC AUC: 0.7031, Valid ROC AUC: 0.7061
# Depth: 5, Train ROC AUC: 0.7102, Valid ROC AUC: 0.7118
# Depth: 6, Train ROC AUC: 0.7148, Valid ROC AUC: 0.7173
# Depth: 7, Train ROC AUC: 0.7180, Valid ROC AUC: 0.7198
# Depth: 8, Train ROC AUC: 0.7209, Valid ROC AUC: 0.7216
# Depth: 9, Train ROC AUC: 0.7241, Valid ROC AUC: 0.7206
# Early stopping triggered at depth: 9
# 최적 Depth: 8, 최종 Train ROC AUC: 0.7209, 최종 Valid ROC AUC: 0.7216
#
# === Ensemble Model 31/500 ===
# Depth: 1, Train ROC AUC: 0.5981, Valid ROC AUC: 0.5965
# Depth: 2, Train ROC AUC: 0.6644, Valid ROC AUC: 0.6609
# Depth: 3, Train ROC AUC: 0.6918, Valid ROC AUC: 0.6887
# Depth: 4, Train ROC AUC: 0.7031, Valid ROC AUC: 0.7005
# Depth: 5, Train ROC AUC: 0.7113, Valid ROC AUC: 0.7077
# Depth: 6, Train ROC AUC: 0.7159, Valid ROC AUC: 0.7120
# Depth: 7, Train ROC AUC: 0.7197, Valid ROC AUC: 0.7138
# Depth: 8, Train ROC AUC: 0.7225, Valid ROC AUC: 0.7136
# Early stopping triggered at depth: 8
# 최적 Depth: 7, 최종 Train ROC AUC: 0.7197, 최종 Valid ROC AUC: 0.7138
#
# === Ensemble Model 32/500 ===
# Depth: 1, Train ROC AUC: 0.5979, Valid ROC AUC: 0.5973
# Depth: 2, Train ROC AUC: 0.6642, Valid ROC AUC: 0.6621
# Depth: 3, Train ROC AUC: 0.6915, Valid ROC AUC: 0.6896
# Depth: 4, Train ROC AUC: 0.7027, Valid ROC AUC: 0.7020
# Depth: 5, Train ROC AUC: 0.7108, Valid ROC AUC: 0.7091
# Depth: 6, Train ROC AUC: 0.7158, Valid ROC AUC: 0.7133
# Depth: 7, Train ROC AUC: 0.7193, Valid ROC AUC: 0.7157
# Depth: 8, Train ROC AUC: 0.7222, Valid ROC AUC: 0.7159
# Depth: 9, Train ROC AUC: 0.7260, Valid ROC AUC: 0.7146
# Early stopping triggered at depth: 9
# 최적 Depth: 8, 최종 Train ROC AUC: 0.7222, 최종 Valid ROC AUC: 0.7159
#
# === Ensemble Model 33/500 ===
# Depth: 1, Train ROC AUC: 0.5976, Valid ROC AUC: 0.5984
# Depth: 2, Train ROC AUC: 0.6646, Valid ROC AUC: 0.6601
# Depth: 3, Train ROC AUC: 0.6918, Valid ROC AUC: 0.6886
# Depth: 4, Train ROC AUC: 0.7029, Valid ROC AUC: 0.6999
# Depth: 5, Train ROC AUC: 0.7107, Valid ROC AUC: 0.7097
# Depth: 6, Train ROC AUC: 0.7154, Valid ROC AUC: 0.7138
# Depth: 7, Train ROC AUC: 0.7188, Valid ROC AUC: 0.7171
# Depth: 8, Train ROC AUC: 0.7216, Valid ROC AUC: 0.7169
# Early stopping triggered at depth: 8
# 최적 Depth: 7, 최종 Train ROC AUC: 0.7188, 최종 Valid ROC AUC: 0.7171
#
# === Ensemble Model 34/500 ===
# Depth: 1, Train ROC AUC: 0.5975, Valid ROC AUC: 0.5990
# Depth: 2, Train ROC AUC: 0.6640, Valid ROC AUC: 0.6628
# Depth: 3, Train ROC AUC: 0.6912, Valid ROC AUC: 0.6908
# Depth: 4, Train ROC AUC: 0.7025, Valid ROC AUC: 0.7030
# Depth: 5, Train ROC AUC: 0.7105, Valid ROC AUC: 0.7113
# Depth: 6, Train ROC AUC: 0.7156, Valid ROC AUC: 0.7152
# Depth: 7, Train ROC AUC: 0.7190, Valid ROC AUC: 0.7173
# Depth: 8, Train ROC AUC: 0.7217, Valid ROC AUC: 0.7170
# Early stopping triggered at depth: 8
# 최적 Depth: 7, 최종 Train ROC AUC: 0.7190, 최종 Valid ROC AUC: 0.7173
#
# === Ensemble Model 35/500 ===
# Depth: 1, Train ROC AUC: 0.5974, Valid ROC AUC: 0.5993
# Depth: 2, Train ROC AUC: 0.6637, Valid ROC AUC: 0.6640
# Depth: 3, Train ROC AUC: 0.6908, Valid ROC AUC: 0.6926
# Depth: 4, Train ROC AUC: 0.7020, Valid ROC AUC: 0.7049
# Depth: 5, Train ROC AUC: 0.7100, Valid ROC AUC: 0.7122
# Depth: 6, Train ROC AUC: 0.7149, Valid ROC AUC: 0.7161
# Depth: 7, Train ROC AUC: 0.7184, Valid ROC AUC: 0.7189
# Depth: 8, Train ROC AUC: 0.7213, Valid ROC AUC: 0.7184
# Early stopping triggered at depth: 8
# 최적 Depth: 7, 최종 Train ROC AUC: 0.7184, 최종 Valid ROC AUC: 0.7189
#
# === Ensemble Model 36/500 ===
# Depth: 1, Train ROC AUC: 0.5979, Valid ROC AUC: 0.5972
# Depth: 2, Train ROC AUC: 0.6637, Valid ROC AUC: 0.6637
# Depth: 3, Train ROC AUC: 0.6913, Valid ROC AUC: 0.6907
# Depth: 4, Train ROC AUC: 0.7027, Valid ROC AUC: 0.7023
# Depth: 5, Train ROC AUC: 0.7109, Valid ROC AUC: 0.7096
# Depth: 6, Train ROC AUC: 0.7158, Valid ROC AUC: 0.7134
# Depth: 7, Train ROC AUC: 0.7194, Valid ROC AUC: 0.7148
# Depth: 8, Train ROC AUC: 0.7223, Valid ROC AUC: 0.7143
# Early stopping triggered at depth: 8
# 최적 Depth: 7, 최종 Train ROC AUC: 0.7194, 최종 Valid ROC AUC: 0.7148
#
# === Ensemble Model 37/500 ===
# Depth: 1, Train ROC AUC: 0.5978, Valid ROC AUC: 0.5979
# Depth: 2, Train ROC AUC: 0.6636, Valid ROC AUC: 0.6642
# Depth: 3, Train ROC AUC: 0.6908, Valid ROC AUC: 0.6924
# Depth: 4, Train ROC AUC: 0.7020, Valid ROC AUC: 0.7050
# Depth: 5, Train ROC AUC: 0.7100, Valid ROC AUC: 0.7130
# Depth: 6, Train ROC AUC: 0.7149, Valid ROC AUC: 0.7166
# Depth: 7, Train ROC AUC: 0.7185, Valid ROC AUC: 0.7191
# Depth: 8, Train ROC AUC: 0.7214, Valid ROC AUC: 0.7190
# Early stopping triggered at depth: 8
# 최적 Depth: 7, 최종 Train ROC AUC: 0.7185, 최종 Valid ROC AUC: 0.7191
#
# === Ensemble Model 38/500 ===
# Depth: 1, Train ROC AUC: 0.5972, Valid ROC AUC: 0.6002
# Depth: 2, Train ROC AUC: 0.6632, Valid ROC AUC: 0.6658
# Depth: 3, Train ROC AUC: 0.6907, Valid ROC AUC: 0.6929
# Depth: 4, Train ROC AUC: 0.7021, Valid ROC AUC: 0.7043
# Depth: 5, Train ROC AUC: 0.7101, Valid ROC AUC: 0.7124
# Depth: 6, Train ROC AUC: 0.7146, Valid ROC AUC: 0.7161
# Depth: 7, Train ROC AUC: 0.7184, Valid ROC AUC: 0.7176
# Depth: 8, Train ROC AUC: 0.7212, Valid ROC AUC: 0.7176
# Early stopping triggered at depth: 8
# 최적 Depth: 7, 최종 Train ROC AUC: 0.7184, 최종 Valid ROC AUC: 0.7176
#
# === Ensemble Model 39/500 ===
# Depth: 1, Train ROC AUC: 0.5972, Valid ROC AUC: 0.6000
# Depth: 2, Train ROC AUC: 0.6638, Valid ROC AUC: 0.6634
# Depth: 3, Train ROC AUC: 0.6911, Valid ROC AUC: 0.6912
# Depth: 4, Train ROC AUC: 0.7022, Valid ROC AUC: 0.7040
# Depth: 5, Train ROC AUC: 0.7106, Valid ROC AUC: 0.7108
# Depth: 6, Train ROC AUC: 0.7153, Valid ROC AUC: 0.7146
# Depth: 7, Train ROC AUC: 0.7190, Valid ROC AUC: 0.7167
# Depth: 8, Train ROC AUC: 0.7218, Valid ROC AUC: 0.7162
# Early stopping triggered at depth: 8
# 최적 Depth: 7, 최종 Train ROC AUC: 0.7190, 최종 Valid ROC AUC: 0.7167
#
# === Ensemble Model 40/500 ===
# Depth: 1, Train ROC AUC: 0.5981, Valid ROC AUC: 0.5966
# Depth: 2, Train ROC AUC: 0.6637, Valid ROC AUC: 0.6637
# Depth: 3, Train ROC AUC: 0.6911, Valid ROC AUC: 0.6913
# Depth: 4, Train ROC AUC: 0.7030, Valid ROC AUC: 0.7006
# Depth: 5, Train ROC AUC: 0.7110, Valid ROC AUC: 0.7092
# Depth: 6, Train ROC AUC: 0.7157, Valid ROC AUC: 0.7129
# Depth: 7, Train ROC AUC: 0.7191, Valid ROC AUC: 0.7160
# Depth: 8, Train ROC AUC: 0.7220, Valid ROC AUC: 0.7152
# Early stopping triggered at depth: 8
# 최적 Depth: 7, 최종 Train ROC AUC: 0.7191, 최종 Valid ROC AUC: 0.7160
#
# === Ensemble Model 41/500 ===
# Depth: 1, Train ROC AUC: 0.5976, Valid ROC AUC: 0.5984
# Depth: 2, Train ROC AUC: 0.6634, Valid ROC AUC: 0.6650
# Depth: 3, Train ROC AUC: 0.6910, Valid ROC AUC: 0.6918
# Depth: 4, Train ROC AUC: 0.7026, Valid ROC AUC: 0.7026
# Depth: 5, Train ROC AUC: 0.7103, Valid ROC AUC: 0.7121
# Depth: 6, Train ROC AUC: 0.7151, Valid ROC AUC: 0.7161
# Depth: 7, Train ROC AUC: 0.7185, Valid ROC AUC: 0.7183
# Depth: 8, Train ROC AUC: 0.7213, Valid ROC AUC: 0.7174
# Early stopping triggered at depth: 8
# 최적 Depth: 7, 최종 Train ROC AUC: 0.7185, 최종 Valid ROC AUC: 0.7183
#
# === Ensemble Model 42/500 ===
# Depth: 1, Train ROC AUC: 0.5980, Valid ROC AUC: 0.5970
# Depth: 2, Train ROC AUC: 0.6651, Valid ROC AUC: 0.6634
# Depth: 3, Train ROC AUC: 0.6909, Valid ROC AUC: 0.6897
# Depth: 4, Train ROC AUC: 0.7028, Valid ROC AUC: 0.7016
# Depth: 5, Train ROC AUC: 0.7108, Valid ROC AUC: 0.7099
# Depth: 6, Train ROC AUC: 0.7157, Valid ROC AUC: 0.7143
# Depth: 7, Train ROC AUC: 0.7188, Valid ROC AUC: 0.7172
# Depth: 8, Train ROC AUC: 0.7215, Valid ROC AUC: 0.7166
# Early stopping triggered at depth: 8
# 최적 Depth: 7, 최종 Train ROC AUC: 0.7188, 최종 Valid ROC AUC: 0.7172
#
# === Ensemble Model 43/500 ===
# Depth: 1, Train ROC AUC: 0.5978, Valid ROC AUC: 0.5977
# Depth: 2, Train ROC AUC: 0.6637, Valid ROC AUC: 0.6639
# Depth: 3, Train ROC AUC: 0.6912, Valid ROC AUC: 0.6910
# Depth: 4, Train ROC AUC: 0.7026, Valid ROC AUC: 0.7026
# Depth: 5, Train ROC AUC: 0.7105, Valid ROC AUC: 0.7113
# Depth: 6, Train ROC AUC: 0.7154, Valid ROC AUC: 0.7151
# Depth: 7, Train ROC AUC: 0.7187, Valid ROC AUC: 0.7181
# Depth: 8, Train ROC AUC: 0.7216, Valid ROC AUC: 0.7185
# Depth: 9, Train ROC AUC: 0.7248, Valid ROC AUC: 0.7182
# Early stopping triggered at depth: 9
# 최적 Depth: 8, 최종 Train ROC AUC: 0.7216, 최종 Valid ROC AUC: 0.7185
#
# === Ensemble Model 44/500 ===
# Depth: 1, Train ROC AUC: 0.5973, Valid ROC AUC: 0.5995
# Depth: 2, Train ROC AUC: 0.6627, Valid ROC AUC: 0.6680
# Depth: 3, Train ROC AUC: 0.6898, Valid ROC AUC: 0.6966
# Depth: 4, Train ROC AUC: 0.7013, Valid ROC AUC: 0.7077
# Depth: 5, Train ROC AUC: 0.7093, Valid ROC AUC: 0.7159
# Depth: 6, Train ROC AUC: 0.7141, Valid ROC AUC: 0.7201
# Depth: 7, Train ROC AUC: 0.7176, Valid ROC AUC: 0.7224
# Depth: 8, Train ROC AUC: 0.7203, Valid ROC AUC: 0.7223
# Early stopping triggered at depth: 8
# 최적 Depth: 7, 최종 Train ROC AUC: 0.7176, 최종 Valid ROC AUC: 0.7224
#
# === Ensemble Model 45/500 ===
# Depth: 1, Train ROC AUC: 0.5976, Valid ROC AUC: 0.5984
# Depth: 2, Train ROC AUC: 0.6640, Valid ROC AUC: 0.6629
# Depth: 3, Train ROC AUC: 0.6914, Valid ROC AUC: 0.6902
# Depth: 4, Train ROC AUC: 0.7025, Valid ROC AUC: 0.7030
# Depth: 5, Train ROC AUC: 0.7106, Valid ROC AUC: 0.7113
# Depth: 6, Train ROC AUC: 0.7152, Valid ROC AUC: 0.7154
# Depth: 7, Train ROC AUC: 0.7188, Valid ROC AUC: 0.7183
# Depth: 8, Train ROC AUC: 0.7217, Valid ROC AUC: 0.7185
# Depth: 9, Train ROC AUC: 0.7250, Valid ROC AUC: 0.7187
# Depth: 10, Train ROC AUC: 0.7291, Valid ROC AUC: 0.7176
# Early stopping triggered at depth: 10
# 최적 Depth: 9, 최종 Train ROC AUC: 0.7250, 최종 Valid ROC AUC: 0.7187
#
# === Ensemble Model 46/500 ===
# Depth: 1, Train ROC AUC: 0.5976, Valid ROC AUC: 0.5986
# Depth: 2, Train ROC AUC: 0.6642, Valid ROC AUC: 0.6671
# Depth: 3, Train ROC AUC: 0.6906, Valid ROC AUC: 0.6913
# Depth: 4, Train ROC AUC: 0.7035, Valid ROC AUC: 0.7043
# Depth: 5, Train ROC AUC: 0.7108, Valid ROC AUC: 0.7097
# Depth: 6, Train ROC AUC: 0.7155, Valid ROC AUC: 0.7155
# Depth: 7, Train ROC AUC: 0.7188, Valid ROC AUC: 0.7178
# Depth: 8, Train ROC AUC: 0.7216, Valid ROC AUC: 0.7187
# Depth: 9, Train ROC AUC: 0.7250, Valid ROC AUC: 0.7187
# Early stopping triggered at depth: 9
# 최적 Depth: 8, 최종 Train ROC AUC: 0.7216, 최종 Valid ROC AUC: 0.7187
#
# === Ensemble Model 47/500 ===
# Depth: 1, Train ROC AUC: 0.5981, Valid ROC AUC: 0.5964
# Depth: 2, Train ROC AUC: 0.6638, Valid ROC AUC: 0.6637
# Depth: 3, Train ROC AUC: 0.6911, Valid ROC AUC: 0.6912
# Depth: 4, Train ROC AUC: 0.7027, Valid ROC AUC: 0.7021
# Depth: 5, Train ROC AUC: 0.7108, Valid ROC AUC: 0.7098
# Depth: 6, Train ROC AUC: 0.7155, Valid ROC AUC: 0.7146
# Depth: 7, Train ROC AUC: 0.7189, Valid ROC AUC: 0.7173
# Depth: 8, Train ROC AUC: 0.7218, Valid ROC AUC: 0.7161
# Early stopping triggered at depth: 8
# 최적 Depth: 7, 최종 Train ROC AUC: 0.7189, 최종 Valid ROC AUC: 0.7173
#
# === Ensemble Model 48/500 ===
# Depth: 1, Train ROC AUC: 0.5979, Valid ROC AUC: 0.5975
# Depth: 2, Train ROC AUC: 0.6649, Valid ROC AUC: 0.6642
# Depth: 3, Train ROC AUC: 0.6909, Valid ROC AUC: 0.6902
# Depth: 4, Train ROC AUC: 0.7037, Valid ROC AUC: 0.7021
# Depth: 5, Train ROC AUC: 0.7107, Valid ROC AUC: 0.7091
# Depth: 6, Train ROC AUC: 0.7157, Valid ROC AUC: 0.7139
# Depth: 7, Train ROC AUC: 0.7191, Valid ROC AUC: 0.7156
# Depth: 8, Train ROC AUC: 0.7222, Valid ROC AUC: 0.7164
# Depth: 9, Train ROC AUC: 0.7254, Valid ROC AUC: 0.7158
# Early stopping triggered at depth: 9
# 최적 Depth: 8, 최종 Train ROC AUC: 0.7222, 최종 Valid ROC AUC: 0.7164
#
# === Ensemble Model 49/500 ===
# Depth: 1, Train ROC AUC: 0.5977, Valid ROC AUC: 0.5980
# Depth: 2, Train ROC AUC: 0.6632, Valid ROC AUC: 0.6659
# Depth: 3, Train ROC AUC: 0.6909, Valid ROC AUC: 0.6922
# Depth: 4, Train ROC AUC: 0.7023, Valid ROC AUC: 0.7037
# Depth: 5, Train ROC AUC: 0.7104, Valid ROC AUC: 0.7117
# Depth: 6, Train ROC AUC: 0.7150, Valid ROC AUC: 0.7159
# Depth: 7, Train ROC AUC: 0.7185, Valid ROC AUC: 0.7189
# Depth: 8, Train ROC AUC: 0.7213, Valid ROC AUC: 0.7180
# Early stopping triggered at depth: 8
# 최적 Depth: 7, 최종 Train ROC AUC: 0.7185, 최종 Valid ROC AUC: 0.7189
#
# === Ensemble Model 50/500 ===
# Depth: 1, Train ROC AUC: 0.5982, Valid ROC AUC: 0.5963
# Depth: 2, Train ROC AUC: 0.6635, Valid ROC AUC: 0.6645
# Depth: 3, Train ROC AUC: 0.6906, Valid ROC AUC: 0.6933
# Depth: 4, Train ROC AUC: 0.7019, Valid ROC AUC: 0.7054
# Depth: 5, Train ROC AUC: 0.7098, Valid ROC AUC: 0.7138
# Depth: 6, Train ROC AUC: 0.7147, Valid ROC AUC: 0.7177
# Depth: 7, Train ROC AUC: 0.7182, Valid ROC AUC: 0.7201
# Depth: 8, Train ROC AUC: 0.7209, Valid ROC AUC: 0.7204
# Depth: 9, Train ROC AUC: 0.7242, Valid ROC AUC: 0.7201
# Early stopping triggered at depth: 9
# 최적 Depth: 8, 최종 Train ROC AUC: 0.7209, 최종 Valid ROC AUC: 0.7204
#
# === Ensemble Model 51/500 ===
# Depth: 1, Train ROC AUC: 0.5976, Valid ROC AUC: 0.5983
# Depth: 2, Train ROC AUC: 0.6650, Valid ROC AUC: 0.6640
# Depth: 3, Train ROC AUC: 0.6908, Valid ROC AUC: 0.6902
# Depth: 4, Train ROC AUC: 0.7028, Valid ROC AUC: 0.7018
# Depth: 5, Train ROC AUC: 0.7108, Valid ROC AUC: 0.7099
# Depth: 6, Train ROC AUC: 0.7157, Valid ROC AUC: 0.7145
# Depth: 7, Train ROC AUC: 0.7190, Valid ROC AUC: 0.7166
# Depth: 8, Train ROC AUC: 0.7217, Valid ROC AUC: 0.7173
# Depth: 9, Train ROC AUC: 0.7247, Valid ROC AUC: 0.7165
# Early stopping triggered at depth: 9
# 최적 Depth: 8, 최종 Train ROC AUC: 0.7217, 최종 Valid ROC AUC: 0.7173
#
# === Ensemble Model 52/500 ===
# Depth: 1, Train ROC AUC: 0.5980, Valid ROC AUC: 0.5969
# Depth: 2, Train ROC AUC: 0.6638, Valid ROC AUC: 0.6635
# Depth: 3, Train ROC AUC: 0.6911, Valid ROC AUC: 0.6915
# Depth: 4, Train ROC AUC: 0.7027, Valid ROC AUC: 0.7020
# Depth: 5, Train ROC AUC: 0.7109, Valid ROC AUC: 0.7094
# Depth: 6, Train ROC AUC: 0.7157, Valid ROC AUC: 0.7137
# Depth: 7, Train ROC AUC: 0.7191, Valid ROC AUC: 0.7160
# Depth: 8, Train ROC AUC: 0.7221, Valid ROC AUC: 0.7152
# Early stopping triggered at depth: 8
# 최적 Depth: 7, 최종 Train ROC AUC: 0.7191, 최종 Valid ROC AUC: 0.7160
#
# === Ensemble Model 53/500 ===
# Depth: 1, Train ROC AUC: 0.5983, Valid ROC AUC: 0.5956
# Depth: 2, Train ROC AUC: 0.6642, Valid ROC AUC: 0.6618
# Depth: 3, Train ROC AUC: 0.6909, Valid ROC AUC: 0.6921
# Depth: 4, Train ROC AUC: 0.7022, Valid ROC AUC: 0.7030
# Depth: 5, Train ROC AUC: 0.7104, Valid ROC AUC: 0.7118
# Depth: 6, Train ROC AUC: 0.7151, Valid ROC AUC: 0.7160
# Depth: 7, Train ROC AUC: 0.7186, Valid ROC AUC: 0.7194
# Depth: 8, Train ROC AUC: 0.7216, Valid ROC AUC: 0.7194
# Depth: 9, Train ROC AUC: 0.7250, Valid ROC AUC: 0.7185
# Early stopping triggered at depth: 9
# 최적 Depth: 8, 최종 Train ROC AUC: 0.7216, 최종 Valid ROC AUC: 0.7194
#
# === Ensemble Model 54/500 ===
# Depth: 1, Train ROC AUC: 0.5977, Valid ROC AUC: 0.5981
# Depth: 2, Train ROC AUC: 0.6640, Valid ROC AUC: 0.6626
# Depth: 3, Train ROC AUC: 0.6913, Valid ROC AUC: 0.6908
# Depth: 4, Train ROC AUC: 0.7026, Valid ROC AUC: 0.7025
# Depth: 5, Train ROC AUC: 0.7110, Valid ROC AUC: 0.7091
# Depth: 6, Train ROC AUC: 0.7158, Valid ROC AUC: 0.7138
# Depth: 7, Train ROC AUC: 0.7193, Valid ROC AUC: 0.7159
# Depth: 8, Train ROC AUC: 0.7222, Valid ROC AUC: 0.7159
# Early stopping triggered at depth: 8
# 최적 Depth: 7, 최종 Train ROC AUC: 0.7193, 최종 Valid ROC AUC: 0.7159
#
# === Ensemble Model 55/500 ===
# Depth: 1, Train ROC AUC: 0.5976, Valid ROC AUC: 0.5984
# Depth: 2, Train ROC AUC: 0.6640, Valid ROC AUC: 0.6626
# Depth: 3, Train ROC AUC: 0.6914, Valid ROC AUC: 0.6903
# Depth: 4, Train ROC AUC: 0.7028, Valid ROC AUC: 0.7016
# Depth: 5, Train ROC AUC: 0.7110, Valid ROC AUC: 0.7091
# Depth: 6, Train ROC AUC: 0.7154, Valid ROC AUC: 0.7136
# Depth: 7, Train ROC AUC: 0.7193, Valid ROC AUC: 0.7164
# Depth: 8, Train ROC AUC: 0.7221, Valid ROC AUC: 0.7158
# Early stopping triggered at depth: 8
# 최적 Depth: 7, 최종 Train ROC AUC: 0.7193, 최종 Valid ROC AUC: 0.7164
#
# === Ensemble Model 56/500 ===
# Depth: 1, Train ROC AUC: 0.5982, Valid ROC AUC: 0.5961
# Depth: 2, Train ROC AUC: 0.6647, Valid ROC AUC: 0.6600
# Depth: 3, Train ROC AUC: 0.6921, Valid ROC AUC: 0.6872
# Depth: 4, Train ROC AUC: 0.7035, Valid ROC AUC: 0.6989
# Depth: 5, Train ROC AUC: 0.7116, Valid ROC AUC: 0.7068
# Depth: 6, Train ROC AUC: 0.7165, Valid ROC AUC: 0.7105
# Depth: 7, Train ROC AUC: 0.7198, Valid ROC AUC: 0.7126
# Depth: 8, Train ROC AUC: 0.7226, Valid ROC AUC: 0.7125
# Early stopping triggered at depth: 8
# 최적 Depth: 7, 최종 Train ROC AUC: 0.7198, 최종 Valid ROC AUC: 0.7126
#
# === Ensemble Model 57/500 ===
# Depth: 1, Train ROC AUC: 0.5981, Valid ROC AUC: 0.5964
# Depth: 2, Train ROC AUC: 0.6637, Valid ROC AUC: 0.6640
# Depth: 3, Train ROC AUC: 0.6912, Valid ROC AUC: 0.6908
# Depth: 4, Train ROC AUC: 0.7027, Valid ROC AUC: 0.7020
# Depth: 5, Train ROC AUC: 0.7109, Valid ROC AUC: 0.7095
# Depth: 6, Train ROC AUC: 0.7156, Valid ROC AUC: 0.7139
# Depth: 7, Train ROC AUC: 0.7190, Valid ROC AUC: 0.7168
# Depth: 8, Train ROC AUC: 0.7218, Valid ROC AUC: 0.7154
# Early stopping triggered at depth: 8
# 최적 Depth: 7, 최종 Train ROC AUC: 0.7190, 최종 Valid ROC AUC: 0.7168
#
# === Ensemble Model 58/500 ===
# Depth: 1, Train ROC AUC: 0.5978, Valid ROC AUC: 0.5976
# Depth: 2, Train ROC AUC: 0.6637, Valid ROC AUC: 0.6637
# Depth: 3, Train ROC AUC: 0.6912, Valid ROC AUC: 0.6911
# Depth: 4, Train ROC AUC: 0.7028, Valid ROC AUC: 0.7019
# Depth: 5, Train ROC AUC: 0.7107, Valid ROC AUC: 0.7103
# Depth: 6, Train ROC AUC: 0.7152, Valid ROC AUC: 0.7147
# Depth: 7, Train ROC AUC: 0.7186, Valid ROC AUC: 0.7168
# Depth: 8, Train ROC AUC: 0.7215, Valid ROC AUC: 0.7182
# Depth: 9, Train ROC AUC: 0.7248, Valid ROC AUC: 0.7171
# Early stopping triggered at depth: 9
# 최적 Depth: 8, 최종 Train ROC AUC: 0.7215, 최종 Valid ROC AUC: 0.7182
#
# === Ensemble Model 59/500 ===
# Depth: 1, Train ROC AUC: 0.5977, Valid ROC AUC: 0.5981
# Depth: 2, Train ROC AUC: 0.6635, Valid ROC AUC: 0.6648
# Depth: 3, Train ROC AUC: 0.6906, Valid ROC AUC: 0.6936
# Depth: 4, Train ROC AUC: 0.7018, Valid ROC AUC: 0.7058
# Depth: 5, Train ROC AUC: 0.7097, Valid ROC AUC: 0.7144
# Depth: 6, Train ROC AUC: 0.7145, Valid ROC AUC: 0.7180
# Depth: 7, Train ROC AUC: 0.7180, Valid ROC AUC: 0.7203
# Depth: 8, Train ROC AUC: 0.7211, Valid ROC AUC: 0.7200
# Early stopping triggered at depth: 8
# 최적 Depth: 7, 최종 Train ROC AUC: 0.7180, 최종 Valid ROC AUC: 0.7203
#
# === Ensemble Model 60/500 ===
# Depth: 1, Train ROC AUC: 0.5979, Valid ROC AUC: 0.5975
# Depth: 2, Train ROC AUC: 0.6644, Valid ROC AUC: 0.6664
# Depth: 3, Train ROC AUC: 0.6907, Valid ROC AUC: 0.6911
# Depth: 4, Train ROC AUC: 0.7038, Valid ROC AUC: 0.7031
# Depth: 5, Train ROC AUC: 0.7100, Valid ROC AUC: 0.7094
# Depth: 6, Train ROC AUC: 0.7148, Valid ROC AUC: 0.7151
# Depth: 7, Train ROC AUC: 0.7179, Valid ROC AUC: 0.7188
# Depth: 8, Train ROC AUC: 0.7210, Valid ROC AUC: 0.7199
# Depth: 9, Train ROC AUC: 0.7245, Valid ROC AUC: 0.7177
# Early stopping triggered at depth: 9
# 최적 Depth: 8, 최종 Train ROC AUC: 0.7210, 최종 Valid ROC AUC: 0.7199
#
# === Ensemble Model 61/500 ===
# Depth: 1, Train ROC AUC: 0.5975, Valid ROC AUC: 0.5987
# Depth: 2, Train ROC AUC: 0.6640, Valid ROC AUC: 0.6627
# Depth: 3, Train ROC AUC: 0.6913, Valid ROC AUC: 0.6905
# Depth: 4, Train ROC AUC: 0.7028, Valid ROC AUC: 0.7016
# Depth: 5, Train ROC AUC: 0.7108, Valid ROC AUC: 0.7095
# Depth: 6, Train ROC AUC: 0.7156, Valid ROC AUC: 0.7137
# Depth: 7, Train ROC AUC: 0.7190, Valid ROC AUC: 0.7156
# Depth: 8, Train ROC AUC: 0.7220, Valid ROC AUC: 0.7155
# Early stopping triggered at depth: 8
# 최적 Depth: 7, 최종 Train ROC AUC: 0.7190, 최종 Valid ROC AUC: 0.7156
#
# === Ensemble Model 62/500 ===
# Depth: 1, Train ROC AUC: 0.5976, Valid ROC AUC: 0.5984
# Depth: 2, Train ROC AUC: 0.6649, Valid ROC AUC: 0.6645
# Depth: 3, Train ROC AUC: 0.6908, Valid ROC AUC: 0.6907
# Depth: 4, Train ROC AUC: 0.7042, Valid ROC AUC: 0.7040
# Depth: 5, Train ROC AUC: 0.7109, Valid ROC AUC: 0.7102
# Depth: 6, Train ROC AUC: 0.7153, Valid ROC AUC: 0.7151
# Depth: 7, Train ROC AUC: 0.7187, Valid ROC AUC: 0.7176
# Depth: 8, Train ROC AUC: 0.7216, Valid ROC AUC: 0.7182
# Depth: 9, Train ROC AUC: 0.7251, Valid ROC AUC: 0.7176
# Early stopping triggered at depth: 9
# 최적 Depth: 8, 최종 Train ROC AUC: 0.7216, 최종 Valid ROC AUC: 0.7182
#
# === Ensemble Model 63/500 ===
# Depth: 1, Train ROC AUC: 0.5976, Valid ROC AUC: 0.5983
# Depth: 2, Train ROC AUC: 0.6638, Valid ROC AUC: 0.6633
# Depth: 3, Train ROC AUC: 0.6915, Valid ROC AUC: 0.6896
# Depth: 4, Train ROC AUC: 0.7029, Valid ROC AUC: 0.7015
# Depth: 5, Train ROC AUC: 0.7109, Valid ROC AUC: 0.7095
# Depth: 6, Train ROC AUC: 0.7155, Valid ROC AUC: 0.7140
# Depth: 7, Train ROC AUC: 0.7192, Valid ROC AUC: 0.7161
# Depth: 8, Train ROC AUC: 0.7221, Valid ROC AUC: 0.7156
# Early stopping triggered at depth: 8
# 최적 Depth: 7, 최종 Train ROC AUC: 0.7192, 최종 Valid ROC AUC: 0.7161
#
# === Ensemble Model 64/500 ===
# Depth: 1, Train ROC AUC: 0.5977, Valid ROC AUC: 0.5981
# Depth: 2, Train ROC AUC: 0.6638, Valid ROC AUC: 0.6633
# Depth: 3, Train ROC AUC: 0.6910, Valid ROC AUC: 0.6916
# Depth: 4, Train ROC AUC: 0.7026, Valid ROC AUC: 0.7024
# Depth: 5, Train ROC AUC: 0.7106, Valid ROC AUC: 0.7105
# Depth: 6, Train ROC AUC: 0.7150, Valid ROC AUC: 0.7146
# Depth: 7, Train ROC AUC: 0.7189, Valid ROC AUC: 0.7167
# Depth: 8, Train ROC AUC: 0.7218, Valid ROC AUC: 0.7162
# Early stopping triggered at depth: 8
# 최적 Depth: 7, 최종 Train ROC AUC: 0.7189, 최종 Valid ROC AUC: 0.7167
#
# === Ensemble Model 65/500 ===
# Depth: 1, Train ROC AUC: 0.5981, Valid ROC AUC: 0.5965
# Depth: 2, Train ROC AUC: 0.6640, Valid ROC AUC: 0.6626
# Depth: 3, Train ROC AUC: 0.6907, Valid ROC AUC: 0.6930
# Depth: 4, Train ROC AUC: 0.7018, Valid ROC AUC: 0.7046
# Depth: 5, Train ROC AUC: 0.7096, Valid ROC AUC: 0.7135
# Depth: 6, Train ROC AUC: 0.7147, Valid ROC AUC: 0.7181
# Depth: 7, Train ROC AUC: 0.7183, Valid ROC AUC: 0.7206
# Depth: 8, Train ROC AUC: 0.7210, Valid ROC AUC: 0.7190
# Early stopping triggered at depth: 8
# 최적 Depth: 7, 최종 Train ROC AUC: 0.7183, 최종 Valid ROC AUC: 0.7206
#
# === Ensemble Model 66/500 ===
# Depth: 1, Train ROC AUC: 0.5973, Valid ROC AUC: 0.5996
# Depth: 2, Train ROC AUC: 0.6638, Valid ROC AUC: 0.6636
# Depth: 3, Train ROC AUC: 0.6909, Valid ROC AUC: 0.6923
# Depth: 4, Train ROC AUC: 0.7020, Valid ROC AUC: 0.7037
# Depth: 5, Train ROC AUC: 0.7101, Valid ROC AUC: 0.7122
# Depth: 6, Train ROC AUC: 0.7150, Valid ROC AUC: 0.7166
# Depth: 7, Train ROC AUC: 0.7183, Valid ROC AUC: 0.7193
# Depth: 8, Train ROC AUC: 0.7211, Valid ROC AUC: 0.7195
# Depth: 9, Train ROC AUC: 0.7244, Valid ROC AUC: 0.7193
# Early stopping triggered at depth: 9
# 최적 Depth: 8, 최종 Train ROC AUC: 0.7211, 최종 Valid ROC AUC: 0.7195
#
# === Ensemble Model 67/500 ===
# Depth: 1, Train ROC AUC: 0.5975, Valid ROC AUC: 0.5990
# Depth: 2, Train ROC AUC: 0.6648, Valid ROC AUC: 0.6648
# Depth: 3, Train ROC AUC: 0.6910, Valid ROC AUC: 0.6899
# Depth: 4, Train ROC AUC: 0.7035, Valid ROC AUC: 0.7044
# Depth: 5, Train ROC AUC: 0.7104, Valid ROC AUC: 0.7100
# Depth: 6, Train ROC AUC: 0.7152, Valid ROC AUC: 0.7151
# Depth: 7, Train ROC AUC: 0.7186, Valid ROC AUC: 0.7162
# Depth: 8, Train ROC AUC: 0.7217, Valid ROC AUC: 0.7156
# Early stopping triggered at depth: 8
# 최적 Depth: 7, 최종 Train ROC AUC: 0.7186, 최종 Valid ROC AUC: 0.7162
#
# === Ensemble Model 68/500 ===
# Depth: 1, Train ROC AUC: 0.5980, Valid ROC AUC: 0.5967
# Depth: 2, Train ROC AUC: 0.6633, Valid ROC AUC: 0.6654
# Depth: 3, Train ROC AUC: 0.6908, Valid ROC AUC: 0.6925
# Depth: 4, Train ROC AUC: 0.7023, Valid ROC AUC: 0.7035
# Depth: 5, Train ROC AUC: 0.7103, Valid ROC AUC: 0.7109
# Depth: 6, Train ROC AUC: 0.7151, Valid ROC AUC: 0.7157
# Depth: 7, Train ROC AUC: 0.7189, Valid ROC AUC: 0.7172
# Depth: 8, Train ROC AUC: 0.7217, Valid ROC AUC: 0.7167
# Early stopping triggered at depth: 8
# 최적 Depth: 7, 최종 Train ROC AUC: 0.7189, 최종 Valid ROC AUC: 0.7172
#
# === Ensemble Model 69/500 ===
# Depth: 1, Train ROC AUC: 0.5973, Valid ROC AUC: 0.5997
# Depth: 2, Train ROC AUC: 0.6633, Valid ROC AUC: 0.6656
# Depth: 3, Train ROC AUC: 0.6908, Valid ROC AUC: 0.6924
# Depth: 4, Train ROC AUC: 0.7022, Valid ROC AUC: 0.7041
# Depth: 5, Train ROC AUC: 0.7104, Valid ROC AUC: 0.7120
# Depth: 6, Train ROC AUC: 0.7153, Valid ROC AUC: 0.7160
# Depth: 7, Train ROC AUC: 0.7187, Valid ROC AUC: 0.7185
# Depth: 8, Train ROC AUC: 0.7216, Valid ROC AUC: 0.7179
# Early stopping triggered at depth: 8
# 최적 Depth: 7, 최종 Train ROC AUC: 0.7187, 최종 Valid ROC AUC: 0.7185
#
# === Ensemble Model 70/500 ===
# Depth: 1, Train ROC AUC: 0.5979, Valid ROC AUC: 0.5972
# Depth: 2, Train ROC AUC: 0.6645, Valid ROC AUC: 0.6606
# Depth: 3, Train ROC AUC: 0.6918, Valid ROC AUC: 0.6887
# Depth: 4, Train ROC AUC: 0.7025, Valid ROC AUC: 0.7027
# Depth: 5, Train ROC AUC: 0.7108, Valid ROC AUC: 0.7092
# Depth: 6, Train ROC AUC: 0.7157, Valid ROC AUC: 0.7133
# Depth: 7, Train ROC AUC: 0.7193, Valid ROC AUC: 0.7148
# Depth: 8, Train ROC AUC: 0.7222, Valid ROC AUC: 0.7153
# Depth: 9, Train ROC AUC: 0.7254, Valid ROC AUC: 0.7143
# Early stopping triggered at depth: 9
# 최적 Depth: 8, 최종 Train ROC AUC: 0.7222, 최종 Valid ROC AUC: 0.7153
#
# === Ensemble Model 71/500 ===
# Depth: 1, Train ROC AUC: 0.5974, Valid ROC AUC: 0.5992
# Depth: 2, Train ROC AUC: 0.6634, Valid ROC AUC: 0.6650
# Depth: 3, Train ROC AUC: 0.6908, Valid ROC AUC: 0.6927
# Depth: 4, Train ROC AUC: 0.7021, Valid ROC AUC: 0.7044
# Depth: 5, Train ROC AUC: 0.7103, Valid ROC AUC: 0.7118
# Depth: 6, Train ROC AUC: 0.7152, Valid ROC AUC: 0.7154
# Depth: 7, Train ROC AUC: 0.7186, Valid ROC AUC: 0.7181
# Depth: 8, Train ROC AUC: 0.7213, Valid ROC AUC: 0.7180
# Early stopping triggered at depth: 8
# 최적 Depth: 7, 최종 Train ROC AUC: 0.7186, 최종 Valid ROC AUC: 0.7181
#
# === Ensemble Model 72/500 ===
# Depth: 1, Train ROC AUC: 0.5979, Valid ROC AUC: 0.5974
# Depth: 2, Train ROC AUC: 0.6645, Valid ROC AUC: 0.6660
# Depth: 3, Train ROC AUC: 0.6903, Valid ROC AUC: 0.6926
# Depth: 4, Train ROC AUC: 0.7030, Valid ROC AUC: 0.7059
# Depth: 5, Train ROC AUC: 0.7100, Valid ROC AUC: 0.7122
# Depth: 6, Train ROC AUC: 0.7146, Valid ROC AUC: 0.7178
# Depth: 7, Train ROC AUC: 0.7182, Valid ROC AUC: 0.7193
# Depth: 8, Train ROC AUC: 0.7213, Valid ROC AUC: 0.7193
# Depth: 9, Train ROC AUC: 0.7245, Valid ROC AUC: 0.7180
# Early stopping triggered at depth: 9
# 최적 Depth: 8, 최종 Train ROC AUC: 0.7213, 최종 Valid ROC AUC: 0.7193
#
# === Ensemble Model 73/500 ===
# Depth: 1, Train ROC AUC: 0.5979, Valid ROC AUC: 0.5973
# Depth: 2, Train ROC AUC: 0.6638, Valid ROC AUC: 0.6636
# Depth: 3, Train ROC AUC: 0.6909, Valid ROC AUC: 0.6922
# Depth: 4, Train ROC AUC: 0.7024, Valid ROC AUC: 0.7035
# Depth: 5, Train ROC AUC: 0.7105, Valid ROC AUC: 0.7113
# Depth: 6, Train ROC AUC: 0.7154, Valid ROC AUC: 0.7150
# Depth: 7, Train ROC AUC: 0.7188, Valid ROC AUC: 0.7173
# Depth: 8, Train ROC AUC: 0.7218, Valid ROC AUC: 0.7171
# Early stopping triggered at depth: 8
# 최적 Depth: 7, 최종 Train ROC AUC: 0.7188, 최종 Valid ROC AUC: 0.7173
#
# === Ensemble Model 74/500 ===
# Depth: 1, Train ROC AUC: 0.5977, Valid ROC AUC: 0.5982
# Depth: 2, Train ROC AUC: 0.6652, Valid ROC AUC: 0.6633
# Depth: 3, Train ROC AUC: 0.6913, Valid ROC AUC: 0.6883
# Depth: 4, Train ROC AUC: 0.7043, Valid ROC AUC: 0.7036
# Depth: 5, Train ROC AUC: 0.7114, Valid ROC AUC: 0.7085
# Depth: 6, Train ROC AUC: 0.7160, Valid ROC AUC: 0.7123
# Depth: 7, Train ROC AUC: 0.7193, Valid ROC AUC: 0.7148
# Depth: 8, Train ROC AUC: 0.7222, Valid ROC AUC: 0.7147
# Early stopping triggered at depth: 8
# 최적 Depth: 7, 최종 Train ROC AUC: 0.7193, 최종 Valid ROC AUC: 0.7148
#
# === Ensemble Model 75/500 ===
# Depth: 1, Train ROC AUC: 0.5974, Valid ROC AUC: 0.5995
# Depth: 2, Train ROC AUC: 0.6633, Valid ROC AUC: 0.6653
# Depth: 3, Train ROC AUC: 0.6908, Valid ROC AUC: 0.6926
# Depth: 4, Train ROC AUC: 0.7023, Valid ROC AUC: 0.7036
# Depth: 5, Train ROC AUC: 0.7104, Valid ROC AUC: 0.7109
# Depth: 6, Train ROC AUC: 0.7150, Valid ROC AUC: 0.7156
# Depth: 7, Train ROC AUC: 0.7184, Valid ROC AUC: 0.7187
# Depth: 8, Train ROC AUC: 0.7211, Valid ROC AUC: 0.7190
# Depth: 9, Train ROC AUC: 0.7246, Valid ROC AUC: 0.7172
# Early stopping triggered at depth: 9
# 최적 Depth: 8, 최종 Train ROC AUC: 0.7211, 최종 Valid ROC AUC: 0.7190
#
# === Ensemble Model 76/500 ===
# Depth: 1, Train ROC AUC: 0.5975, Valid ROC AUC: 0.5989
# Depth: 2, Train ROC AUC: 0.6642, Valid ROC AUC: 0.6620
# Depth: 3, Train ROC AUC: 0.6912, Valid ROC AUC: 0.6911
# Depth: 4, Train ROC AUC: 0.7025, Valid ROC AUC: 0.7018
# Depth: 5, Train ROC AUC: 0.7109, Valid ROC AUC: 0.7100
# Depth: 6, Train ROC AUC: 0.7158, Valid ROC AUC: 0.7137
# Depth: 7, Train ROC AUC: 0.7190, Valid ROC AUC: 0.7169
# Depth: 8, Train ROC AUC: 0.7219, Valid ROC AUC: 0.7165
# Early stopping triggered at depth: 8
# 최적 Depth: 7, 최종 Train ROC AUC: 0.7190, 최종 Valid ROC AUC: 0.7169
#
# === Ensemble Model 77/500 ===
# Depth: 1, Train ROC AUC: 0.5978, Valid ROC AUC: 0.5979
# Depth: 2, Train ROC AUC: 0.6638, Valid ROC AUC: 0.6634
# Depth: 3, Train ROC AUC: 0.6911, Valid ROC AUC: 0.6914
# Depth: 4, Train ROC AUC: 0.7026, Valid ROC AUC: 0.7026
# Depth: 5, Train ROC AUC: 0.7107, Valid ROC AUC: 0.7104
# Depth: 6, Train ROC AUC: 0.7154, Valid ROC AUC: 0.7150
# Depth: 7, Train ROC AUC: 0.7191, Valid ROC AUC: 0.7165
# Depth: 8, Train ROC AUC: 0.7220, Valid ROC AUC: 0.7165
# Depth: 9, Train ROC AUC: 0.7252, Valid ROC AUC: 0.7160
# Early stopping triggered at depth: 9
# 최적 Depth: 8, 최종 Train ROC AUC: 0.7220, 최종 Valid ROC AUC: 0.7165
#
# === Ensemble Model 78/500 ===
# Depth: 1, Train ROC AUC: 0.5980, Valid ROC AUC: 0.5970
# Depth: 2, Train ROC AUC: 0.6647, Valid ROC AUC: 0.6600
# Depth: 3, Train ROC AUC: 0.6922, Valid ROC AUC: 0.6870
# Depth: 4, Train ROC AUC: 0.7034, Valid ROC AUC: 0.6993
# Depth: 5, Train ROC AUC: 0.7112, Valid ROC AUC: 0.7082
# Depth: 6, Train ROC AUC: 0.7159, Valid ROC AUC: 0.7115
# Depth: 7, Train ROC AUC: 0.7197, Valid ROC AUC: 0.7144
# Depth: 8, Train ROC AUC: 0.7225, Valid ROC AUC: 0.7135
# Early stopping triggered at depth: 8
# 최적 Depth: 7, 최종 Train ROC AUC: 0.7197, 최종 Valid ROC AUC: 0.7144
#
# === Ensemble Model 79/500 ===
# Depth: 1, Train ROC AUC: 0.5978, Valid ROC AUC: 0.5977
# Depth: 2, Train ROC AUC: 0.6634, Valid ROC AUC: 0.6650
# Depth: 3, Train ROC AUC: 0.6909, Valid ROC AUC: 0.6921
# Depth: 4, Train ROC AUC: 0.7025, Valid ROC AUC: 0.7028
# Depth: 5, Train ROC AUC: 0.7105, Valid ROC AUC: 0.7111
# Depth: 6, Train ROC AUC: 0.7154, Valid ROC AUC: 0.7144
# Depth: 7, Train ROC AUC: 0.7190, Valid ROC AUC: 0.7161
# Depth: 8, Train ROC AUC: 0.7220, Valid ROC AUC: 0.7152
# Early stopping triggered at depth: 8
# 최적 Depth: 7, 최종 Train ROC AUC: 0.7190, 최종 Valid ROC AUC: 0.7161
#
# === Ensemble Model 80/500 ===
# Depth: 1, Train ROC AUC: 0.5981, Valid ROC AUC: 0.5966
# Depth: 2, Train ROC AUC: 0.6637, Valid ROC AUC: 0.6639
# Depth: 3, Train ROC AUC: 0.6912, Valid ROC AUC: 0.6908
# Depth: 4, Train ROC AUC: 0.7026, Valid ROC AUC: 0.7025
# Depth: 5, Train ROC AUC: 0.7107, Valid ROC AUC: 0.7102
# Depth: 6, Train ROC AUC: 0.7154, Valid ROC AUC: 0.7130
# Depth: 7, Train ROC AUC: 0.7189, Valid ROC AUC: 0.7166
# Depth: 8, Train ROC AUC: 0.7217, Valid ROC AUC: 0.7163
# Early stopping triggered at depth: 8
# 최적 Depth: 7, 최종 Train ROC AUC: 0.7189, 최종 Valid ROC AUC: 0.7166
#
# === Ensemble Model 81/500 ===
# Depth: 1, Train ROC AUC: 0.5980, Valid ROC AUC: 0.5969
# Depth: 2, Train ROC AUC: 0.6641, Valid ROC AUC: 0.6622
# Depth: 3, Train ROC AUC: 0.6917, Valid ROC AUC: 0.6891
# Depth: 4, Train ROC AUC: 0.7033, Valid ROC AUC: 0.6998
# Depth: 5, Train ROC AUC: 0.7114, Valid ROC AUC: 0.7072
# Depth: 6, Train ROC AUC: 0.7162, Valid ROC AUC: 0.7112
# Depth: 7, Train ROC AUC: 0.7195, Valid ROC AUC: 0.7133
# Depth: 8, Train ROC AUC: 0.7225, Valid ROC AUC: 0.7144
# ...
# Depth: 8, Train ROC AUC: 0.7221, Valid ROC AUC: 0.7145
# Early stopping triggered at depth: 8
# 최적 Depth: 7, 최종 Train ROC AUC: 0.7194, 최종 Valid ROC AUC: 0.7149
#
# === Ensemble Model 475/500 ===
# Depth: 1, Train ROC AUC: 0.5978, Valid ROC AUC: 0.5979
# Depth: 2, Train ROC AUC: 0.6633, Valid ROC AUC: 0.6655
# Depth: 3, Train ROC AUC: 0.6905, Valid ROC AUC: 0.6937
# Depth: 4, Train ROC AUC: 0.7021, Valid ROC AUC: 0.7044
# Depth: 5, Train ROC AUC: 0.7102, Valid ROC AUC: 0.7125
# Depth: 6, Train ROC AUC: 0.7148, Valid ROC AUC: 0.7174
# Depth: 7, Train ROC AUC: 0.7182, Valid ROC AUC: 0.7197
# Depth: 8, Train ROC AUC: 0.7210, Valid ROC AUC: 0.7195
# Early stopping triggered at depth: 8
# 최적 Depth: 7, 최종 Train ROC AUC: 0.7182, 최종 Valid ROC AUC: 0.7197
#
# === Ensemble Model 476/500 ===
# Depth: 1, Train ROC AUC: 0.5978, Valid ROC AUC: 0.5977
# Depth: 2, Train ROC AUC: 0.6640, Valid ROC AUC: 0.6629
# Depth: 3, Train ROC AUC: 0.6914, Valid ROC AUC: 0.6902
# Depth: 4, Train ROC AUC: 0.7026, Valid ROC AUC: 0.7027
# Depth: 5, Train ROC AUC: 0.7106, Valid ROC AUC: 0.7107
# Depth: 6, Train ROC AUC: 0.7153, Valid ROC AUC: 0.7150
# Depth: 7, Train ROC AUC: 0.7188, Valid ROC AUC: 0.7171
# Depth: 8, Train ROC AUC: 0.7216, Valid ROC AUC: 0.7164
# Early stopping triggered at depth: 8
# 최적 Depth: 7, 최종 Train ROC AUC: 0.7188, 최종 Valid ROC AUC: 0.7171
#
# === Ensemble Model 477/500 ===
# Depth: 1, Train ROC AUC: 0.5974, Valid ROC AUC: 0.5992
# Depth: 2, Train ROC AUC: 0.6638, Valid ROC AUC: 0.6634
# Depth: 3, Train ROC AUC: 0.6911, Valid ROC AUC: 0.6913
# Depth: 4, Train ROC AUC: 0.7023, Valid ROC AUC: 0.7036
# Depth: 5, Train ROC AUC: 0.7105, Valid ROC AUC: 0.7113
# Depth: 6, Train ROC AUC: 0.7155, Valid ROC AUC: 0.7145
# Depth: 7, Train ROC AUC: 0.7191, Valid ROC AUC: 0.7164
# Depth: 8, Train ROC AUC: 0.7218, Valid ROC AUC: 0.7156
# Early stopping triggered at depth: 8
# 최적 Depth: 7, 최종 Train ROC AUC: 0.7191, 최종 Valid ROC AUC: 0.7164
#
# === Ensemble Model 478/500 ===
# Depth: 1, Train ROC AUC: 0.5980, Valid ROC AUC: 0.5969
# Depth: 2, Train ROC AUC: 0.6642, Valid ROC AUC: 0.6619
# Depth: 3, Train ROC AUC: 0.6915, Valid ROC AUC: 0.6898
# Depth: 4, Train ROC AUC: 0.7027, Valid ROC AUC: 0.7022
# Depth: 5, Train ROC AUC: 0.7110, Valid ROC AUC: 0.7091
# Depth: 6, Train ROC AUC: 0.7157, Valid ROC AUC: 0.7127
# Depth: 7, Train ROC AUC: 0.7192, Valid ROC AUC: 0.7153
# Depth: 8, Train ROC AUC: 0.7221, Valid ROC AUC: 0.7152
# Early stopping triggered at depth: 8
# 최적 Depth: 7, 최종 Train ROC AUC: 0.7192, 최종 Valid ROC AUC: 0.7153
#
# === Ensemble Model 479/500 ===
# Depth: 1, Train ROC AUC: 0.5979, Valid ROC AUC: 0.5975
# Depth: 2, Train ROC AUC: 0.6634, Valid ROC AUC: 0.6650
# Depth: 3, Train ROC AUC: 0.6908, Valid ROC AUC: 0.6925
# Depth: 4, Train ROC AUC: 0.7022, Valid ROC AUC: 0.7042
# Depth: 5, Train ROC AUC: 0.7106, Valid ROC AUC: 0.7107
# Depth: 6, Train ROC AUC: 0.7156, Valid ROC AUC: 0.7142
# Depth: 7, Train ROC AUC: 0.7190, Valid ROC AUC: 0.7170
# Depth: 8, Train ROC AUC: 0.7218, Valid ROC AUC: 0.7173
# Depth: 9, Train ROC AUC: 0.7252, Valid ROC AUC: 0.7171
# Early stopping triggered at depth: 9
# 최적 Depth: 8, 최종 Train ROC AUC: 0.7218, 최종 Valid ROC AUC: 0.7173
#
# === Ensemble Model 480/500 ===
# Depth: 1, Train ROC AUC: 0.5980, Valid ROC AUC: 0.5968
# Depth: 2, Train ROC AUC: 0.6647, Valid ROC AUC: 0.6651
# Depth: 3, Train ROC AUC: 0.6912, Valid ROC AUC: 0.6891
# Depth: 4, Train ROC AUC: 0.7038, Valid ROC AUC: 0.7010
# Depth: 5, Train ROC AUC: 0.7111, Valid ROC AUC: 0.7069
# Depth: 6, Train ROC AUC: 0.7164, Valid ROC AUC: 0.7114
# Depth: 7, Train ROC AUC: 0.7195, Valid ROC AUC: 0.7142
# Depth: 8, Train ROC AUC: 0.7225, Valid ROC AUC: 0.7154
# Depth: 9, Train ROC AUC: 0.7257, Valid ROC AUC: 0.7144
# Early stopping triggered at depth: 9
# 최적 Depth: 8, 최종 Train ROC AUC: 0.7225, 최종 Valid ROC AUC: 0.7154
#
# === Ensemble Model 481/500 ===
# Depth: 1, Train ROC AUC: 0.5978, Valid ROC AUC: 0.5978
# Depth: 2, Train ROC AUC: 0.6631, Valid ROC AUC: 0.6661
# Depth: 3, Train ROC AUC: 0.6907, Valid ROC AUC: 0.6931
# Depth: 4, Train ROC AUC: 0.7023, Valid ROC AUC: 0.7036
# Depth: 5, Train ROC AUC: 0.7105, Valid ROC AUC: 0.7114
# Depth: 6, Train ROC AUC: 0.7152, Valid ROC AUC: 0.7154
# Depth: 7, Train ROC AUC: 0.7186, Valid ROC AUC: 0.7179
# Depth: 8, Train ROC AUC: 0.7214, Valid ROC AUC: 0.7175
# Early stopping triggered at depth: 8
# 최적 Depth: 7, 최종 Train ROC AUC: 0.7186, 최종 Valid ROC AUC: 0.7179
#
# === Ensemble Model 482/500 ===
# Depth: 1, Train ROC AUC: 0.5978, Valid ROC AUC: 0.5976
# Depth: 2, Train ROC AUC: 0.6637, Valid ROC AUC: 0.6641
# Depth: 3, Train ROC AUC: 0.6912, Valid ROC AUC: 0.6911
# Depth: 4, Train ROC AUC: 0.7027, Valid ROC AUC: 0.7019
# Depth: 5, Train ROC AUC: 0.7105, Valid ROC AUC: 0.7102
# Depth: 6, Train ROC AUC: 0.7151, Valid ROC AUC: 0.7136
# Depth: 7, Train ROC AUC: 0.7190, Valid ROC AUC: 0.7162
# Depth: 8, Train ROC AUC: 0.7215, Valid ROC AUC: 0.7163
# Depth: 9, Train ROC AUC: 0.7247, Valid ROC AUC: 0.7173
# Depth: 10, Train ROC AUC: 0.7285, Valid ROC AUC: 0.7158
# Early stopping triggered at depth: 10
# 최적 Depth: 9, 최종 Train ROC AUC: 0.7247, 최종 Valid ROC AUC: 0.7173
#
# === Ensemble Model 483/500 ===
# Depth: 1, Train ROC AUC: 0.5976, Valid ROC AUC: 0.5984
# Depth: 2, Train ROC AUC: 0.6635, Valid ROC AUC: 0.6648
# Depth: 3, Train ROC AUC: 0.6910, Valid ROC AUC: 0.6918
# Depth: 4, Train ROC AUC: 0.7023, Valid ROC AUC: 0.7036
# Depth: 5, Train ROC AUC: 0.7103, Valid ROC AUC: 0.7113
# Depth: 6, Train ROC AUC: 0.7151, Valid ROC AUC: 0.7149
# Depth: 7, Train ROC AUC: 0.7189, Valid ROC AUC: 0.7165
# Depth: 8, Train ROC AUC: 0.7217, Valid ROC AUC: 0.7159
# Early stopping triggered at depth: 8
# 최적 Depth: 7, 최종 Train ROC AUC: 0.7189, 최종 Valid ROC AUC: 0.7165
#
# === Ensemble Model 484/500 ===
# Depth: 1, Train ROC AUC: 0.5973, Valid ROC AUC: 0.5996
# Depth: 2, Train ROC AUC: 0.6641, Valid ROC AUC: 0.6624
# Depth: 3, Train ROC AUC: 0.6919, Valid ROC AUC: 0.6882
# Depth: 4, Train ROC AUC: 0.7033, Valid ROC AUC: 0.6998
# Depth: 5, Train ROC AUC: 0.7114, Valid ROC AUC: 0.7078
# Depth: 6, Train ROC AUC: 0.7162, Valid ROC AUC: 0.7117
# Depth: 7, Train ROC AUC: 0.7198, Valid ROC AUC: 0.7142
# Depth: 8, Train ROC AUC: 0.7226, Valid ROC AUC: 0.7145
# Depth: 9, Train ROC AUC: 0.7260, Valid ROC AUC: 0.7149
# Depth: 10, Train ROC AUC: 0.7301, Valid ROC AUC: 0.7124
# Early stopping triggered at depth: 10
# 최적 Depth: 9, 최종 Train ROC AUC: 0.7260, 최종 Valid ROC AUC: 0.7149
#
# === Ensemble Model 485/500 ===
# Depth: 1, Train ROC AUC: 0.5977, Valid ROC AUC: 0.5983
# Depth: 2, Train ROC AUC: 0.6642, Valid ROC AUC: 0.6619
# Depth: 3, Train ROC AUC: 0.6911, Valid ROC AUC: 0.6913
# Depth: 4, Train ROC AUC: 0.7022, Valid ROC AUC: 0.7027
# Depth: 5, Train ROC AUC: 0.7105, Valid ROC AUC: 0.7117
# Depth: 6, Train ROC AUC: 0.7153, Valid ROC AUC: 0.7162
# Depth: 7, Train ROC AUC: 0.7187, Valid ROC AUC: 0.7184
# Depth: 8, Train ROC AUC: 0.7216, Valid ROC AUC: 0.7176
# Early stopping triggered at depth: 8
# 최적 Depth: 7, 최종 Train ROC AUC: 0.7187, 최종 Valid ROC AUC: 0.7184
#
# === Ensemble Model 486/500 ===
# Depth: 1, Train ROC AUC: 0.5977, Valid ROC AUC: 0.5981
# Depth: 2, Train ROC AUC: 0.6633, Valid ROC AUC: 0.6656
# Depth: 3, Train ROC AUC: 0.6906, Valid ROC AUC: 0.6934
# Depth: 4, Train ROC AUC: 0.7019, Valid ROC AUC: 0.7053
# Depth: 5, Train ROC AUC: 0.7098, Valid ROC AUC: 0.7140
# Depth: 6, Train ROC AUC: 0.7150, Valid ROC AUC: 0.7167
# Depth: 7, Train ROC AUC: 0.7186, Valid ROC AUC: 0.7190
# Depth: 8, Train ROC AUC: 0.7215, Valid ROC AUC: 0.7173
# Early stopping triggered at depth: 8
# 최적 Depth: 7, 최종 Train ROC AUC: 0.7186, 최종 Valid ROC AUC: 0.7190
#
# === Ensemble Model 487/500 ===
# Depth: 1, Train ROC AUC: 0.5981, Valid ROC AUC: 0.5966
# Depth: 2, Train ROC AUC: 0.6637, Valid ROC AUC: 0.6638
# Depth: 3, Train ROC AUC: 0.6909, Valid ROC AUC: 0.6923
# Depth: 4, Train ROC AUC: 0.7024, Valid ROC AUC: 0.7034
# Depth: 5, Train ROC AUC: 0.7103, Valid ROC AUC: 0.7119
# Depth: 6, Train ROC AUC: 0.7150, Valid ROC AUC: 0.7167
# Depth: 7, Train ROC AUC: 0.7186, Valid ROC AUC: 0.7193
# Depth: 8, Train ROC AUC: 0.7215, Valid ROC AUC: 0.7184
# Early stopping triggered at depth: 8
# 최적 Depth: 7, 최종 Train ROC AUC: 0.7186, 최종 Valid ROC AUC: 0.7193
#
# === Ensemble Model 488/500 ===
# Depth: 1, Train ROC AUC: 0.5981, Valid ROC AUC: 0.5965
# Depth: 2, Train ROC AUC: 0.6658, Valid ROC AUC: 0.6608
# Depth: 3, Train ROC AUC: 0.6917, Valid ROC AUC: 0.6866
# Depth: 4, Train ROC AUC: 0.7041, Valid ROC AUC: 0.6965
# Depth: 5, Train ROC AUC: 0.7124, Valid ROC AUC: 0.7043
# Depth: 6, Train ROC AUC: 0.7171, Valid ROC AUC: 0.7084
# Depth: 7, Train ROC AUC: 0.7207, Valid ROC AUC: 0.7098
# Depth: 8, Train ROC AUC: 0.7235, Valid ROC AUC: 0.7101
# Depth: 9, Train ROC AUC: 0.7264, Valid ROC AUC: 0.7091
# Early stopping triggered at depth: 9
# 최적 Depth: 8, 최종 Train ROC AUC: 0.7235, 최종 Valid ROC AUC: 0.7101
#
# === Ensemble Model 489/500 ===
# Depth: 1, Train ROC AUC: 0.5975, Valid ROC AUC: 0.5991
# Depth: 2, Train ROC AUC: 0.6634, Valid ROC AUC: 0.6650
# Depth: 3, Train ROC AUC: 0.6907, Valid ROC AUC: 0.6929
# Depth: 4, Train ROC AUC: 0.7021, Valid ROC AUC: 0.7043
# Depth: 5, Train ROC AUC: 0.7103, Valid ROC AUC: 0.7122
# Depth: 6, Train ROC AUC: 0.7153, Valid ROC AUC: 0.7159
# Depth: 7, Train ROC AUC: 0.7188, Valid ROC AUC: 0.7185
# Depth: 8, Train ROC AUC: 0.7214, Valid ROC AUC: 0.7187
# Depth: 9, Train ROC AUC: 0.7247, Valid ROC AUC: 0.7187
# Early stopping triggered at depth: 9
# 최적 Depth: 8, 최종 Train ROC AUC: 0.7214, 최종 Valid ROC AUC: 0.7187
#
# === Ensemble Model 490/500 ===
# Depth: 1, Train ROC AUC: 0.5980, Valid ROC AUC: 0.5969
# Depth: 2, Train ROC AUC: 0.6644, Valid ROC AUC: 0.6612
# Depth: 3, Train ROC AUC: 0.6916, Valid ROC AUC: 0.6893
# Depth: 4, Train ROC AUC: 0.7026, Valid ROC AUC: 0.7024
# Depth: 5, Train ROC AUC: 0.7108, Valid ROC AUC: 0.7099
# Depth: 6, Train ROC AUC: 0.7153, Valid ROC AUC: 0.7146
# Depth: 7, Train ROC AUC: 0.7192, Valid ROC AUC: 0.7154
# Depth: 8, Train ROC AUC: 0.7221, Valid ROC AUC: 0.7151
# Early stopping triggered at depth: 8
# 최적 Depth: 7, 최종 Train ROC AUC: 0.7192, 최종 Valid ROC AUC: 0.7154
#
# === Ensemble Model 491/500 ===
# Depth: 1, Train ROC AUC: 0.5974, Valid ROC AUC: 0.5995
# Depth: 2, Train ROC AUC: 0.6630, Valid ROC AUC: 0.6666
# Depth: 3, Train ROC AUC: 0.6906, Valid ROC AUC: 0.6932
# Depth: 4, Train ROC AUC: 0.7022, Valid ROC AUC: 0.7040
# Depth: 5, Train ROC AUC: 0.7104, Valid ROC AUC: 0.7117
# Depth: 6, Train ROC AUC: 0.7153, Valid ROC AUC: 0.7155
# Depth: 7, Train ROC AUC: 0.7187, Valid ROC AUC: 0.7180
# Depth: 8, Train ROC AUC: 0.7215, Valid ROC AUC: 0.7175
# Early stopping triggered at depth: 8
# 최적 Depth: 7, 최종 Train ROC AUC: 0.7187, 최종 Valid ROC AUC: 0.7180
#
# === Ensemble Model 492/500 ===
# Depth: 1, Train ROC AUC: 0.5974, Valid ROC AUC: 0.5992
# Depth: 2, Train ROC AUC: 0.6641, Valid ROC AUC: 0.6624
# Depth: 3, Train ROC AUC: 0.6913, Valid ROC AUC: 0.6904
# Depth: 4, Train ROC AUC: 0.7026, Valid ROC AUC: 0.7027
# Depth: 5, Train ROC AUC: 0.7109, Valid ROC AUC: 0.7094
# Depth: 6, Train ROC AUC: 0.7159, Valid ROC AUC: 0.7127
# Depth: 7, Train ROC AUC: 0.7191, Valid ROC AUC: 0.7161
# Depth: 8, Train ROC AUC: 0.7218, Valid ROC AUC: 0.7169
# Depth: 9, Train ROC AUC: 0.7251, Valid ROC AUC: 0.7164
# Early stopping triggered at depth: 9
# 최적 Depth: 8, 최종 Train ROC AUC: 0.7218, 최종 Valid ROC AUC: 0.7169
#
# === Ensemble Model 493/500 ===
# Depth: 1, Train ROC AUC: 0.5981, Valid ROC AUC: 0.5967
# Depth: 2, Train ROC AUC: 0.6651, Valid ROC AUC: 0.6636
# Depth: 3, Train ROC AUC: 0.6907, Valid ROC AUC: 0.6908
# Depth: 4, Train ROC AUC: 0.7036, Valid ROC AUC: 0.7036
# Depth: 5, Train ROC AUC: 0.7104, Valid ROC AUC: 0.7099
# Depth: 6, Train ROC AUC: 0.7154, Valid ROC AUC: 0.7150
# Depth: 7, Train ROC AUC: 0.7185, Valid ROC AUC: 0.7173
# Depth: 8, Train ROC AUC: 0.7216, Valid ROC AUC: 0.7182
# Depth: 9, Train ROC AUC: 0.7247, Valid ROC AUC: 0.7167
# Early stopping triggered at depth: 9
# 최적 Depth: 8, 최종 Train ROC AUC: 0.7216, 최종 Valid ROC AUC: 0.7182
#
# === Ensemble Model 494/500 ===
# Depth: 1, Train ROC AUC: 0.5974, Valid ROC AUC: 0.5993
# Depth: 2, Train ROC AUC: 0.6643, Valid ROC AUC: 0.6616
# Depth: 3, Train ROC AUC: 0.6918, Valid ROC AUC: 0.6885
# Depth: 4, Train ROC AUC: 0.7030, Valid ROC AUC: 0.7009
# Depth: 5, Train ROC AUC: 0.7111, Valid ROC AUC: 0.7085
# Depth: 6, Train ROC AUC: 0.7159, Valid ROC AUC: 0.7123
# Depth: 7, Train ROC AUC: 0.7194, Valid ROC AUC: 0.7148
# Depth: 8, Train ROC AUC: 0.7223, Valid ROC AUC: 0.7143
# Early stopping triggered at depth: 8
# 최적 Depth: 7, 최종 Train ROC AUC: 0.7194, 최종 Valid ROC AUC: 0.7148
#
# === Ensemble Model 495/500 ===
# Depth: 1, Train ROC AUC: 0.5979, Valid ROC AUC: 0.5972
# Depth: 2, Train ROC AUC: 0.6642, Valid ROC AUC: 0.6620
# Depth: 3, Train ROC AUC: 0.6920, Valid ROC AUC: 0.6879
# Depth: 4, Train ROC AUC: 0.7036, Valid ROC AUC: 0.6984
# Depth: 5, Train ROC AUC: 0.7116, Valid ROC AUC: 0.7068
# Depth: 6, Train ROC AUC: 0.7163, Valid ROC AUC: 0.7113
# Depth: 7, Train ROC AUC: 0.7197, Valid ROC AUC: 0.7145
# Depth: 8, Train ROC AUC: 0.7226, Valid ROC AUC: 0.7136
# Early stopping triggered at depth: 8
# 최적 Depth: 7, 최종 Train ROC AUC: 0.7197, 최종 Valid ROC AUC: 0.7145
#
# === Ensemble Model 496/500 ===
# Depth: 1, Train ROC AUC: 0.5979, Valid ROC AUC: 0.5972
# Depth: 2, Train ROC AUC: 0.6648, Valid ROC AUC: 0.6646
# Depth: 3, Train ROC AUC: 0.6905, Valid ROC AUC: 0.6914
# Depth: 4, Train ROC AUC: 0.7033, Valid ROC AUC: 0.7052
# Depth: 5, Train ROC AUC: 0.7100, Valid ROC AUC: 0.7123
# Depth: 6, Train ROC AUC: 0.7151, Valid ROC AUC: 0.7160
# Depth: 7, Train ROC AUC: 0.7189, Valid ROC AUC: 0.7169
# Depth: 8, Train ROC AUC: 0.7217, Valid ROC AUC: 0.7168
# Early stopping triggered at depth: 8
# 최적 Depth: 7, 최종 Train ROC AUC: 0.7189, 최종 Valid ROC AUC: 0.7169
#
# === Ensemble Model 497/500 ===
# Depth: 1, Train ROC AUC: 0.5978, Valid ROC AUC: 0.5976
# Depth: 2, Train ROC AUC: 0.6640, Valid ROC AUC: 0.6628
# Depth: 3, Train ROC AUC: 0.6909, Valid ROC AUC: 0.6920
# Depth: 4, Train ROC AUC: 0.7020, Valid ROC AUC: 0.7050
# Depth: 5, Train ROC AUC: 0.7101, Valid ROC AUC: 0.7127
# Depth: 6, Train ROC AUC: 0.7150, Valid ROC AUC: 0.7166
# Depth: 7, Train ROC AUC: 0.7185, Valid ROC AUC: 0.7188
# Depth: 8, Train ROC AUC: 0.7216, Valid ROC AUC: 0.7167
# Early stopping triggered at depth: 8
# 최적 Depth: 7, 최종 Train ROC AUC: 0.7185, 최종 Valid ROC AUC: 0.7188
#
# === Ensemble Model 498/500 ===
# Depth: 1, Train ROC AUC: 0.5979, Valid ROC AUC: 0.5974
# Depth: 2, Train ROC AUC: 0.6636, Valid ROC AUC: 0.6642
# Depth: 3, Train ROC AUC: 0.6910, Valid ROC AUC: 0.6917
# Depth: 4, Train ROC AUC: 0.7026, Valid ROC AUC: 0.7027
# Depth: 5, Train ROC AUC: 0.7104, Valid ROC AUC: 0.7115
# Depth: 6, Train ROC AUC: 0.7154, Valid ROC AUC: 0.7148
# Depth: 7, Train ROC AUC: 0.7192, Valid ROC AUC: 0.7163
# Depth: 8, Train ROC AUC: 0.7222, Valid ROC AUC: 0.7152
# Early stopping triggered at depth: 8
# 최적 Depth: 7, 최종 Train ROC AUC: 0.7192, 최종 Valid ROC AUC: 0.7163
#
# === Ensemble Model 499/500 ===
# Depth: 1, Train ROC AUC: 0.5975, Valid ROC AUC: 0.5990
# Depth: 2, Train ROC AUC: 0.6645, Valid ROC AUC: 0.6661
# Depth: 3, Train ROC AUC: 0.6903, Valid ROC AUC: 0.6923
# Depth: 4, Train ROC AUC: 0.7022, Valid ROC AUC: 0.7042
# Depth: 5, Train ROC AUC: 0.7105, Valid ROC AUC: 0.7110
# Depth: 6, Train ROC AUC: 0.7155, Valid ROC AUC: 0.7153
# Depth: 7, Train ROC AUC: 0.7188, Valid ROC AUC: 0.7165
# Depth: 8, Train ROC AUC: 0.7217, Valid ROC AUC: 0.7167
# Depth: 9, Train ROC AUC: 0.7248, Valid ROC AUC: 0.7155
# Early stopping triggered at depth: 9
# 최적 Depth: 8, 최종 Train ROC AUC: 0.7217, 최종 Valid ROC AUC: 0.7167
#
# === Ensemble Model 500/500 ===
# Depth: 1, Train ROC AUC: 0.5976, Valid ROC AUC: 0.5985
# Depth: 2, Train ROC AUC: 0.6640, Valid ROC AUC: 0.6627
# Depth: 3, Train ROC AUC: 0.6913, Valid ROC AUC: 0.6907
# Depth: 4, Train ROC AUC: 0.7022, Valid ROC AUC: 0.7027
# Depth: 5, Train ROC AUC: 0.7106, Valid ROC AUC: 0.7106
# Depth: 6, Train ROC AUC: 0.7154, Valid ROC AUC: 0.7148
# Depth: 7, Train ROC AUC: 0.7188, Valid ROC AUC: 0.7176
# Depth: 8, Train ROC AUC: 0.7216, Valid ROC AUC: 0.7169
# Early stopping triggered at depth: 8
# 최적 Depth: 7, 최종 Train ROC AUC: 0.7188, 최종 Valid ROC AUC: 0.7176
#
# Ensemble 평균 성능:
# 평균 Train ROC AUC: 0.7205
# 평균 Valid ROC AUC: 0.7169
#
# Ensemble 모델이 'ensemble_deep_decision_trees.pkl'로 저장되었습니다.
# 테스트 데이터 예측 결과가 각각 'ensemble_test_predictions_top100.csv',
# 'ensemble_test_predictions_top200.csv', 'ensemble_test_predictions_top300.csv',
# 그리고 'ensemble_test_predictions_all.csv' 파일에 저장되었습니다.

# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import roc_auc_score
from sklearn.preprocessing import StandardScaler
from sklearn.pipeline import Pipeline
import joblib
import copy

# -------------------------------
# 1. 데이터 로드 및 전처리
# -------------------------------
data = pd.read_csv('train2.csv', encoding='cp949')
X = data.drop(columns=['ID', '시술 시기 코드', '시술 유형', '임신 성공 여부',
                '여성 주 불임 원인', '부부 주 불임 원인', '부부 부 불임 원인',
                'IVF 시술 횟수', 'IVF 출산 횟수', '혼합된 난자 수',
                '동결 배아 사용 여부', '신선 배아 사용 여부'])
y = data['임신 성공 여부']

# -------------------------------
# 2. Ensemble 학습을 위한 설정
# -------------------------------
n_iterations = 500   # 전체 데이터를 500번 사용
max_depth_start = 1
max_depth_end = 1000
patience = 1         # 연속 개선이 없으면 early stopping (여기서는 매우 짧게 설정)

ensemble_models = []        # 각 반복의 최적 모델 저장 리스트
ensemble_best_depths = []   # 각 모델의 최적 max_depth 저장
ensemble_train_auc = []     # 각 모델의 학습 ROC AUC 저장
ensemble_val_auc = []       # 각 모델의 검증 ROC AUC 저장

# -------------------------------
# 3. 여러 번의 무작위 데이터 분할 및 모델 학습
# -------------------------------
for i in range(n_iterations):
    print(f"\n=== Ensemble Model {i+1}/{n_iterations} ===")
    # 무작위 분할 (매번 다른 분할)
    X_train, X_val, y_train, y_val = train_test_split(
        X, y, test_size=0.2, stratify=y
    )
    
    # 파이프라인 구성: StandardScaler와 DecisionTreeClassifier
    pipeline = Pipeline([
        ('scaler', StandardScaler()),
        ('dt', DecisionTreeClassifier())
    ])
    
    patience_counter = 0   # early stopping 카운터 초기화
    best_score = -np.inf     # 검증 ROC AUC 최적값 초기화
    best_depth = None
    best_model = None
    
    # max_depth를 1부터 max_depth_end까지 증가시키며 모델 학습 및 평가
    for depth in range(max_depth_start, max_depth_end + 1):
        pipeline.set_params(dt__max_depth=depth)
        pipeline.fit(X_train, y_train)
        
        # 학습 및 검증 데이터 ROC AUC 계산
        y_train_prob = pipeline.predict_proba(X_train)[:, 1]
        train_score = roc_auc_score(y_train, y_train_prob)
        y_val_prob = pipeline.predict_proba(X_val)[:, 1]
        current_score = roc_auc_score(y_val, y_val_prob)
        
        # 각 depth 반복 시점의 결과 출력 (트래킹)
        print(f"Depth: {depth}, Train ROC AUC: {train_score:.4f}, Valid ROC AUC: {current_score:.4f}")
        
        # 검증 ROC AUC가 개선되면 갱신
        if current_score > best_score:
            best_score = current_score
            best_depth = depth
            best_model = copy.deepcopy(pipeline)
            patience_counter = 0  # 개선 시 카운터 리셋
        else:
            patience_counter += 1
        
        # 연속 개선이 없으면 조기 종료
        if patience_counter >= patience:
            print(f"Early stopping triggered at depth: {depth}")
            break

    # 해당 반복의 최종 학습 데이터 ROC AUC 재계산 (선택 사항)
    y_train_prob = best_model.predict_proba(X_train)[:, 1]
    final_train_score = roc_auc_score(y_train, y_train_prob)
    
    print(f"최적 Depth: {best_depth}, 최종 Train ROC AUC: {final_train_score:.4f}, 최종 Valid ROC AUC: {best_score:.4f}")
    
    ensemble_models.append(best_model)
    ensemble_best_depths.append(best_depth)
    ensemble_train_auc.append(final_train_score)
    ensemble_val_auc.append(best_score)

# -------------------------------
# 4. Ensemble 평가 (평균 성능 확인)
# -------------------------------
avg_train_auc = np.mean(ensemble_train_auc)
avg_val_auc = np.mean(ensemble_val_auc)
print("\nEnsemble 평균 성능:")
print(f"평균 Train ROC AUC: {avg_train_auc:.4f}")
print(f"평균 Valid ROC AUC: {avg_val_auc:.4f}")

# 전체 모델 저장 (나중에 재사용 가능)
joblib.dump(ensemble_models, "ensemble_deep_decision_trees.pkl")
print("\nEnsemble 모델이 'ensemble_deep_decision_trees.pkl'로 저장되었습니다.")

# -------------------------------
# 5. 상위 및 전체 모델 기반으로 테스트 데이터 예측
# -------------------------------
# validation ROC AUC를 기준으로 내림차순 정렬할 인덱스를 구합니다.
val_auc_array = np.array(ensemble_val_auc)
sorted_indices = np.argsort(val_auc_array)[::-1]  # 내림차순 (높은 성능순)

# 사용할 모델 개수별 인덱스 추출
top100_indices = sorted_indices[:100]
top200_indices = sorted_indices[:200]
top300_indices = sorted_indices[:300]
all_indices = np.arange(len(ensemble_models))  # 전체 500개 모델

# 테스트 데이터 로드 및 전처리
test_data = pd.read_csv('test2.csv', encoding='cp949')
X_test = test_data.drop(columns=['ID', '시술 시기 코드', '시술 유형', '임신 성공 여부',
                '여성 주 불임 원인', '부부 주 불임 원인', '부부 부 불임 원인',
                'IVF 시술 횟수', 'IVF 출산 횟수', '혼합된 난자 수',
                '동결 배아 사용 여부', '신선 배아 사용 여부'], errors='ignore')

def predict_with_ensemble(model_indices, models, X_test, threshold=0.5):
    probs_list = []
    for idx in model_indices:
        probs = models[idx].predict_proba(X_test)[:, 1]
        probs_list.append(probs)
    avg_probs = np.mean(probs_list, axis=0)
    preds = (avg_probs >= threshold).astype(int)
    return preds

# 각 앙상블 결과로 예측
top100_preds = predict_with_ensemble(top100_indices, ensemble_models, X_test)
top200_preds = predict_with_ensemble(top200_indices, ensemble_models, X_test)
top300_preds = predict_with_ensemble(top300_indices, ensemble_models, X_test)
all_preds    = predict_with_ensemble(all_indices,    ensemble_models, X_test)

# 예측 결과를 test_data에 추가
test_data['임신 성공 여부 예측_top100'] = top100_preds
test_data['임신 성공 여부 예측_top200'] = top200_preds
test_data['임신 성공 여부 예측_top300'] = top300_preds
test_data['임신 성공 여부 예측_all']     = all_preds

# 각각의 파일로 저장 (원하는 대로 컬럼 선택 가능)
test_data[['ID', '임신 성공 여부 예측_top100']].to_csv('ensemble_test_predictions_top100_feature_selection.csv', index=False, encoding='cp949')
test_data[['ID', '임신 성공 여부 예측_top200']].to_csv('ensemble_test_predictions_top200_feature_selection.csv', index=False, encoding='cp949')
test_data[['ID', '임신 성공 여부 예측_top300']].to_csv('ensemble_test_predictions_top300_feature_selection.csv', index=False, encoding='cp949')
test_data[['ID', '임신 성공 여부 예측_all']].to_csv('ensemble_test_predictions_all_feature_selection.csv', index=False, encoding='cp949')

print("테스트 데이터 예측 결과가 각각 'ensemble_test_predictions_top100.csv',")
print("'ensemble_test_predictions_top200.csv', 'ensemble_test_predictions_top300.csv',")
print("그리고 'ensemble_test_predictions_all.csv' 파일에 저장되었습니다.")
# Out:
# === Ensemble Model 1/500 ===
# Depth: 1, Train ROC AUC: 0.5977, Valid ROC AUC: 0.5981
# Depth: 2, Train ROC AUC: 0.6651, Valid ROC AUC: 0.6637
# Depth: 3, Train ROC AUC: 0.6914, Valid ROC AUC: 0.6884
# Depth: 4, Train ROC AUC: 0.7042, Valid ROC AUC: 0.7001
# Depth: 5, Train ROC AUC: 0.7113, Valid ROC AUC: 0.7073
# Depth: 6, Train ROC AUC: 0.7161, Valid ROC AUC: 0.7125
# Depth: 7, Train ROC AUC: 0.7188, Valid ROC AUC: 0.7155
# Depth: 8, Train ROC AUC: 0.7216, Valid ROC AUC: 0.7167
# Depth: 9, Train ROC AUC: 0.7247, Valid ROC AUC: 0.7152
# Early stopping triggered at depth: 9
# 최적 Depth: 8, 최종 Train ROC AUC: 0.7216, 최종 Valid ROC AUC: 0.7167
#
# === Ensemble Model 2/500 ===
# Depth: 1, Train ROC AUC: 0.5974, Valid ROC AUC: 0.5992
# Depth: 2, Train ROC AUC: 0.6630, Valid ROC AUC: 0.6668
# Depth: 3, Train ROC AUC: 0.6907, Valid ROC AUC: 0.6930
# Depth: 4, Train ROC AUC: 0.7022, Valid ROC AUC: 0.7040
# Depth: 5, Train ROC AUC: 0.7101, Valid ROC AUC: 0.7131
# Depth: 6, Train ROC AUC: 0.7150, Valid ROC AUC: 0.7165
# Depth: 7, Train ROC AUC: 0.7183, Valid ROC AUC: 0.7187
# Depth: 8, Train ROC AUC: 0.7209, Valid ROC AUC: 0.7178
# Early stopping triggered at depth: 8
# 최적 Depth: 7, 최종 Train ROC AUC: 0.7183, 최종 Valid ROC AUC: 0.7187
#
# === Ensemble Model 3/500 ===
# Depth: 1, Train ROC AUC: 0.5978, Valid ROC AUC: 0.5976
# Depth: 2, Train ROC AUC: 0.6639, Valid ROC AUC: 0.6632
# Depth: 3, Train ROC AUC: 0.6913, Valid ROC AUC: 0.6906
# Depth: 4, Train ROC AUC: 0.7029, Valid ROC AUC: 0.7014
# Depth: 5, Train ROC AUC: 0.7109, Valid ROC AUC: 0.7099
# Depth: 6, Train ROC AUC: 0.7157, Valid ROC AUC: 0.7140
# Depth: 7, Train ROC AUC: 0.7186, Valid ROC AUC: 0.7166
# Depth: 8, Train ROC AUC: 0.7211, Valid ROC AUC: 0.7166
# Early stopping triggered at depth: 8
# 최적 Depth: 7, 최종 Train ROC AUC: 0.7186, 최종 Valid ROC AUC: 0.7166
#
# === Ensemble Model 4/500 ===
# Depth: 1, Train ROC AUC: 0.5976, Valid ROC AUC: 0.5986
# Depth: 2, Train ROC AUC: 0.6652, Valid ROC AUC: 0.6631
# Depth: 3, Train ROC AUC: 0.6910, Valid ROC AUC: 0.6893
# Depth: 4, Train ROC AUC: 0.7037, Valid ROC AUC: 0.7021
# Depth: 5, Train ROC AUC: 0.7105, Valid ROC AUC: 0.7095
# Depth: 6, Train ROC AUC: 0.7157, Valid ROC AUC: 0.7138
# Depth: 7, Train ROC AUC: 0.7188, Valid ROC AUC: 0.7156
# Depth: 8, Train ROC AUC: 0.7215, Valid ROC AUC: 0.7163
# Depth: 9, Train ROC AUC: 0.7245, Valid ROC AUC: 0.7145
# Early stopping triggered at depth: 9
# 최적 Depth: 8, 최종 Train ROC AUC: 0.7215, 최종 Valid ROC AUC: 0.7163
#
# === Ensemble Model 5/500 ===
# Depth: 1, Train ROC AUC: 0.5977, Valid ROC AUC: 0.5981
# Depth: 2, Train ROC AUC: 0.6648, Valid ROC AUC: 0.6645
# Depth: 3, Train ROC AUC: 0.6906, Valid ROC AUC: 0.6910
# Depth: 4, Train ROC AUC: 0.7039, Valid ROC AUC: 0.7052
# Depth: 5, Train ROC AUC: 0.7105, Valid ROC AUC: 0.7109
# Depth: 6, Train ROC AUC: 0.7151, Valid ROC AUC: 0.7142
# Depth: 7, Train ROC AUC: 0.7188, Valid ROC AUC: 0.7150
# Depth: 8, Train ROC AUC: 0.7216, Valid ROC AUC: 0.7155
# Depth: 9, Train ROC AUC: 0.7246, Valid ROC AUC: 0.7150
# Early stopping triggered at depth: 9
# 최적 Depth: 8, 최종 Train ROC AUC: 0.7216, 최종 Valid ROC AUC: 0.7155
#
# === Ensemble Model 6/500 ===
# Depth: 1, Train ROC AUC: 0.5980, Valid ROC AUC: 0.5969
# Depth: 2, Train ROC AUC: 0.6639, Valid ROC AUC: 0.6629
# Depth: 3, Train ROC AUC: 0.6910, Valid ROC AUC: 0.6916
# Depth: 4, Train ROC AUC: 0.7023, Valid ROC AUC: 0.7036
# Depth: 5, Train ROC AUC: 0.7102, Valid ROC AUC: 0.7125
# Depth: 6, Train ROC AUC: 0.7150, Valid ROC AUC: 0.7156
# Depth: 7, Train ROC AUC: 0.7183, Valid ROC AUC: 0.7181
# Depth: 8, Train ROC AUC: 0.7210, Valid ROC AUC: 0.7178
# Early stopping triggered at depth: 8
# 최적 Depth: 7, 최종 Train ROC AUC: 0.7183, 최종 Valid ROC AUC: 0.7181
#
# === Ensemble Model 7/500 ===
# Depth: 1, Train ROC AUC: 0.5980, Valid ROC AUC: 0.5968
# Depth: 2, Train ROC AUC: 0.6642, Valid ROC AUC: 0.6619
# Depth: 3, Train ROC AUC: 0.6917, Valid ROC AUC: 0.6888
# Depth: 4, Train ROC AUC: 0.7033, Valid ROC AUC: 0.6998
# Depth: 5, Train ROC AUC: 0.7114, Valid ROC AUC: 0.7080
# Depth: 6, Train ROC AUC: 0.7161, Valid ROC AUC: 0.7117
# Depth: 7, Train ROC AUC: 0.7193, Valid ROC AUC: 0.7134
# Depth: 8, Train ROC AUC: 0.7219, Valid ROC AUC: 0.7130
# Early stopping triggered at depth: 8
# 최적 Depth: 7, 최종 Train ROC AUC: 0.7193, 최종 Valid ROC AUC: 0.7134
#
# === Ensemble Model 8/500 ===
# Depth: 1, Train ROC AUC: 0.5981, Valid ROC AUC: 0.5966
# Depth: 2, Train ROC AUC: 0.6653, Valid ROC AUC: 0.6627
# Depth: 3, Train ROC AUC: 0.6912, Valid ROC AUC: 0.6888
# Depth: 4, Train ROC AUC: 0.7039, Valid ROC AUC: 0.7028
# Depth: 5, Train ROC AUC: 0.7108, Valid ROC AUC: 0.7088
# Depth: 6, Train ROC AUC: 0.7157, Valid ROC AUC: 0.7134
# Depth: 7, Train ROC AUC: 0.7188, Valid ROC AUC: 0.7156
# Depth: 8, Train ROC AUC: 0.7215, Valid ROC AUC: 0.7157
# Depth: 9, Train ROC AUC: 0.7246, Valid ROC AUC: 0.7156
# Early stopping triggered at depth: 9
# 최적 Depth: 8, 최종 Train ROC AUC: 0.7215, 최종 Valid ROC AUC: 0.7157
#
# === Ensemble Model 9/500 ===
# Depth: 1, Train ROC AUC: 0.5977, Valid ROC AUC: 0.5982
# Depth: 2, Train ROC AUC: 0.6646, Valid ROC AUC: 0.6657
# Depth: 3, Train ROC AUC: 0.6904, Valid ROC AUC: 0.6924
# Depth: 4, Train ROC AUC: 0.7033, Valid ROC AUC: 0.7053
# Depth: 5, Train ROC AUC: 0.7100, Valid ROC AUC: 0.7124
# Depth: 6, Train ROC AUC: 0.7147, Valid ROC AUC: 0.7178
# Depth: 7, Train ROC AUC: 0.7179, Valid ROC AUC: 0.7199
# Depth: 8, Train ROC AUC: 0.7207, Valid ROC AUC: 0.7198
# Early stopping triggered at depth: 8
# 최적 Depth: 7, 최종 Train ROC AUC: 0.7179, 최종 Valid ROC AUC: 0.7199
#
# === Ensemble Model 10/500 ===
# Depth: 1, Train ROC AUC: 0.5977, Valid ROC AUC: 0.5981
# Depth: 2, Train ROC AUC: 0.6631, Valid ROC AUC: 0.6661
# Depth: 3, Train ROC AUC: 0.6907, Valid ROC AUC: 0.6929
# Depth: 4, Train ROC AUC: 0.7025, Valid ROC AUC: 0.7029
# Depth: 5, Train ROC AUC: 0.7108, Valid ROC AUC: 0.7104
# Depth: 6, Train ROC AUC: 0.7155, Valid ROC AUC: 0.7137
# Depth: 7, Train ROC AUC: 0.7190, Valid ROC AUC: 0.7156
# Depth: 8, Train ROC AUC: 0.7216, Valid ROC AUC: 0.7155
# Early stopping triggered at depth: 8
# 최적 Depth: 7, 최종 Train ROC AUC: 0.7190, 최종 Valid ROC AUC: 0.7156
#
# === Ensemble Model 11/500 ===
# Depth: 1, Train ROC AUC: 0.5977, Valid ROC AUC: 0.5980
# Depth: 2, Train ROC AUC: 0.6641, Valid ROC AUC: 0.6623
# Depth: 3, Train ROC AUC: 0.6913, Valid ROC AUC: 0.6907
# Depth: 4, Train ROC AUC: 0.7027, Valid ROC AUC: 0.7020
# Depth: 5, Train ROC AUC: 0.7105, Valid ROC AUC: 0.7113
# Depth: 6, Train ROC AUC: 0.7153, Valid ROC AUC: 0.7151
# Depth: 7, Train ROC AUC: 0.7185, Valid ROC AUC: 0.7169
# Depth: 8, Train ROC AUC: 0.7210, Valid ROC AUC: 0.7175
# Depth: 9, Train ROC AUC: 0.7240, Valid ROC AUC: 0.7170
# Early stopping triggered at depth: 9
# 최적 Depth: 8, 최종 Train ROC AUC: 0.7210, 최종 Valid ROC AUC: 0.7175
#
# === Ensemble Model 12/500 ===
# Depth: 1, Train ROC AUC: 0.5980, Valid ROC AUC: 0.5969
# Depth: 2, Train ROC AUC: 0.6641, Valid ROC AUC: 0.6623
# Depth: 3, Train ROC AUC: 0.6914, Valid ROC AUC: 0.6899
# Depth: 4, Train ROC AUC: 0.7028, Valid ROC AUC: 0.7015
# Depth: 5, Train ROC AUC: 0.7111, Valid ROC AUC: 0.7087
# Depth: 6, Train ROC AUC: 0.7159, Valid ROC AUC: 0.7129
# Depth: 7, Train ROC AUC: 0.7189, Valid ROC AUC: 0.7155
# Depth: 8, Train ROC AUC: 0.7216, Valid ROC AUC: 0.7150
# Early stopping triggered at depth: 8
# 최적 Depth: 7, 최종 Train ROC AUC: 0.7189, 최종 Valid ROC AUC: 0.7155
#
# === Ensemble Model 13/500 ===
# Depth: 1, Train ROC AUC: 0.5981, Valid ROC AUC: 0.5966
# Depth: 2, Train ROC AUC: 0.6647, Valid ROC AUC: 0.6600
# Depth: 3, Train ROC AUC: 0.6919, Valid ROC AUC: 0.6882
# Depth: 4, Train ROC AUC: 0.7032, Valid ROC AUC: 0.6999
# Depth: 5, Train ROC AUC: 0.7115, Valid ROC AUC: 0.7075
# Depth: 6, Train ROC AUC: 0.7162, Valid ROC AUC: 0.7109
# Depth: 7, Train ROC AUC: 0.7194, Valid ROC AUC: 0.7127
# Depth: 8, Train ROC AUC: 0.7220, Valid ROC AUC: 0.7121
# Early stopping triggered at depth: 8
# 최적 Depth: 7, 최종 Train ROC AUC: 0.7194, 최종 Valid ROC AUC: 0.7127
#
# === Ensemble Model 14/500 ===
# Depth: 1, Train ROC AUC: 0.5975, Valid ROC AUC: 0.5988
# Depth: 2, Train ROC AUC: 0.6645, Valid ROC AUC: 0.6608
# Depth: 3, Train ROC AUC: 0.6915, Valid ROC AUC: 0.6899
# Depth: 4, Train ROC AUC: 0.7024, Valid ROC AUC: 0.7022
# Depth: 5, Train ROC AUC: 0.7105, Valid ROC AUC: 0.7114
# Depth: 6, Train ROC AUC: 0.7152, Valid ROC AUC: 0.7151
# Depth: 7, Train ROC AUC: 0.7184, Valid ROC AUC: 0.7176
# Depth: 8, Train ROC AUC: 0.7211, Valid ROC AUC: 0.7177
# Depth: 9, Train ROC AUC: 0.7242, Valid ROC AUC: 0.7179
# Depth: 10, Train ROC AUC: 0.7281, Valid ROC AUC: 0.7176
# Early stopping triggered at depth: 10
# 최적 Depth: 9, 최종 Train ROC AUC: 0.7242, 최종 Valid ROC AUC: 0.7179
#
# === Ensemble Model 15/500 ===
# Depth: 1, Train ROC AUC: 0.5977, Valid ROC AUC: 0.5981
# Depth: 2, Train ROC AUC: 0.6642, Valid ROC AUC: 0.6618
# Depth: 3, Train ROC AUC: 0.6915, Valid ROC AUC: 0.6896
# Depth: 4, Train ROC AUC: 0.7024, Valid ROC AUC: 0.7032
# Depth: 5, Train ROC AUC: 0.7107, Valid ROC AUC: 0.7106
# Depth: 6, Train ROC AUC: 0.7152, Valid ROC AUC: 0.7147
# Depth: 7, Train ROC AUC: 0.7185, Valid ROC AUC: 0.7164
# Depth: 8, Train ROC AUC: 0.7211, Valid ROC AUC: 0.7158
# Early stopping triggered at depth: 8
# 최적 Depth: 7, 최종 Train ROC AUC: 0.7185, 최종 Valid ROC AUC: 0.7164
#
# === Ensemble Model 16/500 ===
# Depth: 1, Train ROC AUC: 0.5983, Valid ROC AUC: 0.5959
# Depth: 2, Train ROC AUC: 0.6640, Valid ROC AUC: 0.6628
# Depth: 3, Train ROC AUC: 0.6910, Valid ROC AUC: 0.6917
# Depth: 4, Train ROC AUC: 0.7024, Valid ROC AUC: 0.7032
# Depth: 5, Train ROC AUC: 0.7106, Valid ROC AUC: 0.7114
# Depth: 6, Train ROC AUC: 0.7150, Valid ROC AUC: 0.7157
# Depth: 7, Train ROC AUC: 0.7183, Valid ROC AUC: 0.7171
# Depth: 8, Train ROC AUC: 0.7212, Valid ROC AUC: 0.7169
# Early stopping triggered at depth: 8
# 최적 Depth: 7, 최종 Train ROC AUC: 0.7183, 최종 Valid ROC AUC: 0.7171
#
# === Ensemble Model 17/500 ===
# Depth: 1, Train ROC AUC: 0.5977, Valid ROC AUC: 0.5980
# Depth: 2, Train ROC AUC: 0.6633, Valid ROC AUC: 0.6655
# Depth: 3, Train ROC AUC: 0.6908, Valid ROC AUC: 0.6925
# Depth: 4, Train ROC AUC: 0.7024, Valid ROC AUC: 0.7032
# Depth: 5, Train ROC AUC: 0.7105, Valid ROC AUC: 0.7111
# Depth: 6, Train ROC AUC: 0.7151, Valid ROC AUC: 0.7153
# Depth: 7, Train ROC AUC: 0.7182, Valid ROC AUC: 0.7175
# Depth: 8, Train ROC AUC: 0.7208, Valid ROC AUC: 0.7173
# Early stopping triggered at depth: 8
# 최적 Depth: 7, 최종 Train ROC AUC: 0.7182, 최종 Valid ROC AUC: 0.7175
#
# === Ensemble Model 18/500 ===
# Depth: 1, Train ROC AUC: 0.5979, Valid ROC AUC: 0.5974
# Depth: 2, Train ROC AUC: 0.6634, Valid ROC AUC: 0.6650
# Depth: 3, Train ROC AUC: 0.6907, Valid ROC AUC: 0.6932
# Depth: 4, Train ROC AUC: 0.7020, Valid ROC AUC: 0.7050
# Depth: 5, Train ROC AUC: 0.7102, Valid ROC AUC: 0.7126
# Depth: 6, Train ROC AUC: 0.7150, Valid ROC AUC: 0.7160
# Depth: 7, Train ROC AUC: 0.7183, Valid ROC AUC: 0.7180
# Depth: 8, Train ROC AUC: 0.7208, Valid ROC AUC: 0.7179
# Early stopping triggered at depth: 8
# 최적 Depth: 7, 최종 Train ROC AUC: 0.7183, 최종 Valid ROC AUC: 0.7180
#
# === Ensemble Model 19/500 ===
# Depth: 1, Train ROC AUC: 0.5974, Valid ROC AUC: 0.5993
# Depth: 2, Train ROC AUC: 0.6632, Valid ROC AUC: 0.6661
# Depth: 3, Train ROC AUC: 0.6907, Valid ROC AUC: 0.6930
# Depth: 4, Train ROC AUC: 0.7024, Valid ROC AUC: 0.7035
# Depth: 5, Train ROC AUC: 0.7105, Valid ROC AUC: 0.7114
# Depth: 6, Train ROC AUC: 0.7150, Valid ROC AUC: 0.7163
# Depth: 7, Train ROC AUC: 0.7182, Valid ROC AUC: 0.7193
# Depth: 8, Train ROC AUC: 0.7207, Valid ROC AUC: 0.7191
# Early stopping triggered at depth: 8
# 최적 Depth: 7, 최종 Train ROC AUC: 0.7182, 최종 Valid ROC AUC: 0.7193
#
# === Ensemble Model 20/500 ===
# Depth: 1, Train ROC AUC: 0.5978, Valid ROC AUC: 0.5976
# Depth: 2, Train ROC AUC: 0.6644, Valid ROC AUC: 0.6609
# Depth: 3, Train ROC AUC: 0.6919, Valid ROC AUC: 0.6881
# Depth: 4, Train ROC AUC: 0.7033, Valid ROC AUC: 0.6995
# Depth: 5, Train ROC AUC: 0.7114, Valid ROC AUC: 0.7078
# Depth: 6, Train ROC AUC: 0.7159, Valid ROC AUC: 0.7126
# Depth: 7, Train ROC AUC: 0.7190, Valid ROC AUC: 0.7153
# Depth: 8, Train ROC AUC: 0.7217, Valid ROC AUC: 0.7145
# Early stopping triggered at depth: 8
# 최적 Depth: 7, 최종 Train ROC AUC: 0.7190, 최종 Valid ROC AUC: 0.7153
#
# === Ensemble Model 21/500 ===
# Depth: 1, Train ROC AUC: 0.5979, Valid ROC AUC: 0.5973
# Depth: 2, Train ROC AUC: 0.6644, Valid ROC AUC: 0.6611
# Depth: 3, Train ROC AUC: 0.6918, Valid ROC AUC: 0.6885
# Depth: 4, Train ROC AUC: 0.7035, Valid ROC AUC: 0.6988
# Depth: 5, Train ROC AUC: 0.7117, Valid ROC AUC: 0.7066
# Depth: 6, Train ROC AUC: 0.7160, Valid ROC AUC: 0.7115
# Depth: 7, Train ROC AUC: 0.7194, Valid ROC AUC: 0.7142
# Depth: 8, Train ROC AUC: 0.7220, Valid ROC AUC: 0.7147
# Depth: 9, Train ROC AUC: 0.7250, Valid ROC AUC: 0.7150
# Depth: 10, Train ROC AUC: 0.7287, Valid ROC AUC: 0.7145
# Early stopping triggered at depth: 10
# 최적 Depth: 9, 최종 Train ROC AUC: 0.7250, 최종 Valid ROC AUC: 0.7150
#
# === Ensemble Model 22/500 ===
# Depth: 1, Train ROC AUC: 0.5979, Valid ROC AUC: 0.5973
# Depth: 2, Train ROC AUC: 0.6660, Valid ROC AUC: 0.6600
# Depth: 3, Train ROC AUC: 0.6921, Valid ROC AUC: 0.6848
# Depth: 4, Train ROC AUC: 0.7043, Valid ROC AUC: 0.6965
# Depth: 5, Train ROC AUC: 0.7121, Valid ROC AUC: 0.7046
# Depth: 6, Train ROC AUC: 0.7172, Valid ROC AUC: 0.7087
# Depth: 7, Train ROC AUC: 0.7203, Valid ROC AUC: 0.7108
# Depth: 8, Train ROC AUC: 0.7230, Valid ROC AUC: 0.7108
# Early stopping triggered at depth: 8
# 최적 Depth: 7, 최종 Train ROC AUC: 0.7203, 최종 Valid ROC AUC: 0.7108
#
# === Ensemble Model 23/500 ===
# Depth: 1, Train ROC AUC: 0.5978, Valid ROC AUC: 0.5978
# Depth: 2, Train ROC AUC: 0.6638, Valid ROC AUC: 0.6636
# Depth: 3, Train ROC AUC: 0.6910, Valid ROC AUC: 0.6916
# Depth: 4, Train ROC AUC: 0.7024, Valid ROC AUC: 0.7031
# Depth: 5, Train ROC AUC: 0.7106, Valid ROC AUC: 0.7110
# Depth: 6, Train ROC AUC: 0.7152, Valid ROC AUC: 0.7149
# Depth: 7, Train ROC AUC: 0.7186, Valid ROC AUC: 0.7170
# Depth: 8, Train ROC AUC: 0.7212, Valid ROC AUC: 0.7180
# Depth: 9, Train ROC AUC: 0.7241, Valid ROC AUC: 0.7169
# Early stopping triggered at depth: 9
# 최적 Depth: 8, 최종 Train ROC AUC: 0.7212, 최종 Valid ROC AUC: 0.7180
#
# === Ensemble Model 24/500 ===
# Depth: 1, Train ROC AUC: 0.5979, Valid ROC AUC: 0.5972
# Depth: 2, Train ROC AUC: 0.6639, Valid ROC AUC: 0.6631
# Depth: 3, Train ROC AUC: 0.6916, Valid ROC AUC: 0.6892
# Depth: 4, Train ROC AUC: 0.7031, Valid ROC AUC: 0.7005
# Depth: 5, Train ROC AUC: 0.7113, Valid ROC AUC: 0.7076
# Depth: 6, Train ROC AUC: 0.7159, Valid ROC AUC: 0.7113
# Depth: 7, Train ROC AUC: 0.7195, Valid ROC AUC: 0.7134
# Depth: 8, Train ROC AUC: 0.7221, Valid ROC AUC: 0.7136
# Depth: 9, Train ROC AUC: 0.7251, Valid ROC AUC: 0.7128
# Early stopping triggered at depth: 9
# 최적 Depth: 8, 최종 Train ROC AUC: 0.7221, 최종 Valid ROC AUC: 0.7136
#
# === Ensemble Model 25/500 ===
# Depth: 1, Train ROC AUC: 0.5981, Valid ROC AUC: 0.5967
# Depth: 2, Train ROC AUC: 0.6639, Valid ROC AUC: 0.6629
# Depth: 3, Train ROC AUC: 0.6916, Valid ROC AUC: 0.6893
# Depth: 4, Train ROC AUC: 0.7033, Valid ROC AUC: 0.6995
# Depth: 5, Train ROC AUC: 0.7112, Valid ROC AUC: 0.7086
# Depth: 6, Train ROC AUC: 0.7157, Valid ROC AUC: 0.7122
# Depth: 7, Train ROC AUC: 0.7191, Valid ROC AUC: 0.7141
# Depth: 8, Train ROC AUC: 0.7219, Valid ROC AUC: 0.7152
# Depth: 9, Train ROC AUC: 0.7251, Valid ROC AUC: 0.7144
# Early stopping triggered at depth: 9
# 최적 Depth: 8, 최종 Train ROC AUC: 0.7219, 최종 Valid ROC AUC: 0.7152
#
# === Ensemble Model 26/500 ===
# Depth: 1, Train ROC AUC: 0.5977, Valid ROC AUC: 0.5981
# Depth: 2, Train ROC AUC: 0.6639, Valid ROC AUC: 0.6632
# Depth: 3, Train ROC AUC: 0.6913, Valid ROC AUC: 0.6907
# Depth: 4, Train ROC AUC: 0.7026, Valid ROC AUC: 0.7024
# Depth: 5, Train ROC AUC: 0.7106, Valid ROC AUC: 0.7106
# Depth: 6, Train ROC AUC: 0.7153, Valid ROC AUC: 0.7138
# Depth: 7, Train ROC AUC: 0.7185, Valid ROC AUC: 0.7171
# Depth: 8, Train ROC AUC: 0.7211, Valid ROC AUC: 0.7173
# Depth: 9, Train ROC AUC: 0.7245, Valid ROC AUC: 0.7160
# Early stopping triggered at depth: 9
# 최적 Depth: 8, 최종 Train ROC AUC: 0.7211, 최종 Valid ROC AUC: 0.7173
#
# === Ensemble Model 27/500 ===
# Depth: 1, Train ROC AUC: 0.5976, Valid ROC AUC: 0.5984
# Depth: 2, Train ROC AUC: 0.6640, Valid ROC AUC: 0.6626
# Depth: 3, Train ROC AUC: 0.6916, Valid ROC AUC: 0.6895
# Depth: 4, Train ROC AUC: 0.7029, Valid ROC AUC: 0.7012
# Depth: 5, Train ROC AUC: 0.7112, Valid ROC AUC: 0.7087
# Depth: 6, Train ROC AUC: 0.7161, Valid ROC AUC: 0.7117
# Depth: 7, Train ROC AUC: 0.7196, Valid ROC AUC: 0.7130
# Depth: 8, Train ROC AUC: 0.7223, Valid ROC AUC: 0.7133
# Depth: 9, Train ROC AUC: 0.7254, Valid ROC AUC: 0.7122
# Early stopping triggered at depth: 9
# 최적 Depth: 8, 최종 Train ROC AUC: 0.7223, 최종 Valid ROC AUC: 0.7133
#
# === Ensemble Model 28/500 ===
# Depth: 1, Train ROC AUC: 0.5975, Valid ROC AUC: 0.5988
# Depth: 2, Train ROC AUC: 0.6639, Valid ROC AUC: 0.6629
# Depth: 3, Train ROC AUC: 0.6915, Valid ROC AUC: 0.6898
# Depth: 4, Train ROC AUC: 0.7029, Valid ROC AUC: 0.7012
# Depth: 5, Train ROC AUC: 0.7108, Valid ROC AUC: 0.7103
# Depth: 6, Train ROC AUC: 0.7158, Valid ROC AUC: 0.7137
# Depth: 7, Train ROC AUC: 0.7187, Valid ROC AUC: 0.7160
# Depth: 8, Train ROC AUC: 0.7214, Valid ROC AUC: 0.7155
# Early stopping triggered at depth: 8
# 최적 Depth: 7, 최종 Train ROC AUC: 0.7187, 최종 Valid ROC AUC: 0.7160
#
# === Ensemble Model 29/500 ===
# Depth: 1, Train ROC AUC: 0.5978, Valid ROC AUC: 0.5976
# Depth: 2, Train ROC AUC: 0.6640, Valid ROC AUC: 0.6628
# Depth: 3, Train ROC AUC: 0.6916, Valid ROC AUC: 0.6893
# Depth: 4, Train ROC AUC: 0.7030, Valid ROC AUC: 0.7009
# Depth: 5, Train ROC AUC: 0.7112, Valid ROC AUC: 0.7088
# Depth: 6, Train ROC AUC: 0.7156, Valid ROC AUC: 0.7131
# Depth: 7, Train ROC AUC: 0.7191, Valid ROC AUC: 0.7151
# Depth: 8, Train ROC AUC: 0.7218, Valid ROC AUC: 0.7153
# Depth: 9, Train ROC AUC: 0.7248, Valid ROC AUC: 0.7143
# Early stopping triggered at depth: 9
# 최적 Depth: 8, 최종 Train ROC AUC: 0.7218, 최종 Valid ROC AUC: 0.7153
#
# === Ensemble Model 30/500 ===
# Depth: 1, Train ROC AUC: 0.5975, Valid ROC AUC: 0.5988
# Depth: 2, Train ROC AUC: 0.6652, Valid ROC AUC: 0.6633
# Depth: 3, Train ROC AUC: 0.6910, Valid ROC AUC: 0.6892
# Depth: 4, Train ROC AUC: 0.7039, Valid ROC AUC: 0.7026
# Depth: 5, Train ROC AUC: 0.7107, Valid ROC AUC: 0.7090
# Depth: 6, Train ROC AUC: 0.7157, Valid ROC AUC: 0.7132
# Depth: 7, Train ROC AUC: 0.7189, Valid ROC AUC: 0.7159
# Depth: 8, Train ROC AUC: 0.7217, Valid ROC AUC: 0.7150
# Early stopping triggered at depth: 8
# 최적 Depth: 7, 최종 Train ROC AUC: 0.7189, 최종 Valid ROC AUC: 0.7159
#
# === Ensemble Model 31/500 ===
# Depth: 1, Train ROC AUC: 0.5975, Valid ROC AUC: 0.5988
# Depth: 2, Train ROC AUC: 0.6634, Valid ROC AUC: 0.6652
# Depth: 3, Train ROC AUC: 0.6912, Valid ROC AUC: 0.6908
# Depth: 4, Train ROC AUC: 0.7024, Valid ROC AUC: 0.7000
# Depth: 5, Train ROC AUC: 0.7107, Valid ROC AUC: 0.7083
# Depth: 6, Train ROC AUC: 0.7158, Valid ROC AUC: 0.7126
# Depth: 7, Train ROC AUC: 0.7189, Valid ROC AUC: 0.7149
# Depth: 8, Train ROC AUC: 0.7216, Valid ROC AUC: 0.7155
# Depth: 9, Train ROC AUC: 0.7245, Valid ROC AUC: 0.7151
# Early stopping triggered at depth: 9
# 최적 Depth: 8, 최종 Train ROC AUC: 0.7216, 최종 Valid ROC AUC: 0.7155
#
# === Ensemble Model 32/500 ===
# Depth: 1, Train ROC AUC: 0.5977, Valid ROC AUC: 0.5980
# Depth: 2, Train ROC AUC: 0.6645, Valid ROC AUC: 0.6658
# Depth: 3, Train ROC AUC: 0.6905, Valid ROC AUC: 0.6918
# Depth: 4, Train ROC AUC: 0.7032, Valid ROC AUC: 0.7052
# Depth: 5, Train ROC AUC: 0.7099, Valid ROC AUC: 0.7121
# Depth: 6, Train ROC AUC: 0.7150, Valid ROC AUC: 0.7158
# Depth: 7, Train ROC AUC: 0.7182, Valid ROC AUC: 0.7177
# Depth: 8, Train ROC AUC: 0.7208, Valid ROC AUC: 0.7186
# Depth: 9, Train ROC AUC: 0.7237, Valid ROC AUC: 0.7176
# Early stopping triggered at depth: 9
# 최적 Depth: 8, 최종 Train ROC AUC: 0.7208, 최종 Valid ROC AUC: 0.7186
#
# === Ensemble Model 33/500 ===
# Depth: 1, Train ROC AUC: 0.5975, Valid ROC AUC: 0.5991
# Depth: 2, Train ROC AUC: 0.6634, Valid ROC AUC: 0.6650
# Depth: 3, Train ROC AUC: 0.6908, Valid ROC AUC: 0.6925
# Depth: 4, Train ROC AUC: 0.7021, Valid ROC AUC: 0.7044
# Depth: 5, Train ROC AUC: 0.7101, Valid ROC AUC: 0.7132
# Depth: 6, Train ROC AUC: 0.7146, Valid ROC AUC: 0.7176
# Depth: 7, Train ROC AUC: 0.7179, Valid ROC AUC: 0.7195
# Depth: 8, Train ROC AUC: 0.7207, Valid ROC AUC: 0.7191
# Early stopping triggered at depth: 8
# 최적 Depth: 7, 최종 Train ROC AUC: 0.7179, 최종 Valid ROC AUC: 0.7195
#
# === Ensemble Model 34/500 ===
# Depth: 1, Train ROC AUC: 0.5974, Valid ROC AUC: 0.5993
# Depth: 2, Train ROC AUC: 0.6642, Valid ROC AUC: 0.6618
# Depth: 3, Train ROC AUC: 0.6919, Valid ROC AUC: 0.6882
# Depth: 4, Train ROC AUC: 0.7033, Valid ROC AUC: 0.6998
# Depth: 5, Train ROC AUC: 0.7113, Valid ROC AUC: 0.7076
# Depth: 6, Train ROC AUC: 0.7158, Valid ROC AUC: 0.7120
# Depth: 7, Train ROC AUC: 0.7192, Valid ROC AUC: 0.7139
# Depth: 8, Train ROC AUC: 0.7219, Valid ROC AUC: 0.7133
# Early stopping triggered at depth: 8
# 최적 Depth: 7, 최종 Train ROC AUC: 0.7192, 최종 Valid ROC AUC: 0.7139
#
# === Ensemble Model 35/500 ===
# Depth: 1, Train ROC AUC: 0.5980, Valid ROC AUC: 0.5970
# Depth: 2, Train ROC AUC: 0.6651, Valid ROC AUC: 0.6633
# Depth: 3, Train ROC AUC: 0.6908, Valid ROC AUC: 0.6902
# Depth: 4, Train ROC AUC: 0.7030, Valid ROC AUC: 0.7017
# Depth: 5, Train ROC AUC: 0.7106, Valid ROC AUC: 0.7096
# Depth: 6, Train ROC AUC: 0.7155, Valid ROC AUC: 0.7132
# Depth: 7, Train ROC AUC: 0.7185, Valid ROC AUC: 0.7162
# Depth: 8, Train ROC AUC: 0.7209, Valid ROC AUC: 0.7169
# Depth: 9, Train ROC AUC: 0.7239, Valid ROC AUC: 0.7167
# Early stopping triggered at depth: 9
# 최적 Depth: 8, 최종 Train ROC AUC: 0.7209, 최종 Valid ROC AUC: 0.7169
#
# === Ensemble Model 36/500 ===
# Depth: 1, Train ROC AUC: 0.5976, Valid ROC AUC: 0.5983
# Depth: 2, Train ROC AUC: 0.6639, Valid ROC AUC: 0.6632
# Depth: 3, Train ROC AUC: 0.6912, Valid ROC AUC: 0.6911
# Depth: 4, Train ROC AUC: 0.7025, Valid ROC AUC: 0.7018
# Depth: 5, Train ROC AUC: 0.7108, Valid ROC AUC: 0.7105
# Depth: 6, Train ROC AUC: 0.7154, Valid ROC AUC: 0.7150
# Depth: 7, Train ROC AUC: 0.7184, Valid ROC AUC: 0.7168
# Depth: 8, Train ROC AUC: 0.7212, Valid ROC AUC: 0.7173
# Depth: 9, Train ROC AUC: 0.7241, Valid ROC AUC: 0.7167
# Early stopping triggered at depth: 9
# 최적 Depth: 8, 최종 Train ROC AUC: 0.7212, 최종 Valid ROC AUC: 0.7173
#
# === Ensemble Model 37/500 ===
# Depth: 1, Train ROC AUC: 0.5977, Valid ROC AUC: 0.5980
# Depth: 2, Train ROC AUC: 0.6639, Valid ROC AUC: 0.6631
# Depth: 3, Train ROC AUC: 0.6915, Valid ROC AUC: 0.6897
# Depth: 4, Train ROC AUC: 0.7033, Valid ROC AUC: 0.6997
# Depth: 5, Train ROC AUC: 0.7113, Valid ROC AUC: 0.7085
# Depth: 6, Train ROC AUC: 0.7154, Valid ROC AUC: 0.7136
# Depth: 7, Train ROC AUC: 0.7187, Valid ROC AUC: 0.7159
# Depth: 8, Train ROC AUC: 0.7215, Valid ROC AUC: 0.7158
# Early stopping triggered at depth: 8
# 최적 Depth: 7, 최종 Train ROC AUC: 0.7187, 최종 Valid ROC AUC: 0.7159
#
# === Ensemble Model 38/500 ===
# Depth: 1, Train ROC AUC: 0.5973, Valid ROC AUC: 0.5998
# Depth: 2, Train ROC AUC: 0.6644, Valid ROC AUC: 0.6662
# Depth: 3, Train ROC AUC: 0.6909, Valid ROC AUC: 0.6901
# Depth: 4, Train ROC AUC: 0.7033, Valid ROC AUC: 0.7050
# Depth: 5, Train ROC AUC: 0.7103, Valid ROC AUC: 0.7121
# Depth: 6, Train ROC AUC: 0.7151, Valid ROC AUC: 0.7164
# Depth: 7, Train ROC AUC: 0.7187, Valid ROC AUC: 0.7167
# Depth: 8, Train ROC AUC: 0.7213, Valid ROC AUC: 0.7168
# Depth: 9, Train ROC AUC: 0.7246, Valid ROC AUC: 0.7153
# Early stopping triggered at depth: 9
# 최적 Depth: 8, 최종 Train ROC AUC: 0.7213, 최종 Valid ROC AUC: 0.7168
#
# === Ensemble Model 39/500 ===
# Depth: 1, Train ROC AUC: 0.5978, Valid ROC AUC: 0.5977
# Depth: 2, Train ROC AUC: 0.6655, Valid ROC AUC: 0.6621
# Depth: 3, Train ROC AUC: 0.6915, Valid ROC AUC: 0.6875
# Depth: 4, Train ROC AUC: 0.7046, Valid ROC AUC: 0.6995
# Depth: 5, Train ROC AUC: 0.7112, Valid ROC AUC: 0.7070
# Depth: 6, Train ROC AUC: 0.7158, Valid ROC AUC: 0.7114
# Depth: 7, Train ROC AUC: 0.7190, Valid ROC AUC: 0.7140
# Depth: 8, Train ROC AUC: 0.7216, Valid ROC AUC: 0.7146
# Depth: 9, Train ROC AUC: 0.7245, Valid ROC AUC: 0.7129
# Early stopping triggered at depth: 9
# 최적 Depth: 8, 최종 Train ROC AUC: 0.7216, 최종 Valid ROC AUC: 0.7146
#
# === Ensemble Model 40/500 ===
# Depth: 1, Train ROC AUC: 0.5977, Valid ROC AUC: 0.5982
# Depth: 2, Train ROC AUC: 0.6649, Valid ROC AUC: 0.6644
# Depth: 3, Train ROC AUC: 0.6912, Valid ROC AUC: 0.6892
# Depth: 4, Train ROC AUC: 0.7037, Valid ROC AUC: 0.7023
# Depth: 5, Train ROC AUC: 0.7108, Valid ROC AUC: 0.7088
# Depth: 6, Train ROC AUC: 0.7157, Valid ROC AUC: 0.7126
# Depth: 7, Train ROC AUC: 0.7190, Valid ROC AUC: 0.7146
# Depth: 8, Train ROC AUC: 0.7219, Valid ROC AUC: 0.7148
# Depth: 9, Train ROC AUC: 0.7247, Valid ROC AUC: 0.7137
# Early stopping triggered at depth: 9
# 최적 Depth: 8, 최종 Train ROC AUC: 0.7219, 최종 Valid ROC AUC: 0.7148
#
# === Ensemble Model 41/500 ===
# Depth: 1, Train ROC AUC: 0.5976, Valid ROC AUC: 0.5986
# Depth: 2, Train ROC AUC: 0.6638, Valid ROC AUC: 0.6636
# Depth: 3, Train ROC AUC: 0.6910, Valid ROC AUC: 0.6917
# Depth: 4, Train ROC AUC: 0.7021, Valid ROC AUC: 0.7045
# Depth: 5, Train ROC AUC: 0.7101, Valid ROC AUC: 0.7131
# Depth: 6, Train ROC AUC: 0.7146, Valid ROC AUC: 0.7178
# Depth: 7, Train ROC AUC: 0.7178, Valid ROC AUC: 0.7203
# Depth: 8, Train ROC AUC: 0.7204, Valid ROC AUC: 0.7193
# Early stopping triggered at depth: 8
# 최적 Depth: 7, 최종 Train ROC AUC: 0.7178, 최종 Valid ROC AUC: 0.7203
#
# === Ensemble Model 42/500 ===
# Depth: 1, Train ROC AUC: 0.5981, Valid ROC AUC: 0.5965
# Depth: 2, Train ROC AUC: 0.6647, Valid ROC AUC: 0.6598
# Depth: 3, Train ROC AUC: 0.6918, Valid ROC AUC: 0.6884
# Depth: 4, Train ROC AUC: 0.7028, Valid ROC AUC: 0.7006
# Depth: 5, Train ROC AUC: 0.7109, Valid ROC AUC: 0.7099
# Depth: 6, Train ROC AUC: 0.7155, Valid ROC AUC: 0.7137
# Depth: 7, Train ROC AUC: 0.7188, Valid ROC AUC: 0.7152
# Depth: 8, Train ROC AUC: 0.7214, Valid ROC AUC: 0.7156
# Depth: 9, Train ROC AUC: 0.7245, Valid ROC AUC: 0.7149
# Early stopping triggered at depth: 9
# 최적 Depth: 8, 최종 Train ROC AUC: 0.7214, 최종 Valid ROC AUC: 0.7156
#
# === Ensemble Model 43/500 ===
# Depth: 1, Train ROC AUC: 0.5979, Valid ROC AUC: 0.5974
# Depth: 2, Train ROC AUC: 0.6629, Valid ROC AUC: 0.6669
# Depth: 3, Train ROC AUC: 0.6904, Valid ROC AUC: 0.6942
# Depth: 4, Train ROC AUC: 0.7026, Valid ROC AUC: 0.7027
# Depth: 5, Train ROC AUC: 0.7106, Valid ROC AUC: 0.7103
# Depth: 6, Train ROC AUC: 0.7153, Valid ROC AUC: 0.7150
# Depth: 7, Train ROC AUC: 0.7184, Valid ROC AUC: 0.7166
# Depth: 8, Train ROC AUC: 0.7211, Valid ROC AUC: 0.7171
# Depth: 9, Train ROC AUC: 0.7239, Valid ROC AUC: 0.7167
# Early stopping triggered at depth: 9
# 최적 Depth: 8, 최종 Train ROC AUC: 0.7211, 최종 Valid ROC AUC: 0.7171
#
# === Ensemble Model 44/500 ===
# Depth: 1, Train ROC AUC: 0.5978, Valid ROC AUC: 0.5978
# Depth: 2, Train ROC AUC: 0.6641, Valid ROC AUC: 0.6623
# Depth: 3, Train ROC AUC: 0.6914, Valid ROC AUC: 0.6901
# Depth: 4, Train ROC AUC: 0.7029, Valid ROC AUC: 0.7013
# Depth: 5, Train ROC AUC: 0.7109, Valid ROC AUC: 0.7097
# Depth: 6, Train ROC AUC: 0.7157, Valid ROC AUC: 0.7133
# Depth: 7, Train ROC AUC: 0.7189, Valid ROC AUC: 0.7159
# Depth: 8, Train ROC AUC: 0.7215, Valid ROC AUC: 0.7162
# Depth: 9, Train ROC AUC: 0.7249, Valid ROC AUC: 0.7151
# Early stopping triggered at depth: 9
# 최적 Depth: 8, 최종 Train ROC AUC: 0.7215, 최종 Valid ROC AUC: 0.7162
#
# === Ensemble Model 45/500 ===
# Depth: 1, Train ROC AUC: 0.5973, Valid ROC AUC: 0.5998
# Depth: 2, Train ROC AUC: 0.6642, Valid ROC AUC: 0.6670
# Depth: 3, Train ROC AUC: 0.6903, Valid ROC AUC: 0.6928
# Depth: 4, Train ROC AUC: 0.7033, Valid ROC AUC: 0.7076
# Depth: 5, Train ROC AUC: 0.7101, Valid ROC AUC: 0.7132
# Depth: 6, Train ROC AUC: 0.7145, Valid ROC AUC: 0.7168
# Depth: 7, Train ROC AUC: 0.7181, Valid ROC AUC: 0.7188
# Depth: 8, Train ROC AUC: 0.7207, Valid ROC AUC: 0.7196
# Depth: 9, Train ROC AUC: 0.7237, Valid ROC AUC: 0.7191
# Early stopping triggered at depth: 9
# 최적 Depth: 8, 최종 Train ROC AUC: 0.7207, 최종 Valid ROC AUC: 0.7196
#
# === Ensemble Model 46/500 ===
# Depth: 1, Train ROC AUC: 0.5976, Valid ROC AUC: 0.5984
# Depth: 2, Train ROC AUC: 0.6651, Valid ROC AUC: 0.6637
# Depth: 3, Train ROC AUC: 0.6909, Valid ROC AUC: 0.6900
# Depth: 4, Train ROC AUC: 0.7041, Valid ROC AUC: 0.7041
# Depth: 5, Train ROC AUC: 0.7108, Valid ROC AUC: 0.7110
# Depth: 6, Train ROC AUC: 0.7151, Valid ROC AUC: 0.7141
# Depth: 7, Train ROC AUC: 0.7185, Valid ROC AUC: 0.7171
# Depth: 8, Train ROC AUC: 0.7214, Valid ROC AUC: 0.7179
# Depth: 9, Train ROC AUC: 0.7245, Valid ROC AUC: 0.7176
# Early stopping triggered at depth: 9
# 최적 Depth: 8, 최종 Train ROC AUC: 0.7214, 최종 Valid ROC AUC: 0.7179
#
# === Ensemble Model 47/500 ===
# Depth: 1, Train ROC AUC: 0.5976, Valid ROC AUC: 0.5983
# Depth: 2, Train ROC AUC: 0.6639, Valid ROC AUC: 0.6631
# Depth: 3, Train ROC AUC: 0.6914, Valid ROC AUC: 0.6902
# Depth: 4, Train ROC AUC: 0.7029, Valid ROC AUC: 0.7014
# Depth: 5, Train ROC AUC: 0.7109, Valid ROC AUC: 0.7096
# Depth: 6, Train ROC AUC: 0.7156, Valid ROC AUC: 0.7125
# Depth: 7, Train ROC AUC: 0.7189, Valid ROC AUC: 0.7148
# Depth: 8, Train ROC AUC: 0.7217, Valid ROC AUC: 0.7155
# Depth: 9, Train ROC AUC: 0.7248, Valid ROC AUC: 0.7156
# Depth: 10, Train ROC AUC: 0.7290, Valid ROC AUC: 0.7134
# Early stopping triggered at depth: 10
# 최적 Depth: 9, 최종 Train ROC AUC: 0.7248, 최종 Valid ROC AUC: 0.7156
#
# === Ensemble Model 48/500 ===
# Depth: 1, Train ROC AUC: 0.5979, Valid ROC AUC: 0.5971
# Depth: 2, Train ROC AUC: 0.6639, Valid ROC AUC: 0.6630
# Depth: 3, Train ROC AUC: 0.6917, Valid ROC AUC: 0.6890
# Depth: 4, Train ROC AUC: 0.7033, Valid ROC AUC: 0.6997
# Depth: 5, Train ROC AUC: 0.7113, Valid ROC AUC: 0.7082
# Depth: 6, Train ROC AUC: 0.7160, Valid ROC AUC: 0.7122
# Depth: 7, Train ROC AUC: 0.7192, Valid ROC AUC: 0.7150
# Depth: 8, Train ROC AUC: 0.7220, Valid ROC AUC: 0.7141
# Early stopping triggered at depth: 8
# 최적 Depth: 7, 최종 Train ROC AUC: 0.7192, 최종 Valid ROC AUC: 0.7150
#
# === Ensemble Model 49/500 ===
# Depth: 1, Train ROC AUC: 0.5978, Valid ROC AUC: 0.5979
# Depth: 2, Train ROC AUC: 0.6643, Valid ROC AUC: 0.6614
# Depth: 3, Train ROC AUC: 0.6913, Valid ROC AUC: 0.6905
# Depth: 4, Train ROC AUC: 0.7021, Valid ROC AUC: 0.7033
# Depth: 5, Train ROC AUC: 0.7103, Valid ROC AUC: 0.7122
# Depth: 6, Train ROC AUC: 0.7153, Valid ROC AUC: 0.7148
# Depth: 7, Train ROC AUC: 0.7184, Valid ROC AUC: 0.7171
# Depth: 8, Train ROC AUC: 0.7210, Valid ROC AUC: 0.7175
# Depth: 9, Train ROC AUC: 0.7241, Valid ROC AUC: 0.7171
# Early stopping triggered at depth: 9
# 최적 Depth: 8, 최종 Train ROC AUC: 0.7210, 최종 Valid ROC AUC: 0.7175
#
# === Ensemble Model 50/500 ===
# Depth: 1, Train ROC AUC: 0.5976, Valid ROC AUC: 0.5986
# Depth: 2, Train ROC AUC: 0.6648, Valid ROC AUC: 0.6646
# Depth: 3, Train ROC AUC: 0.6911, Valid ROC AUC: 0.6894
# Depth: 4, Train ROC AUC: 0.7031, Valid ROC AUC: 0.7011
# Depth: 5, Train ROC AUC: 0.7116, Valid ROC AUC: 0.7067
# Depth: 6, Train ROC AUC: 0.7163, Valid ROC AUC: 0.7119
# Depth: 7, Train ROC AUC: 0.7192, Valid ROC AUC: 0.7143
# Depth: 8, Train ROC AUC: 0.7216, Valid ROC AUC: 0.7145
# Depth: 9, Train ROC AUC: 0.7247, Valid ROC AUC: 0.7147
# Depth: 10, Train ROC AUC: 0.7282, Valid ROC AUC: 0.7124
# Early stopping triggered at depth: 10
# 최적 Depth: 9, 최종 Train ROC AUC: 0.7247, 최종 Valid ROC AUC: 0.7147
#
# === Ensemble Model 51/500 ===
# Depth: 1, Train ROC AUC: 0.5980, Valid ROC AUC: 0.5970
# Depth: 2, Train ROC AUC: 0.6638, Valid ROC AUC: 0.6637
# Depth: 3, Train ROC AUC: 0.6913, Valid ROC AUC: 0.6906
# Depth: 4, Train ROC AUC: 0.7023, Valid ROC AUC: 0.7038
# Depth: 5, Train ROC AUC: 0.7103, Valid ROC AUC: 0.7123
# Depth: 6, Train ROC AUC: 0.7153, Valid ROC AUC: 0.7147
# Depth: 7, Train ROC AUC: 0.7189, Valid ROC AUC: 0.7160
# Depth: 8, Train ROC AUC: 0.7219, Valid ROC AUC: 0.7153
# Early stopping triggered at depth: 8
# 최적 Depth: 7, 최종 Train ROC AUC: 0.7189, 최종 Valid ROC AUC: 0.7160
#
# === Ensemble Model 52/500 ===
# Depth: 1, Train ROC AUC: 0.5978, Valid ROC AUC: 0.5976
# Depth: 2, Train ROC AUC: 0.6646, Valid ROC AUC: 0.6655
# Depth: 3, Train ROC AUC: 0.6902, Valid ROC AUC: 0.6926
# Depth: 4, Train ROC AUC: 0.7024, Valid ROC AUC: 0.7040
# Depth: 5, Train ROC AUC: 0.7103, Valid ROC AUC: 0.7122
# Depth: 6, Train ROC AUC: 0.7153, Valid ROC AUC: 0.7162
# Depth: 7, Train ROC AUC: 0.7182, Valid ROC AUC: 0.7185
# Depth: 8, Train ROC AUC: 0.7209, Valid ROC AUC: 0.7183
# Early stopping triggered at depth: 8
# 최적 Depth: 7, 최종 Train ROC AUC: 0.7182, 최종 Valid ROC AUC: 0.7185
#
# === Ensemble Model 53/500 ===
# Depth: 1, Train ROC AUC: 0.5979, Valid ROC AUC: 0.5971
# Depth: 2, Train ROC AUC: 0.6638, Valid ROC AUC: 0.6635
# Depth: 3, Train ROC AUC: 0.6910, Valid ROC AUC: 0.6916
# Depth: 4, Train ROC AUC: 0.7025, Valid ROC AUC: 0.7030
# Depth: 5, Train ROC AUC: 0.7107, Valid ROC AUC: 0.7107
# Depth: 6, Train ROC AUC: 0.7153, Valid ROC AUC: 0.7152
# Depth: 7, Train ROC AUC: 0.7186, Valid ROC AUC: 0.7174
# Depth: 8, Train ROC AUC: 0.7214, Valid ROC AUC: 0.7169
# Early stopping triggered at depth: 8
# 최적 Depth: 7, 최종 Train ROC AUC: 0.7186, 최종 Valid ROC AUC: 0.7174
#
# === Ensemble Model 54/500 ===
# Depth: 1, Train ROC AUC: 0.5981, Valid ROC AUC: 0.5964
# Depth: 2, Train ROC AUC: 0.6634, Valid ROC AUC: 0.6652
# Depth: 3, Train ROC AUC: 0.6906, Valid ROC AUC: 0.6934
# Depth: 4, Train ROC AUC: 0.7023, Valid ROC AUC: 0.7036
# Depth: 5, Train ROC AUC: 0.7105, Valid ROC AUC: 0.7103
# Depth: 6, Train ROC AUC: 0.7148, Valid ROC AUC: 0.7149
# Depth: 7, Train ROC AUC: 0.7183, Valid ROC AUC: 0.7168
# Depth: 8, Train ROC AUC: 0.7209, Valid ROC AUC: 0.7176
# Depth: 9, Train ROC AUC: 0.7240, Valid ROC AUC: 0.7181
# Depth: 10, Train ROC AUC: 0.7278, Valid ROC AUC: 0.7163
# Early stopping triggered at depth: 10
# 최적 Depth: 9, 최종 Train ROC AUC: 0.7240, 최종 Valid ROC AUC: 0.7181
#
# === Ensemble Model 55/500 ===
# Depth: 1, Train ROC AUC: 0.5979, Valid ROC AUC: 0.5974
# Depth: 2, Train ROC AUC: 0.6634, Valid ROC AUC: 0.6651
# Depth: 3, Train ROC AUC: 0.6910, Valid ROC AUC: 0.6918
# Depth: 4, Train ROC AUC: 0.7023, Valid ROC AUC: 0.7037
# Depth: 5, Train ROC AUC: 0.7101, Valid ROC AUC: 0.7129
# Depth: 6, Train ROC AUC: 0.7146, Valid ROC AUC: 0.7171
# Depth: 7, Train ROC AUC: 0.7179, Valid ROC AUC: 0.7189
# Depth: 8, Train ROC AUC: 0.7208, Valid ROC AUC: 0.7186
# Early stopping triggered at depth: 8
# 최적 Depth: 7, 최종 Train ROC AUC: 0.7179, 최종 Valid ROC AUC: 0.7189
#
# === Ensemble Model 56/500 ===
# Depth: 1, Train ROC AUC: 0.5979, Valid ROC AUC: 0.5973
# Depth: 2, Train ROC AUC: 0.6634, Valid ROC AUC: 0.6650
# Depth: 3, Train ROC AUC: 0.6908, Valid ROC AUC: 0.6925
# Depth: 4, Train ROC AUC: 0.7023, Valid ROC AUC: 0.7038
# Depth: 5, Train ROC AUC: 0.7104, Valid ROC AUC: 0.7120
# Depth: 6, Train ROC AUC: 0.7152, Valid ROC AUC: 0.7151
# Depth: 7, Train ROC AUC: 0.7185, Valid ROC AUC: 0.7171
# Depth: 8, Train ROC AUC: 0.7213, Valid ROC AUC: 0.7168
# Early stopping triggered at depth: 8
# 최적 Depth: 7, 최종 Train ROC AUC: 0.7185, 최종 Valid ROC AUC: 0.7171
#
# === Ensemble Model 57/500 ===
# Depth: 1, Train ROC AUC: 0.5978, Valid ROC AUC: 0.5978
# Depth: 2, Train ROC AUC: 0.6637, Valid ROC AUC: 0.6637
# Depth: 3, Train ROC AUC: 0.6914, Valid ROC AUC: 0.6899
# Depth: 4, Train ROC AUC: 0.7032, Valid ROC AUC: 0.7002
# Depth: 5, Train ROC AUC: 0.7112, Valid ROC AUC: 0.7075
# Depth: 6, Train ROC AUC: 0.7159, Valid ROC AUC: 0.7114
# Depth: 7, Train ROC AUC: 0.7191, Valid ROC AUC: 0.7140
# Depth: 8, Train ROC AUC: 0.7219, Valid ROC AUC: 0.7140
# Depth: 9, Train ROC AUC: 0.7250, Valid ROC AUC: 0.7140
# Depth: 10, Train ROC AUC: 0.7287, Valid ROC AUC: 0.7128
# Early stopping triggered at depth: 10
# 최적 Depth: 9, 최종 Train ROC AUC: 0.7250, 최종 Valid ROC AUC: 0.7140
#
# === Ensemble Model 58/500 ===
# Depth: 1, Train ROC AUC: 0.5978, Valid ROC AUC: 0.5978
# Depth: 2, Train ROC AUC: 0.6642, Valid ROC AUC: 0.6619
# Depth: 3, Train ROC AUC: 0.6919, Valid ROC AUC: 0.6884
# Depth: 4, Train ROC AUC: 0.7029, Valid ROC AUC: 0.7013
# Depth: 5, Train ROC AUC: 0.7109, Valid ROC AUC: 0.7099
# Depth: 6, Train ROC AUC: 0.7156, Valid ROC AUC: 0.7141
# Depth: 7, Train ROC AUC: 0.7190, Valid ROC AUC: 0.7166
# Depth: 8, Train ROC AUC: 0.7218, Valid ROC AUC: 0.7156
# Early stopping triggered at depth: 8
# 최적 Depth: 7, 최종 Train ROC AUC: 0.7190, 최종 Valid ROC AUC: 0.7166
#
# === Ensemble Model 59/500 ===
# Depth: 1, Train ROC AUC: 0.5978, Valid ROC AUC: 0.5978
# Depth: 2, Train ROC AUC: 0.6642, Valid ROC AUC: 0.6620
# Depth: 3, Train ROC AUC: 0.6916, Valid ROC AUC: 0.6892
# Depth: 4, Train ROC AUC: 0.7031, Valid ROC AUC: 0.7004
# Depth: 5, Train ROC AUC: 0.7112, Valid ROC AUC: 0.7083
# Depth: 6, Train ROC AUC: 0.7155, Valid ROC AUC: 0.7122
# Depth: 7, Train ROC AUC: 0.7190, Valid ROC AUC: 0.7147
# Depth: 8, Train ROC AUC: 0.7218, Valid ROC AUC: 0.7146
# Early stopping triggered at depth: 8
# 최적 Depth: 7, 최종 Train ROC AUC: 0.7190, 최종 Valid ROC AUC: 0.7147
#
# === Ensemble Model 60/500 ===
# Depth: 1, Train ROC AUC: 0.5977, Valid ROC AUC: 0.5981
# Depth: 2, Train ROC AUC: 0.6634, Valid ROC AUC: 0.6652
# Depth: 3, Train ROC AUC: 0.6911, Valid ROC AUC: 0.6914
# Depth: 4, Train ROC AUC: 0.7028, Valid ROC AUC: 0.7017
# Depth: 5, Train ROC AUC: 0.7110, Valid ROC AUC: 0.7096
# Depth: 6, Train ROC AUC: 0.7155, Valid ROC AUC: 0.7134
# Depth: 7, Train ROC AUC: 0.7189, Valid ROC AUC: 0.7155
# Depth: 8, Train ROC AUC: 0.7214, Valid ROC AUC: 0.7158
# Depth: 9, Train ROC AUC: 0.7245, Valid ROC AUC: 0.7151
# Early stopping triggered at depth: 9
# 최적 Depth: 8, 최종 Train ROC AUC: 0.7214, 최종 Valid ROC AUC: 0.7158
#
# === Ensemble Model 61/500 ===
# Depth: 1, Train ROC AUC: 0.5979, Valid ROC AUC: 0.5975
# Depth: 2, Train ROC AUC: 0.6642, Valid ROC AUC: 0.6619
# Depth: 3, Train ROC AUC: 0.6913, Valid ROC AUC: 0.6906
# Depth: 4, Train ROC AUC: 0.7026, Valid ROC AUC: 0.7023
# Depth: 5, Train ROC AUC: 0.7107, Valid ROC AUC: 0.7107
# Depth: 6, Train ROC AUC: 0.7152, Valid ROC AUC: 0.7142
# Depth: 7, Train ROC AUC: 0.7185, Valid ROC AUC: 0.7160
# Depth: 8, Train ROC AUC: 0.7211, Valid ROC AUC: 0.7167
# Depth: 9, Train ROC AUC: 0.7241, Valid ROC AUC: 0.7154
# Early stopping triggered at depth: 9
# 최적 Depth: 8, 최종 Train ROC AUC: 0.7211, 최종 Valid ROC AUC: 0.7167
#
# === Ensemble Model 62/500 ===
# Depth: 1, Train ROC AUC: 0.5976, Valid ROC AUC: 0.5985
# Depth: 2, Train ROC AUC: 0.6651, Valid ROC AUC: 0.6635
# Depth: 3, Train ROC AUC: 0.6907, Valid ROC AUC: 0.6905
# Depth: 4, Train ROC AUC: 0.7034, Valid ROC AUC: 0.7045
# Depth: 5, Train ROC AUC: 0.7104, Valid ROC AUC: 0.7114
# Depth: 6, Train ROC AUC: 0.7152, Valid ROC AUC: 0.7156
# Depth: 7, Train ROC AUC: 0.7185, Valid ROC AUC: 0.7175
# Depth: 8, Train ROC AUC: 0.7213, Valid ROC AUC: 0.7175
# Depth: 9, Train ROC AUC: 0.7242, Valid ROC AUC: 0.7161
# Early stopping triggered at depth: 9
# 최적 Depth: 8, 최종 Train ROC AUC: 0.7213, 최종 Valid ROC AUC: 0.7175
#
# === Ensemble Model 63/500 ===
# Depth: 1, Train ROC AUC: 0.5975, Valid ROC AUC: 0.5990
# Depth: 2, Train ROC AUC: 0.6640, Valid ROC AUC: 0.6679
# Depth: 3, Train ROC AUC: 0.6906, Valid ROC AUC: 0.6915
# Depth: 4, Train ROC AUC: 0.7038, Valid ROC AUC: 0.7029
# Depth: 5, Train ROC AUC: 0.7107, Valid ROC AUC: 0.7097
# Depth: 6, Train ROC AUC: 0.7155, Valid ROC AUC: 0.7141
# Depth: 7, Train ROC AUC: 0.7188, Valid ROC AUC: 0.7156
# Depth: 8, Train ROC AUC: 0.7215, Valid ROC AUC: 0.7164
# Depth: 9, Train ROC AUC: 0.7245, Valid ROC AUC: 0.7137
# Early stopping triggered at depth: 9
# 최적 Depth: 8, 최종 Train ROC AUC: 0.7215, 최종 Valid ROC AUC: 0.7164
#
# === Ensemble Model 64/500 ===
# Depth: 1, Train ROC AUC: 0.5977, Valid ROC AUC: 0.5980
# Depth: 2, Train ROC AUC: 0.6644, Valid ROC AUC: 0.6609
# Depth: 3, Train ROC AUC: 0.6918, Valid ROC AUC: 0.6884
# Depth: 4, Train ROC AUC: 0.7032, Valid ROC AUC: 0.6988
# Depth: 5, Train ROC AUC: 0.7114, Valid ROC AUC: 0.7081
# Depth: 6, Train ROC AUC: 0.7160, Valid ROC AUC: 0.7122
# Depth: 7, Train ROC AUC: 0.7191, Valid ROC AUC: 0.7150
# Depth: 8, Train ROC AUC: 0.7221, Valid ROC AUC: 0.7142
# Early stopping triggered at depth: 8
# 최적 Depth: 7, 최종 Train ROC AUC: 0.7191, 최종 Valid ROC AUC: 0.7150
#
# === Ensemble Model 65/500 ===
# Depth: 1, Train ROC AUC: 0.5977, Valid ROC AUC: 0.5983
# Depth: 2, Train ROC AUC: 0.6639, Valid ROC AUC: 0.6632
# Depth: 3, Train ROC AUC: 0.6912, Valid ROC AUC: 0.6910
# Depth: 4, Train ROC AUC: 0.7024, Valid ROC AUC: 0.7035
# Depth: 5, Train ROC AUC: 0.7103, Valid ROC AUC: 0.7120
# Depth: 6, Train ROC AUC: 0.7152, Valid ROC AUC: 0.7152
# Depth: 7, Train ROC AUC: 0.7182, Valid ROC AUC: 0.7178
# Depth: 8, Train ROC AUC: 0.7209, Valid ROC AUC: 0.7180
# Depth: 9, Train ROC AUC: 0.7238, Valid ROC AUC: 0.7174
# Early stopping triggered at depth: 9
# 최적 Depth: 8, 최종 Train ROC AUC: 0.7209, 최종 Valid ROC AUC: 0.7180
#
# === Ensemble Model 66/500 ===
# Depth: 1, Train ROC AUC: 0.5978, Valid ROC AUC: 0.5978
# Depth: 2, Train ROC AUC: 0.6636, Valid ROC AUC: 0.6641
# Depth: 3, Train ROC AUC: 0.6911, Valid ROC AUC: 0.6915
# Depth: 4, Train ROC AUC: 0.7024, Valid ROC AUC: 0.7032
# Depth: 5, Train ROC AUC: 0.7106, Valid ROC AUC: 0.7109
# Depth: 6, Train ROC AUC: 0.7150, Valid ROC AUC: 0.7150
# Depth: 7, Train ROC AUC: 0.7182, Valid ROC AUC: 0.7174
# Depth: 8, Train ROC AUC: 0.7210, Valid ROC AUC: 0.7172
# Early stopping triggered at depth: 8
# 최적 Depth: 7, 최종 Train ROC AUC: 0.7182, 최종 Valid ROC AUC: 0.7174
#
# === Ensemble Model 67/500 ===
# Depth: 1, Train ROC AUC: 0.5980, Valid ROC AUC: 0.5970
# Depth: 2, Train ROC AUC: 0.6653, Valid ROC AUC: 0.6628
# Depth: 3, Train ROC AUC: 0.6915, Valid ROC AUC: 0.6878
# Depth: 4, Train ROC AUC: 0.7038, Valid ROC AUC: 0.7017
# Depth: 5, Train ROC AUC: 0.7108, Valid ROC AUC: 0.7079
# Depth: 6, Train ROC AUC: 0.7160, Valid ROC AUC: 0.7124
# Depth: 7, Train ROC AUC: 0.7192, Valid ROC AUC: 0.7139
# Depth: 8, Train ROC AUC: 0.7218, Valid ROC AUC: 0.7141
# Depth: 9, Train ROC AUC: 0.7250, Valid ROC AUC: 0.7126
# Early stopping triggered at depth: 9
# 최적 Depth: 8, 최종 Train ROC AUC: 0.7218, 최종 Valid ROC AUC: 0.7141
#
# === Ensemble Model 68/500 ===
# Depth: 1, Train ROC AUC: 0.5979, Valid ROC AUC: 0.5975
# Depth: 2, Train ROC AUC: 0.6636, Valid ROC AUC: 0.6643
# Depth: 3, Train ROC AUC: 0.6907, Valid ROC AUC: 0.6930
# Depth: 4, Train ROC AUC: 0.7018, Valid ROC AUC: 0.7056
# Depth: 5, Train ROC AUC: 0.7101, Valid ROC AUC: 0.7130
# Depth: 6, Train ROC AUC: 0.7146, Valid ROC AUC: 0.7173
# Depth: 7, Train ROC AUC: 0.7181, Valid ROC AUC: 0.7191
# Depth: 8, Train ROC AUC: 0.7207, Valid ROC AUC: 0.7189
# Early stopping triggered at depth: 8
# 최적 Depth: 7, 최종 Train ROC AUC: 0.7181, 최종 Valid ROC AUC: 0.7191
#
# === Ensemble Model 69/500 ===
# Depth: 1, Train ROC AUC: 0.5977, Valid ROC AUC: 0.5983
# Depth: 2, Train ROC AUC: 0.6653, Valid ROC AUC: 0.6627
# Depth: 3, Train ROC AUC: 0.6914, Valid ROC AUC: 0.6884
# Depth: 4, Train ROC AUC: 0.7050, Valid ROC AUC: 0.7002
# Depth: 5, Train ROC AUC: 0.7115, Valid ROC AUC: 0.7084
# Depth: 6, Train ROC AUC: 0.7159, Valid ROC AUC: 0.7113
# Depth: 7, Train ROC AUC: 0.7196, Valid ROC AUC: 0.7122
# Depth: 8, Train ROC AUC: 0.7225, Valid ROC AUC: 0.7125
# Depth: 9, Train ROC AUC: 0.7256, Valid ROC AUC: 0.7122
# Early stopping triggered at depth: 9
# 최적 Depth: 8, 최종 Train ROC AUC: 0.7225, 최종 Valid ROC AUC: 0.7125
#
# === Ensemble Model 70/500 ===
# Depth: 1, Train ROC AUC: 0.5975, Valid ROC AUC: 0.5988
# Depth: 2, Train ROC AUC: 0.6644, Valid ROC AUC: 0.6661
# Depth: 3, Train ROC AUC: 0.6907, Valid ROC AUC: 0.6911
# Depth: 4, Train ROC AUC: 0.7033, Valid ROC AUC: 0.7047
# Depth: 5, Train ROC AUC: 0.7106, Valid ROC AUC: 0.7106
# Depth: 6, Train ROC AUC: 0.7152, Valid ROC AUC: 0.7144
# Depth: 7, Train ROC AUC: 0.7185, Valid ROC AUC: 0.7172
# Depth: 8, Train ROC AUC: 0.7211, Valid ROC AUC: 0.7173
# Depth: 9, Train ROC AUC: 0.7240, Valid ROC AUC: 0.7162
# Early stopping triggered at depth: 9
# 최적 Depth: 8, 최종 Train ROC AUC: 0.7211, 최종 Valid ROC AUC: 0.7173
#
# === Ensemble Model 71/500 ===
# Depth: 1, Train ROC AUC: 0.5985, Valid ROC AUC: 0.5948
# Depth: 2, Train ROC AUC: 0.6653, Valid ROC AUC: 0.6628
# Depth: 3, Train ROC AUC: 0.6911, Valid ROC AUC: 0.6896
# Depth: 4, Train ROC AUC: 0.7038, Valid ROC AUC: 0.7029
# Depth: 5, Train ROC AUC: 0.7107, Valid ROC AUC: 0.7092
# Depth: 6, Train ROC AUC: 0.7157, Valid ROC AUC: 0.7130
# Depth: 7, Train ROC AUC: 0.7192, Valid ROC AUC: 0.7147
# Depth: 8, Train ROC AUC: 0.7222, Valid ROC AUC: 0.7146
# Early stopping triggered at depth: 8
# 최적 Depth: 7, 최종 Train ROC AUC: 0.7192, 최종 Valid ROC AUC: 0.7147
#
# === Ensemble Model 72/500 ===
# Depth: 1, Train ROC AUC: 0.5975, Valid ROC AUC: 0.5990
# Depth: 2, Train ROC AUC: 0.6639, Valid ROC AUC: 0.6629
# Depth: 3, Train ROC AUC: 0.6915, Valid ROC AUC: 0.6896
# Depth: 4, Train ROC AUC: 0.7025, Valid ROC AUC: 0.7029
# Depth: 5, Train ROC AUC: 0.7107, Valid ROC AUC: 0.7106
# Depth: 6, Train ROC AUC: 0.7154, Valid ROC AUC: 0.7150
# Depth: 7, Train ROC AUC: 0.7186, Valid ROC AUC: 0.7165
# Depth: 8, Train ROC AUC: 0.7211, Valid ROC AUC: 0.7167
# Depth: 9, Train ROC AUC: 0.7241, Valid ROC AUC: 0.7167
# Early stopping triggered at depth: 9
# 최적 Depth: 8, 최종 Train ROC AUC: 0.7211, 최종 Valid ROC AUC: 0.7167
#
# === Ensemble Model 73/500 ===
# Depth: 1, Train ROC AUC: 0.5974, Valid ROC AUC: 0.5993
# Depth: 2, Train ROC AUC: 0.6630, Valid ROC AUC: 0.6666
# Depth: 3, Train ROC AUC: 0.6906, Valid ROC AUC: 0.6934
# Depth: 4, Train ROC AUC: 0.7022, Valid ROC AUC: 0.7041
# Depth: 5, Train ROC AUC: 0.7103, Valid ROC AUC: 0.7124
# Depth: 6, Train ROC AUC: 0.7149, Valid ROC AUC: 0.7163
# Depth: 7, Train ROC AUC: 0.7182, Valid ROC AUC: 0.7180
# Depth: 8, Train ROC AUC: 0.7207, Valid ROC AUC: 0.7183
# Depth: 9, Train ROC AUC: 0.7236, Valid ROC AUC: 0.7186
# Depth: 10, Train ROC AUC: 0.7273, Valid ROC AUC: 0.7177
# Early stopping triggered at depth: 10
# 최적 Depth: 9, 최종 Train ROC AUC: 0.7236, 최종 Valid ROC AUC: 0.7186
#
# === Ensemble Model 74/500 ===
# Depth: 1, Train ROC AUC: 0.5977, Valid ROC AUC: 0.5982
# Depth: 2, Train ROC AUC: 0.6643, Valid ROC AUC: 0.6665
# Depth: 3, Train ROC AUC: 0.6906, Valid ROC AUC: 0.6916
# Depth: 4, Train ROC AUC: 0.7031, Valid ROC AUC: 0.7045
# Depth: 5, Train ROC AUC: 0.7101, Valid ROC AUC: 0.7109
# Depth: 6, Train ROC AUC: 0.7153, Valid ROC AUC: 0.7148
# Depth: 7, Train ROC AUC: 0.7187, Valid ROC AUC: 0.7159
# Depth: 8, Train ROC AUC: 0.7214, Valid ROC AUC: 0.7155
# Early stopping triggered at depth: 8
# 최적 Depth: 7, 최종 Train ROC AUC: 0.7187, 최종 Valid ROC AUC: 0.7159
#
# === Ensemble Model 75/500 ===
# Depth: 1, Train ROC AUC: 0.5978, Valid ROC AUC: 0.5975
# Depth: 2, Train ROC AUC: 0.6644, Valid ROC AUC: 0.6611
# Depth: 3, Train ROC AUC: 0.6921, Valid ROC AUC: 0.6875
# Depth: 4, Train ROC AUC: 0.7032, Valid ROC AUC: 0.6999
# Depth: 5, Train ROC AUC: 0.7112, Valid ROC AUC: 0.7077
# Depth: 6, Train ROC AUC: 0.7159, Valid ROC AUC: 0.7114
# Depth: 7, Train ROC AUC: 0.7194, Valid ROC AUC: 0.7140
# Depth: 8, Train ROC AUC: 0.7220, Valid ROC AUC: 0.7142
# Depth: 9, Train ROC AUC: 0.7251, Valid ROC AUC: 0.7141
# Early stopping triggered at depth: 9
# 최적 Depth: 8, 최종 Train ROC AUC: 0.7220, 최종 Valid ROC AUC: 0.7142
#
# === Ensemble Model 76/500 ===
# Depth: 1, Train ROC AUC: 0.5976, Valid ROC AUC: 0.5984
# Depth: 2, Train ROC AUC: 0.6649, Valid ROC AUC: 0.6643
# Depth: 3, Train ROC AUC: 0.6906, Valid ROC AUC: 0.6910
# Depth: 4, Train ROC AUC: 0.7035, Valid ROC AUC: 0.7045
# Depth: 5, Train ROC AUC: 0.7101, Valid ROC AUC: 0.7120
# Depth: 6, Train ROC AUC: 0.7150, Valid ROC AUC: 0.7156
# Depth: 7, Train ROC AUC: 0.7184, Valid ROC AUC: 0.7182
# Depth: 8, Train ROC AUC: 0.7210, Valid ROC AUC: 0.7193
# Depth: 9, Train ROC AUC: 0.7239, Valid ROC AUC: 0.7180
# Early stopping triggered at depth: 9
# 최적 Depth: 8, 최종 Train ROC AUC: 0.7210, 최종 Valid ROC AUC: 0.7193
#
# === Ensemble Model 77/500 ===
# Depth: 1, Train ROC AUC: 0.5977, Valid ROC AUC: 0.5979
# Depth: 2, Train ROC AUC: 0.6631, Valid ROC AUC: 0.6663
# Depth: 3, Train ROC AUC: 0.6905, Valid ROC AUC: 0.6938
# Depth: 4, Train ROC AUC: 0.7021, Valid ROC AUC: 0.7047
# Depth: 5, Train ROC AUC: 0.7101, Valid ROC AUC: 0.7131
# Depth: 6, Train ROC AUC: 0.7148, Valid ROC AUC: 0.7173
# Depth: 7, Train ROC AUC: 0.7181, Valid ROC AUC: 0.7197
# Depth: 8, Train ROC AUC: 0.7207, Valid ROC AUC: 0.7195
# Early stopping triggered at depth: 8
# 최적 Depth: 7, 최종 Train ROC AUC: 0.7181, 최종 Valid ROC AUC: 0.7197
#
# === Ensemble Model 78/500 ===
# Depth: 1, Train ROC AUC: 0.5982, Valid ROC AUC: 0.5960
# Depth: 2, Train ROC AUC: 0.6637, Valid ROC AUC: 0.6637
# Depth: 3, Train ROC AUC: 0.6912, Valid ROC AUC: 0.6910
# Depth: 4, Train ROC AUC: 0.7028, Valid ROC AUC: 0.7017
# Depth: 5, Train ROC AUC: 0.7110, Valid ROC AUC: 0.7092
# Depth: 6, Train ROC AUC: 0.7154, Valid ROC AUC: 0.7140
# Depth: 7, Train ROC AUC: 0.7186, Valid ROC AUC: 0.7164
# Depth: 8, Train ROC AUC: 0.7214, Valid ROC AUC: 0.7164
# Early stopping triggered at depth: 8
# 최적 Depth: 7, 최종 Train ROC AUC: 0.7186, 최종 Valid ROC AUC: 0.7164
#
# === Ensemble Model 79/500 ===
# Depth: 1, Train ROC AUC: 0.5983, Valid ROC AUC: 0.5958
# Depth: 2, Train ROC AUC: 0.6644, Valid ROC AUC: 0.6612
# Depth: 3, Train ROC AUC: 0.6915, Valid ROC AUC: 0.6896
# Depth: 4, Train ROC AUC: 0.7025, Valid ROC AUC: 0.7029
# Depth: 5, Train ROC AUC: 0.7105, Valid ROC AUC: 0.7115
# Depth: 6, Train ROC AUC: 0.7154, Valid ROC AUC: 0.7139
# Depth: 7, Train ROC AUC: 0.7188, Valid ROC AUC: 0.7157
# Depth: 8, Train ROC AUC: 0.7215, Valid ROC AUC: 0.7155
# Early stopping triggered at depth: 8
# 최적 Depth: 7, 최종 Train ROC AUC: 0.7188, 최종 Valid ROC AUC: 0.7157
#
# === Ensemble Model 80/500 ===
# Depth: 1, Train ROC AUC: 0.5980, Valid ROC AUC: 0.5971
# ...
# Depth: 3, Train ROC AUC: 0.6910, Valid ROC AUC: 0.6895
# Depth: 4, Train ROC AUC: 0.7043, Valid ROC AUC: 0.7025
# Depth: 5, Train ROC AUC: 0.7113, Valid ROC AUC: 0.7087
# Depth: 6, Train ROC AUC: 0.7155, Valid ROC AUC: 0.7120
# Depth: 7, Train ROC AUC: 0.7192, Valid ROC AUC: 0.7145
# Depth: 8, Train ROC AUC: 0.7220, Valid ROC AUC: 0.7146
# Depth: 9, Train ROC AUC: 0.7251, Valid ROC AUC: 0.7135
# Early stopping triggered at depth: 9
# 최적 Depth: 8, 최종 Train ROC AUC: 0.7220, 최종 Valid ROC AUC: 0.7146
#
# === Ensemble Model 476/500 ===
# Depth: 1, Train ROC AUC: 0.5976, Valid ROC AUC: 0.5985
# Depth: 2, Train ROC AUC: 0.6642, Valid ROC AUC: 0.6671
# Depth: 3, Train ROC AUC: 0.6913, Valid ROC AUC: 0.6887
# Depth: 4, Train ROC AUC: 0.7039, Valid ROC AUC: 0.7014
# Depth: 5, Train ROC AUC: 0.7109, Valid ROC AUC: 0.7084
# Depth: 6, Train ROC AUC: 0.7157, Valid ROC AUC: 0.7133
# Depth: 7, Train ROC AUC: 0.7189, Valid ROC AUC: 0.7162
# Depth: 8, Train ROC AUC: 0.7214, Valid ROC AUC: 0.7156
# Early stopping triggered at depth: 8
# 최적 Depth: 7, 최종 Train ROC AUC: 0.7189, 최종 Valid ROC AUC: 0.7162
#
# === Ensemble Model 477/500 ===
# Depth: 1, Train ROC AUC: 0.5978, Valid ROC AUC: 0.5976
# Depth: 2, Train ROC AUC: 0.6653, Valid ROC AUC: 0.6627
# Depth: 3, Train ROC AUC: 0.6914, Valid ROC AUC: 0.6882
# Depth: 4, Train ROC AUC: 0.7044, Valid ROC AUC: 0.7003
# Depth: 5, Train ROC AUC: 0.7113, Valid ROC AUC: 0.7066
# Depth: 6, Train ROC AUC: 0.7163, Valid ROC AUC: 0.7111
# Depth: 7, Train ROC AUC: 0.7193, Valid ROC AUC: 0.7128
# Depth: 8, Train ROC AUC: 0.7219, Valid ROC AUC: 0.7132
# Depth: 9, Train ROC AUC: 0.7246, Valid ROC AUC: 0.7138
# Depth: 10, Train ROC AUC: 0.7280, Valid ROC AUC: 0.7121
# Early stopping triggered at depth: 10
# 최적 Depth: 9, 최종 Train ROC AUC: 0.7246, 최종 Valid ROC AUC: 0.7138
#
# === Ensemble Model 478/500 ===
# Depth: 1, Train ROC AUC: 0.5976, Valid ROC AUC: 0.5987
# Depth: 2, Train ROC AUC: 0.6639, Valid ROC AUC: 0.6632
# Depth: 3, Train ROC AUC: 0.6915, Valid ROC AUC: 0.6898
# Depth: 4, Train ROC AUC: 0.7029, Valid ROC AUC: 0.7012
# Depth: 5, Train ROC AUC: 0.7108, Valid ROC AUC: 0.7102
# Depth: 6, Train ROC AUC: 0.7156, Valid ROC AUC: 0.7132
# Depth: 7, Train ROC AUC: 0.7191, Valid ROC AUC: 0.7150
# Depth: 8, Train ROC AUC: 0.7215, Valid ROC AUC: 0.7153
# Depth: 9, Train ROC AUC: 0.7245, Valid ROC AUC: 0.7158
# Depth: 10, Train ROC AUC: 0.7285, Valid ROC AUC: 0.7138
# Early stopping triggered at depth: 10
# 최적 Depth: 9, 최종 Train ROC AUC: 0.7245, 최종 Valid ROC AUC: 0.7158
#
# === Ensemble Model 479/500 ===
# Depth: 1, Train ROC AUC: 0.5977, Valid ROC AUC: 0.5983
# Depth: 2, Train ROC AUC: 0.6633, Valid ROC AUC: 0.6653
# Depth: 3, Train ROC AUC: 0.6907, Valid ROC AUC: 0.6928
# Depth: 4, Train ROC AUC: 0.7024, Valid ROC AUC: 0.7032
# Depth: 5, Train ROC AUC: 0.7106, Valid ROC AUC: 0.7109
# Depth: 6, Train ROC AUC: 0.7154, Valid ROC AUC: 0.7143
# Depth: 7, Train ROC AUC: 0.7187, Valid ROC AUC: 0.7159
# Depth: 8, Train ROC AUC: 0.7215, Valid ROC AUC: 0.7151
# Early stopping triggered at depth: 8
# 최적 Depth: 7, 최종 Train ROC AUC: 0.7187, 최종 Valid ROC AUC: 0.7159
#
# === Ensemble Model 480/500 ===
# Depth: 1, Train ROC AUC: 0.5982, Valid ROC AUC: 0.5960
# Depth: 2, Train ROC AUC: 0.6645, Valid ROC AUC: 0.6608
# Depth: 3, Train ROC AUC: 0.6915, Valid ROC AUC: 0.6897
# Depth: 4, Train ROC AUC: 0.7028, Valid ROC AUC: 0.7014
# Depth: 5, Train ROC AUC: 0.7109, Valid ROC AUC: 0.7097
# Depth: 6, Train ROC AUC: 0.7156, Valid ROC AUC: 0.7133
# Depth: 7, Train ROC AUC: 0.7189, Valid ROC AUC: 0.7158
# Depth: 8, Train ROC AUC: 0.7214, Valid ROC AUC: 0.7163
# Depth: 9, Train ROC AUC: 0.7247, Valid ROC AUC: 0.7163
# Early stopping triggered at depth: 9
# 최적 Depth: 8, 최종 Train ROC AUC: 0.7214, 최종 Valid ROC AUC: 0.7163
#
# === Ensemble Model 481/500 ===
# Depth: 1, Train ROC AUC: 0.5980, Valid ROC AUC: 0.5970
# Depth: 2, Train ROC AUC: 0.6648, Valid ROC AUC: 0.6593
# Depth: 3, Train ROC AUC: 0.6925, Valid ROC AUC: 0.6857
# Depth: 4, Train ROC AUC: 0.7037, Valid ROC AUC: 0.6981
# Depth: 5, Train ROC AUC: 0.7118, Valid ROC AUC: 0.7062
# Depth: 6, Train ROC AUC: 0.7167, Valid ROC AUC: 0.7095
# Depth: 7, Train ROC AUC: 0.7199, Valid ROC AUC: 0.7118
# Depth: 8, Train ROC AUC: 0.7224, Valid ROC AUC: 0.7124
# Depth: 9, Train ROC AUC: 0.7253, Valid ROC AUC: 0.7126
# Depth: 10, Train ROC AUC: 0.7291, Valid ROC AUC: 0.7114
# Early stopping triggered at depth: 10
# 최적 Depth: 9, 최종 Train ROC AUC: 0.7253, 최종 Valid ROC AUC: 0.7126
#
# === Ensemble Model 482/500 ===
# Depth: 1, Train ROC AUC: 0.5980, Valid ROC AUC: 0.5970
# Depth: 2, Train ROC AUC: 0.6645, Valid ROC AUC: 0.6608
# Depth: 3, Train ROC AUC: 0.6915, Valid ROC AUC: 0.6896
# Depth: 4, Train ROC AUC: 0.7023, Valid ROC AUC: 0.7036
# Depth: 5, Train ROC AUC: 0.7108, Valid ROC AUC: 0.7103
# Depth: 6, Train ROC AUC: 0.7154, Valid ROC AUC: 0.7137
# Depth: 7, Train ROC AUC: 0.7187, Valid ROC AUC: 0.7158
# Depth: 8, Train ROC AUC: 0.7213, Valid ROC AUC: 0.7158
# Early stopping triggered at depth: 8
# 최적 Depth: 7, 최종 Train ROC AUC: 0.7187, 최종 Valid ROC AUC: 0.7158
#
# === Ensemble Model 483/500 ===
# Depth: 1, Train ROC AUC: 0.5979, Valid ROC AUC: 0.5973
# Depth: 2, Train ROC AUC: 0.6637, Valid ROC AUC: 0.6639
# Depth: 3, Train ROC AUC: 0.6910, Valid ROC AUC: 0.6917
# Depth: 4, Train ROC AUC: 0.7027, Valid ROC AUC: 0.7020
# Depth: 5, Train ROC AUC: 0.7107, Valid ROC AUC: 0.7102
# Depth: 6, Train ROC AUC: 0.7153, Valid ROC AUC: 0.7145
# Depth: 7, Train ROC AUC: 0.7184, Valid ROC AUC: 0.7175
# Depth: 8, Train ROC AUC: 0.7210, Valid ROC AUC: 0.7173
# Early stopping triggered at depth: 8
# 최적 Depth: 7, 최종 Train ROC AUC: 0.7184, 최종 Valid ROC AUC: 0.7175
#
# === Ensemble Model 484/500 ===
# Depth: 1, Train ROC AUC: 0.5981, Valid ROC AUC: 0.5965
# Depth: 2, Train ROC AUC: 0.6644, Valid ROC AUC: 0.6612
# Depth: 3, Train ROC AUC: 0.6917, Valid ROC AUC: 0.6888
# Depth: 4, Train ROC AUC: 0.7029, Valid ROC AUC: 0.7012
# Depth: 5, Train ROC AUC: 0.7108, Valid ROC AUC: 0.7101
# Depth: 6, Train ROC AUC: 0.7154, Valid ROC AUC: 0.7146
# Depth: 7, Train ROC AUC: 0.7186, Valid ROC AUC: 0.7157
# Depth: 8, Train ROC AUC: 0.7214, Valid ROC AUC: 0.7155
# Early stopping triggered at depth: 8
# 최적 Depth: 7, 최종 Train ROC AUC: 0.7186, 최종 Valid ROC AUC: 0.7157
#
# === Ensemble Model 485/500 ===
# Depth: 1, Train ROC AUC: 0.5977, Valid ROC AUC: 0.5981
# Depth: 2, Train ROC AUC: 0.6634, Valid ROC AUC: 0.6652
# Depth: 3, Train ROC AUC: 0.6911, Valid ROC AUC: 0.6914
# Depth: 4, Train ROC AUC: 0.7029, Valid ROC AUC: 0.7012
# Depth: 5, Train ROC AUC: 0.7109, Valid ROC AUC: 0.7098
# Depth: 6, Train ROC AUC: 0.7154, Valid ROC AUC: 0.7144
# Depth: 7, Train ROC AUC: 0.7186, Valid ROC AUC: 0.7171
# Depth: 8, Train ROC AUC: 0.7214, Valid ROC AUC: 0.7167
# Early stopping triggered at depth: 8
# 최적 Depth: 7, 최종 Train ROC AUC: 0.7186, 최종 Valid ROC AUC: 0.7171
#
# === Ensemble Model 486/500 ===
# Depth: 1, Train ROC AUC: 0.5979, Valid ROC AUC: 0.5973
# Depth: 2, Train ROC AUC: 0.6645, Valid ROC AUC: 0.6658
# Depth: 3, Train ROC AUC: 0.6903, Valid ROC AUC: 0.6924
# Depth: 4, Train ROC AUC: 0.7031, Valid ROC AUC: 0.7058
# Depth: 5, Train ROC AUC: 0.7103, Valid ROC AUC: 0.7107
# Depth: 6, Train ROC AUC: 0.7153, Valid ROC AUC: 0.7152
# Depth: 7, Train ROC AUC: 0.7186, Valid ROC AUC: 0.7169
# Depth: 8, Train ROC AUC: 0.7215, Valid ROC AUC: 0.7162
# Early stopping triggered at depth: 8
# 최적 Depth: 7, 최종 Train ROC AUC: 0.7186, 최종 Valid ROC AUC: 0.7169
#
# === Ensemble Model 487/500 ===
# Depth: 1, Train ROC AUC: 0.5977, Valid ROC AUC: 0.5980
# Depth: 2, Train ROC AUC: 0.6647, Valid ROC AUC: 0.6653
# Depth: 3, Train ROC AUC: 0.6908, Valid ROC AUC: 0.6907
# Depth: 4, Train ROC AUC: 0.7034, Valid ROC AUC: 0.7049
# Depth: 5, Train ROC AUC: 0.7106, Valid ROC AUC: 0.7095
# Depth: 6, Train ROC AUC: 0.7156, Valid ROC AUC: 0.7136
# Depth: 7, Train ROC AUC: 0.7189, Valid ROC AUC: 0.7158
# Depth: 8, Train ROC AUC: 0.7215, Valid ROC AUC: 0.7157
# Early stopping triggered at depth: 8
# 최적 Depth: 7, 최종 Train ROC AUC: 0.7189, 최종 Valid ROC AUC: 0.7158
#
# === Ensemble Model 488/500 ===
# Depth: 1, Train ROC AUC: 0.5978, Valid ROC AUC: 0.5976
# Depth: 2, Train ROC AUC: 0.6656, Valid ROC AUC: 0.6617
# Depth: 3, Train ROC AUC: 0.6917, Valid ROC AUC: 0.6870
# Depth: 4, Train ROC AUC: 0.7043, Valid ROC AUC: 0.6998
# Depth: 5, Train ROC AUC: 0.7113, Valid ROC AUC: 0.7069
# Depth: 6, Train ROC AUC: 0.7166, Valid ROC AUC: 0.7102
# Depth: 7, Train ROC AUC: 0.7199, Valid ROC AUC: 0.7116
# Depth: 8, Train ROC AUC: 0.7226, Valid ROC AUC: 0.7118
# Depth: 9, Train ROC AUC: 0.7255, Valid ROC AUC: 0.7110
# Early stopping triggered at depth: 9
# 최적 Depth: 8, 최종 Train ROC AUC: 0.7226, 최종 Valid ROC AUC: 0.7118
#
# === Ensemble Model 489/500 ===
# Depth: 1, Train ROC AUC: 0.5981, Valid ROC AUC: 0.5967
# Depth: 2, Train ROC AUC: 0.6635, Valid ROC AUC: 0.6648
# Depth: 3, Train ROC AUC: 0.6911, Valid ROC AUC: 0.6913
# Depth: 4, Train ROC AUC: 0.7032, Valid ROC AUC: 0.7001
# Depth: 5, Train ROC AUC: 0.7111, Valid ROC AUC: 0.7090
# Depth: 6, Train ROC AUC: 0.7158, Valid ROC AUC: 0.7133
# Depth: 7, Train ROC AUC: 0.7188, Valid ROC AUC: 0.7155
# Depth: 8, Train ROC AUC: 0.7215, Valid ROC AUC: 0.7157
# Depth: 9, Train ROC AUC: 0.7246, Valid ROC AUC: 0.7154
# Early stopping triggered at depth: 9
# 최적 Depth: 8, 최종 Train ROC AUC: 0.7215, 최종 Valid ROC AUC: 0.7157
#
# === Ensemble Model 490/500 ===
# Depth: 1, Train ROC AUC: 0.5975, Valid ROC AUC: 0.5989
# Depth: 2, Train ROC AUC: 0.6646, Valid ROC AUC: 0.6654
# Depth: 3, Train ROC AUC: 0.6903, Valid ROC AUC: 0.6921
# Depth: 4, Train ROC AUC: 0.7033, Valid ROC AUC: 0.7048
# Depth: 5, Train ROC AUC: 0.7099, Valid ROC AUC: 0.7125
# Depth: 6, Train ROC AUC: 0.7149, Valid ROC AUC: 0.7168
# Depth: 7, Train ROC AUC: 0.7181, Valid ROC AUC: 0.7189
# Depth: 8, Train ROC AUC: 0.7205, Valid ROC AUC: 0.7203
# Depth: 9, Train ROC AUC: 0.7233, Valid ROC AUC: 0.7195
# Early stopping triggered at depth: 9
# 최적 Depth: 8, 최종 Train ROC AUC: 0.7205, 최종 Valid ROC AUC: 0.7203
#
# === Ensemble Model 491/500 ===
# Depth: 1, Train ROC AUC: 0.5979, Valid ROC AUC: 0.5974
# Depth: 2, Train ROC AUC: 0.6642, Valid ROC AUC: 0.6619
# Depth: 3, Train ROC AUC: 0.6917, Valid ROC AUC: 0.6890
# Depth: 4, Train ROC AUC: 0.7029, Valid ROC AUC: 0.7011
# Depth: 5, Train ROC AUC: 0.7112, Valid ROC AUC: 0.7087
# Depth: 6, Train ROC AUC: 0.7157, Valid ROC AUC: 0.7135
# Depth: 7, Train ROC AUC: 0.7191, Valid ROC AUC: 0.7148
# Depth: 8, Train ROC AUC: 0.7216, Valid ROC AUC: 0.7148
# Early stopping triggered at depth: 8
# 최적 Depth: 7, 최종 Train ROC AUC: 0.7191, 최종 Valid ROC AUC: 0.7148
#
# === Ensemble Model 492/500 ===
# Depth: 1, Train ROC AUC: 0.5975, Valid ROC AUC: 0.5990
# Depth: 2, Train ROC AUC: 0.6639, Valid ROC AUC: 0.6632
# Depth: 3, Train ROC AUC: 0.6912, Valid ROC AUC: 0.6911
# Depth: 4, Train ROC AUC: 0.7026, Valid ROC AUC: 0.7026
# Depth: 5, Train ROC AUC: 0.7107, Valid ROC AUC: 0.7106
# Depth: 6, Train ROC AUC: 0.7155, Valid ROC AUC: 0.7137
# Depth: 7, Train ROC AUC: 0.7186, Valid ROC AUC: 0.7158
# Depth: 8, Train ROC AUC: 0.7215, Valid ROC AUC: 0.7152
# Early stopping triggered at depth: 8
# 최적 Depth: 7, 최종 Train ROC AUC: 0.7186, 최종 Valid ROC AUC: 0.7158
#
# === Ensemble Model 493/500 ===
# Depth: 1, Train ROC AUC: 0.5982, Valid ROC AUC: 0.5963
# Depth: 2, Train ROC AUC: 0.6638, Valid ROC AUC: 0.6637
# Depth: 3, Train ROC AUC: 0.6915, Valid ROC AUC: 0.6896
# Depth: 4, Train ROC AUC: 0.7035, Valid ROC AUC: 0.6987
# Depth: 5, Train ROC AUC: 0.7118, Valid ROC AUC: 0.7064
# Depth: 6, Train ROC AUC: 0.7163, Valid ROC AUC: 0.7108
# Depth: 7, Train ROC AUC: 0.7193, Valid ROC AUC: 0.7131
# Depth: 8, Train ROC AUC: 0.7220, Valid ROC AUC: 0.7137
# Depth: 9, Train ROC AUC: 0.7249, Valid ROC AUC: 0.7127
# Early stopping triggered at depth: 9
# 최적 Depth: 8, 최종 Train ROC AUC: 0.7220, 최종 Valid ROC AUC: 0.7137
#
# === Ensemble Model 494/500 ===
# Depth: 1, Train ROC AUC: 0.5972, Valid ROC AUC: 0.6001
# Depth: 2, Train ROC AUC: 0.6627, Valid ROC AUC: 0.6678
# Depth: 3, Train ROC AUC: 0.6905, Valid ROC AUC: 0.6939
# Depth: 4, Train ROC AUC: 0.7024, Valid ROC AUC: 0.7031
# Depth: 5, Train ROC AUC: 0.7108, Valid ROC AUC: 0.7105
# Depth: 6, Train ROC AUC: 0.7154, Valid ROC AUC: 0.7144
# Depth: 7, Train ROC AUC: 0.7187, Valid ROC AUC: 0.7168
# Depth: 8, Train ROC AUC: 0.7214, Valid ROC AUC: 0.7156
# Early stopping triggered at depth: 8
# 최적 Depth: 7, 최종 Train ROC AUC: 0.7187, 최종 Valid ROC AUC: 0.7168
#
# === Ensemble Model 495/500 ===
# Depth: 1, Train ROC AUC: 0.5980, Valid ROC AUC: 0.5970
# Depth: 2, Train ROC AUC: 0.6654, Valid ROC AUC: 0.6625
# Depth: 3, Train ROC AUC: 0.6913, Valid ROC AUC: 0.6882
# Depth: 4, Train ROC AUC: 0.7042, Valid ROC AUC: 0.7016
# Depth: 5, Train ROC AUC: 0.7111, Valid ROC AUC: 0.7077
# Depth: 6, Train ROC AUC: 0.7162, Valid ROC AUC: 0.7119
# Depth: 7, Train ROC AUC: 0.7193, Valid ROC AUC: 0.7143
# Depth: 8, Train ROC AUC: 0.7220, Valid ROC AUC: 0.7144
# Depth: 9, Train ROC AUC: 0.7250, Valid ROC AUC: 0.7138
# Early stopping triggered at depth: 9
# 최적 Depth: 8, 최종 Train ROC AUC: 0.7220, 최종 Valid ROC AUC: 0.7144
#
# === Ensemble Model 496/500 ===
# Depth: 1, Train ROC AUC: 0.5972, Valid ROC AUC: 0.5999
# Depth: 2, Train ROC AUC: 0.6631, Valid ROC AUC: 0.6662
# Depth: 3, Train ROC AUC: 0.6904, Valid ROC AUC: 0.6942
# Depth: 4, Train ROC AUC: 0.7017, Valid ROC AUC: 0.7060
# Depth: 5, Train ROC AUC: 0.7099, Valid ROC AUC: 0.7139
# Depth: 6, Train ROC AUC: 0.7149, Valid ROC AUC: 0.7168
# Depth: 7, Train ROC AUC: 0.7179, Valid ROC AUC: 0.7188
# Depth: 8, Train ROC AUC: 0.7206, Valid ROC AUC: 0.7184
# Early stopping triggered at depth: 8
# 최적 Depth: 7, 최종 Train ROC AUC: 0.7179, 최종 Valid ROC AUC: 0.7188
#
# === Ensemble Model 497/500 ===
# Depth: 1, Train ROC AUC: 0.5978, Valid ROC AUC: 0.5978
# Depth: 2, Train ROC AUC: 0.6646, Valid ROC AUC: 0.6654
# Depth: 3, Train ROC AUC: 0.6908, Valid ROC AUC: 0.6905
# Depth: 4, Train ROC AUC: 0.7034, Valid ROC AUC: 0.7033
# Depth: 5, Train ROC AUC: 0.7105, Valid ROC AUC: 0.7090
# Depth: 6, Train ROC AUC: 0.7155, Valid ROC AUC: 0.7142
# Depth: 7, Train ROC AUC: 0.7185, Valid ROC AUC: 0.7167
# Depth: 8, Train ROC AUC: 0.7212, Valid ROC AUC: 0.7175
# Depth: 9, Train ROC AUC: 0.7240, Valid ROC AUC: 0.7158
# Early stopping triggered at depth: 9
# 최적 Depth: 8, 최종 Train ROC AUC: 0.7212, 최종 Valid ROC AUC: 0.7175
#
# === Ensemble Model 498/500 ===
# Depth: 1, Train ROC AUC: 0.5981, Valid ROC AUC: 0.5964
# Depth: 2, Train ROC AUC: 0.6647, Valid ROC AUC: 0.6598
# Depth: 3, Train ROC AUC: 0.6920, Valid ROC AUC: 0.6878
# Depth: 4, Train ROC AUC: 0.7032, Valid ROC AUC: 0.6989
# Depth: 5, Train ROC AUC: 0.7114, Valid ROC AUC: 0.7080
# Depth: 6, Train ROC AUC: 0.7160, Valid ROC AUC: 0.7117
# Depth: 7, Train ROC AUC: 0.7193, Valid ROC AUC: 0.7132
# Depth: 8, Train ROC AUC: 0.7221, Valid ROC AUC: 0.7132
# Depth: 9, Train ROC AUC: 0.7252, Valid ROC AUC: 0.7132
# Early stopping triggered at depth: 9
# 최적 Depth: 8, 최종 Train ROC AUC: 0.7221, 최종 Valid ROC AUC: 0.7132
#
# === Ensemble Model 499/500 ===
# Depth: 1, Train ROC AUC: 0.5980, Valid ROC AUC: 0.5969
# Depth: 2, Train ROC AUC: 0.6642, Valid ROC AUC: 0.6619
# Depth: 3, Train ROC AUC: 0.6920, Valid ROC AUC: 0.6879
# Depth: 4, Train ROC AUC: 0.7034, Valid ROC AUC: 0.6994
# Depth: 5, Train ROC AUC: 0.7117, Valid ROC AUC: 0.7066
# Depth: 6, Train ROC AUC: 0.7166, Valid ROC AUC: 0.7101
# Depth: 7, Train ROC AUC: 0.7196, Valid ROC AUC: 0.7127
# Depth: 8, Train ROC AUC: 0.7223, Valid ROC AUC: 0.7114
# Early stopping triggered at depth: 8
# 최적 Depth: 7, 최종 Train ROC AUC: 0.7196, 최종 Valid ROC AUC: 0.7127
#
# === Ensemble Model 500/500 ===
# Depth: 1, Train ROC AUC: 0.5978, Valid ROC AUC: 0.5977
# Depth: 2, Train ROC AUC: 0.6650, Valid ROC AUC: 0.6638
# Depth: 3, Train ROC AUC: 0.6910, Valid ROC AUC: 0.6896
# Depth: 4, Train ROC AUC: 0.7043, Valid ROC AUC: 0.7013
# Depth: 5, Train ROC AUC: 0.7113, Valid ROC AUC: 0.7078
# Depth: 6, Train ROC AUC: 0.7162, Valid ROC AUC: 0.7118
# Depth: 7, Train ROC AUC: 0.7194, Valid ROC AUC: 0.7143
# Depth: 8, Train ROC AUC: 0.7221, Valid ROC AUC: 0.7155
# Depth: 9, Train ROC AUC: 0.7251, Valid ROC AUC: 0.7149
# Early stopping triggered at depth: 9
# 최적 Depth: 8, 최종 Train ROC AUC: 0.7221, 최종 Valid ROC AUC: 0.7155
#
# Ensemble 평균 성능:
# 평균 Train ROC AUC: 0.7204
# 평균 Valid ROC AUC: 0.7164
#
# Ensemble 모델이 'ensemble_deep_decision_trees.pkl'로 저장되었습니다.
# 테스트 데이터 예측 결과가 각각 'ensemble_test_predictions_top100.csv',
# 'ensemble_test_predictions_top200.csv', 'ensemble_test_predictions_top300.csv',
# 그리고 'ensemble_test_predictions_all.csv' 파일에 저장되었습니다.

# %%
'ID', '시술 시기 코드', '시술 유형', '임신 성공 여부',
                '여성 주 불임 원인', '부부 주 불임 원인', '부부 부 불임 원인',
                'IVF 시술 횟수', 'IVF 출산 횟수', '혼합된 난자 수',
                '동결 배아 사용 여부', '신선 배아 사용 여부'

# %%
0.72 이상인 애들만 진행하기
